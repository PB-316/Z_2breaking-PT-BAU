# %%
import numpy as np
from cosmoTransitions import generic_potential_1
import matplotlib.pyplot as plt
import pandas as pd
from scipy import optimize
import scipy.integrate as integrate
import random
from scipy import interpolate, special
import seaborn as sns
from scipy import misc


# %config InlineBackend.figure_format = 'retina'
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams["figure.figsize"] = (8, 6)  #set default figure size



####Some definitions##
v2 = 246.2**2
mh=125.09
v=246.2
alpha=1/137
sinthw=np.sqrt(0.223)
g1=np.sqrt(4*np.pi*alpha/(1-sinthw**2))
g=np.sqrt(4*np.pi*alpha)/sinthw
Mplanck=2.4*10**18
cs=1/3**0.5 ##Sound speed constant


####This code uses an interpoaltion function for the number of degrees of freedom as function of temperature
###Data is obtained from https://member.ipmu.jp/satoshi.shirai/EOS2018
data = np.loadtxt( 'satoshi_dof.dat' )[500:3900]
Temperature_d=(data.T)[0]
dof_d=(data.T)[1]#relativistic degrees of freedom  
dof_s=(data.T)[3]#entropic degrees of freedom
g_star = interpolate.interp1d(Temperature_d, dof_d, kind='cubic')
g_star_s = interpolate.interp1d(Temperature_d, dof_s, kind='cubic')


class model1(generic_potential_1.generic_potential):
    def init(self, ms = 50, theta = 0, muhs = 0, u = 100, mu3 = 0,Lam=500):
        self.Lam=Lam
        self.yt=1/(1+u**2/Lam**2)**.5
        self.Ndim = 2
        self.renormScaleSq = v2
        self.ms = ms
        self.theta = theta
        self.muhs = muhs
        self.u = u
        self.mu3 = mu3
        self.lamh = 1/(4*v2)*(mh**2+self.ms**2 + (mh**2 - ms**2)*np.cos(2*self.theta))
        #self.lams = 1/(2*self.u**2)*(mh**2*np.sin(self.theta)**2+self.ms**2*np.cos(self.theta)**2 + self.mu3*self.u + self.muhs*v**2/(2*self.u))
        self.lams = 1/(4*self.u**3)*(mh**2*self.u + ms**2*self.u + 2*self.u**2*self.mu3 + v**2*self.muhs - (mh**2-ms**2)*self.u*np.cos(2*self.theta))
        self.lammix = 1/(v*self.u)*(-(self.ms**2-mh**2)*np.sin(self.theta)*np.cos(self.theta) - self.muhs*v)
        self.muh2 = self.lamh*v2 + self.muhs*self.u + self.lammix/2*self.u**2
        self.mus2 = -self.mu3*self.u + self.lams*self.u**2 + self.muhs*v2/(2*self.u) + self.lammix/2*v2

    def forbidPhaseCrit(self, X):
        return any([np.array([X])[...,0] < -5.0])
        #return any([np.array([X])[...,0] < -5.0, np.array([X])[...,1] < -5.0])

    def V0(self, X):
        X = np.asanyarray(X)
        h, s = X[...,0], X[...,1]
        pot = -1/2*self.muh2*h**2 + 1/4*self.lamh*h**4 - 1/2*self.mus2*s**2 - 1/3*self.mu3*s**3 + 1/4*self.lams*s**4 + 1/2*self.muhs*h**2*s + 1/4*self.lammix*h**2*s**2
        return pot

    def boson_massSq(self, X, T):
        X = np.array(X)
        h, s = X[...,0], X[...,1]

       #####Scalar thermal masses, obtained from appendix of 1702.06124
        Pi_h = T**2*(g1**2/16 + 3*g**2/16 + self.lamh/2 + self.yt**2/4 + self.lammix/24)
        Pi_s= T**2*(self.lammix/6 + self.lams/4)

        ##Scalar mass matrix##
        a=3*h**2*self.lamh + s**2*self.lammix/2 - self.muh2 + s*self.muhs + Pi_h
        b=h**2*self.lammix/2 + 3*s**2*self.lams - 2*s*self.mu3 - self.mus2 + Pi_s
        cc=h*s*self.lammix  + h*self.muhs
        A=(a+b)/2
        B=1/2*np.sqrt((a-b)**2+4*cc**2)
        m1=A+B
        m2=A-B

        ####Gauge boson masses (Longitudinal)
        mWL = g**2*h**2/4 + 11/6*g**2*T**2
        ag=g**2*h**2/4 + 11/6*g**2*T**2
        bg=1/4*g1**2*h**2 + 11/6*g1**2*T**2
        ccg=-1/4*g1*g*h**2
        Ag=(ag+bg)/2
        Bg=1/2*np.sqrt((ag-bg)**2+4*ccg**2)
        mZL=Ag+Bg
        mPh=Ag-Bg


        M = np.array([m1,m2,g**2*h**2/4,h**2/4*(g**2+g1**2),mWL,mZL])
        if self.ms<mh:
            Mphys = np.array([mh**2,self.ms**2,g**2*v**2/4,v**2/4*(g**2+g1**2),g**2*v**2/4,v**2/4*(g**2+g1**2)])
        else:
            Mphys = np.array([self.ms**2,mh**2,g**2*v**2/4,v**2/4*(g**2+g1**2),g**2*v**2/4,v**2/4*(g**2+g1**2)])

        # At this point, we have an array of boson masses, but each entry might
        # be an array itself. This happens if the input X is an array of points.
        # The generic_potential class requires that the output of this function
        # have the different masses lie along the last axis, just like the
        # different fields lie along the last axis of X, so we need to reorder
        # the axes. The next line does this, and should probably be included in
        # all subclasses.
        M = np.rollaxis(M, 0, len(M.shape))
        Mphys = np.rollaxis(Mphys, 0, len(Mphys.shape))

        # The number of degrees of freedom for the masses. This should be a
        # one-dimensional array with the same number of entries as there are
        # masses.

        dof = np.array([1,1,4,2 , 2,1]) ##Longitudinal at the end


        # c is a constant for each particle used in the Coleman-Weinberg
        # potential using MS-bar renormalization. It equals 1.5 for all scalars
        # and the longitudinal polarizations of the gauge bosons, and 0.5 for
        # transverse gauge bosons.
        #c = np.array([1.5,1.5,1.5,1.5,1.5,1.5,1.5])
        c = np.array([1.5,1.5,1.5,1.5,1.5,1.5])

        return M, dof, c, Mphys

   


    def fermion_massSq(self, X):
        X = np.array(X)
        h,s = X[...,0], X[...,1]
        mt=self.yt**2*h**2/2*(1+s**2/self.Lam**2)
        #mt=self.yt**2*h**2/2
        M = np.array([mt])
        Mphys = np.array([v**2/2])

        # At this point, we have an array of boson masses, but each entry might
        # be an array itself. This happens if the input X is an array of points.
        # The generic_potential class requires that the output of this function
        # have the different masses lie along the last axis, just like the
        # different fields lie along the last axis of X, so we need to reorder
        # the axes. The next line does this, and should probably be included in
        # all subclasses.
        M = np.rollaxis(M, 0, len(M.shape))
        Mphys = np.rollaxis(Mphys, 0, len(Mphys.shape))

        dof = np.array([12])
        return M, dof, Mphys


    def approxZeroTMin(self):
        # There are generically two minima at zero temperature in this model,
        # and we want to include both of them.

        return [np.array([v,self.u])]

    def theory_consistent(self):
        perturbative_limit=4*np.pi
        perturbativity=self.lamh<=perturbative_limit and self.lams<=perturbative_limit and abs(self.lammix)<=perturbative_limit
        positivity=(self.lamh>0) and (self.lams>0) and (self.lammix>-2*(self.lamh*self.lams)**.5)
        if perturbativity and positivity:
            #print("Model is theoretically consistent \n")
            return True
        else:
            #print("Model is NOT theoretically consistent \n")
            return False


    def print_couplings(self):
        print("Potential parameters are given by \n ")
        print("mus2=",self.mus2, "muh2=",self.muh2,"lamh=",self.lamh,"lams=",self.lams,"lammix=",self.lammix,"\n")
        print("Model parameters are \n")
        print("ms=",self.ms,"theta=",self.theta,"muhs=",self.muhs,"u=",self.u,"mu3=",self.mu3,"\n")

    def isEWSB(self):
        """Method to find the deepest minima of the potential at T=0.
        Doesn't work for Z_2 symmetric potential!!!"""
        n=100
        X_EW=np.array([v,self.u])
        minima=[]
        if self.muhs==0 and self.mu3==0:
            #print("Model has a Z2 symmetry in the potential \n")
            #print("isEWSB=True \n")
            return True,X_EW
        #------------
        X0=self.findMinimum([0,100],0)
        if self.Vtot(X0,0)<=self.Vtot(X_EW,0) and abs(abs(X0[0])-v)>10 and abs(self.Vtot(X0,0)-self.Vtot(X_EW,0))>1:
            #print("Global minimum found at X=",X0,"\n")
            #print("isEWSB=False \n")
            return False, X0
        X0=self.findMinimum([0,-100],0)
        if self.Vtot(X0,0)<=self.Vtot(X_EW,0) and abs(abs(X0[0])-v)>10 and abs(self.Vtot(X0,0)-self.Vtot(X_EW,0))>1:
            #print("Global minimum found at X=",X0,"\n")
            #print("isEWSB=False \n")
            return False, X0
         
        ###This loop search for a global minima randomly
        for i in range(n):
            x1=np.random.uniform(-100,4*self.Tmax)
            x2=np.random.uniform(-4*self.Tmax,4*self.Tmax)
            X0=self.findMinimum([x1,x2], T=0.0)
            if self.Vtot(X0,0)<=self.Vtot(X_EW,0) and abs(X0[0])-v>10 and abs(self.Vtot(X0,0)-self.Vtot(X_EW,0))>1e2:
                #print("Global minimum found at X=",X0,"\n")
                #print("isEWSB=False \n")
                return False, X0
        #print("isEWSB=True \n")
        return True,X_EW


#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTION
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS

def g_loop(z):
    """Loop integral for EDM. Extracted from (A.2) of 1712.09613"""
    g_integrand=lambda x: np.log(x*(1-x)/z)/(x*(1-x)-z)
    integral=integrate.quad(g_integrand,0,1)[0]
    return z*0.5*integral


def d_eEDM(X):
    X=np.array(X)
    theta,ms,Lam=X[...,0],X[...,1],X[...,2]
    G_f=1/2**.5/v**2
    ee=g1
    me=0.5*1e-3
    mt=172.9
    alpha=1/137
    numeric=ee/3/np.pi**2*alpha*G_f*v/2**.5/np.pi/mt*me*(v/2**.5/Lam)
    out=np.sin(theta)*np.cos(theta)*(-g_loop(mt**2/mh**2) + g_loop(mt**2/ms**2))
    return np.abs(numeric*out)

d_eEDM_bound=1.89*10**(-16) 

def alpha_GW(Tnuc,Drho):
    ####This code gives the parameter alpha relevant for stochastic GW spectrum
    ##AS APPEAR IN FORMULA (8.2) OF 1912.12634
    num_dof=g_star(Tnuc)
    radiationDensity=np.pi**2/30*num_dof*Tnuc**4
    latentHeat=Drho
    return latentHeat/radiationDensity


def trans_class(SymNR):
    """Classify the transition according to the following characteristics:
    ---------
    phi-sym: transition happens in the s-field direction
    phi-symNR: transition happens in the s-field direction (symmetry is not restored at T=1000)
    """
    SNR="sym"
    if SymNR==True:
        SNR="SNR"

    if dh>10 and ds>10:
        return "hs-"+SNR
    elif dh>10 and ds<1:
        return "h-"+SNR
    elif ds>10 and dh<1:
        return "s-"+SNR
    else:
        return "none"+SNR

def beta_GW(Tnuc,dS_TdT):
    ###This code defines the parameter beta relevant for stochastic GW spectrum
    beta=Tnuc*dS_TdT
    return beta

def S_profile(T,elem):
    """This function calculates the Euclidean action from a model m at temperature T
    after knowing its phase history. If more than one FOPT is found it uses "elem" from the list. 
    """
    profile=elem["instanton"].profile1D
    alpha_ode=2
    temp=T
    r, phi, dphi, phivector = profile.R, profile.Phi, profile.dPhi, elem["instanton"].Phi
    phi_meta=elem["high_vev"]
    # Find the area of an n-sphere (alpha=n):
    d = alpha_ode+1  # Number of dimensions in the integration
    area = r**alpha_ode * 2*np.pi**(d*.5)/special.gamma(d*.5) ##4 pi r^2 the surface of a sphere
    # And integrate the profile
    integrand = 0.5 * dphi**2 + m.Vtot(phivector,temp) - m.Vtot(phi_meta,temp)
    integrand *= area
    S = integrate.simps(integrand, r)
    # Find the bulk term in the bubble interior
    volume = r[0]**d * np.pi**(d*.5)/special.gamma(d*.5 + 1)
    S += volume * (m.Vtot(phivector[0],temp) - m.Vtot(phi_meta,temp))

    return S/T

#####
def my_getPhases(m):
    myexps=[(-5,-3),(-5,-5),(-5,-4),(-3,-3)]
    for nord in myexps:
        print("doing",nord)
        try:
            m.getPhases(tracingArgs={"dtstart":10**(nord[0]), "tjump":10**(nord[1])})
            phases_out=m.phases
        except:
            phases_out={}
        finally:
            if len(phases_out)>1:
                break
    return phases_out




##DEFINE Nucleation FUNCTION (TO BE OPTIMIZED)
def nucleation_temp(T):
    """DEFINE Nucleation FUNCTION (TO BE OPTIMIZED)
    """
    from cosmoTransitions import transitionFinder as tf
    try:
        S=tf._tunnelFromPhaseAtT(T=T, phases=m.phases, start_phase=m.phases[nuc_dict["high_phase"]], V=m.Vtot, 
                                 dV=m.gradV,phitol=1e-15, overlapAngle=45, nuclCriterion=lambda S,T: Gamma_Hubble4(S,T)-Hubble_total(T)**4,
                                 fullTunneling_params={}, verbose=True, outdict={})
    except:
        return 1e+100
    
    if np.isnan(S):
        return 1e+100
    else:
        return S**2
    
def Hubble_vacuum(T):
    """Hubble parameter for matter density alone. Second term in formula 2.6 of 1809.08242 """
    if m.phases is None:
        phases_dict=m.getPhases()
    else:
        phases_dict=m.phases
    if T<nuc_dict["Tmin"] or T>nuc_dict["Tmax"]:
        return 0
    from cosmoTransitions import transitionFinder as tf
    crit_temps=tf.findCriticalTemperatures(phases_dict, m.Vtot)
    Delta_V=0.0
    for tran_barrier in crit_temps:
        if tran_barrier["trantype"] ==2:
            continue
        ###LOOKS FOR TWO-STEP TRANSITIONS
        #elif T>tran_barrier["Tcrit"] or ((abs(tran_barrier["high_vev"][0]-tran_barrier["low_vev"][0])<1) and (abs(tran_barrier["high_vev"][1]-tran_barrier["low_vev"][1])<1)):
        elif T>tran_barrier["Tcrit"]: ##This is redundant
            continue
        else:
            V_high=m.Vtot(phases_dict[tran_barrier["high_phase"]].valAt(T),T)
            V_low=m.Vtot(phases_dict[tran_barrier["low_phase"]].valAt(T),T)
            if V_high>V_low: 
                Delta_V += V_high - V_low

    return (Delta_V/3)**0.5/Mplanck

def Hubble_radiation(T):
    num_dof=g_star(T)
    Hubble_rad_squared=num_dof*np.pi**2/90*T**4/Mplanck**2
    return Hubble_rad_squared**.5

def Hubble_total(T):
    num_dof=g_star(T)
    Hubble_rad_squared=num_dof*np.pi**2/90*T**4/Mplanck**2
    return (Hubble_rad_squared+Hubble_vacuum(T)**2)**0.5


def Gamma_Hubble4(S,T):
    """Nucleation probability per Hubble volume, including matter contribution. 
    Integrand in formula (2.2) 1809.08242 """
    Gamma1=T**4*np.exp(-S/T)*np.sqrt((S/2/np.pi/T))**3
    return Gamma1

##DEFINE ACTION FUNCTION
def my_Action(T):
    """Calculates S/T at T"""
    from cosmoTransitions import transitionFinder as tf
    try:
        S=tf._tunnelFromPhaseAtT(T=T, phases=m.phases, start_phase=m.phases[nuc_dict["high_phase"]], V=m.Vtot, 
                             dV=m.gradV, phitol=1e-15, overlapAngle=45, nuclCriterion=lambda S,T: S/T ,
                             fullTunneling_params={}, verbose=True, outdict={})
    except:
        S=np.inf
    return S



####This codes the GW signal and SNR given T,alpha, beta and vw. 
LISA_data = np.loadtxt( 'PLS_ESACallv1-2_04yr.txt' )
LISA_data=LISA_data[::20]
LISA_noise=LISA_data[::,0::2]
LISA_data=LISA_data[::,0::3]


def GW_signal_old(Temp,alpha,beta,vel):
    f_redshift=1.65*10**(-5)*(Temp/100)*(g_star(Temp)/100)**(1/6)
    Omega_redshift=1.67*10**(-5)*(100/g_star(Temp))**(1/3)
    kappa_sw=alpha/(0.73+0.083*alpha**0.5+alpha)
    Uf=(3/4*alpha/(1+alpha)*kappa_sw)**0.5
    HR=(8*np.pi)**(1/3)*max(vel,cs)/beta
    HRb=(vel-cs)/vel*HR
    Htau_sw=HR/Uf
    S_fun=lambda s:s**3*(7/(4+3*s**2))**(7/2)
    Omega_sw=3*0.687*Omega_redshift*(1-1/(1+2*HR/Uf)**0.5)*(kappa_sw*alpha/(1+alpha))**2*0.012*HR/cs
    f_sw=f_redshift*(2.6/1.65)*(1/HR)
    GW_tab=[Omega_sw*S_fun(f/f_sw) for f in LISA_noise[::,0]]
    return np.array([LISA_noise[::,0],GW_tab])

def SNR_GW_old(Temp,alpha,beta,vel):
    time=4
    f_redshift=1.65*10**(-5)*(Temp/100)*(g_star(Temp)/100)**(1/6)
    Omega_redshift=1.67*10**(-5)*(100/g_star(Temp))**(1/3)
    kappa_sw=alpha/(0.73+0.083*alpha**0.5+alpha)
    Uf=(3/4*alpha/(1+alpha)*kappa_sw)**0.5
    HR=(8*np.pi)**(1/3)*max(vel,cs)/beta
    HRb=(vel-cs)/vel*HR
    Htau_sw=HR/Uf
    S_fun=lambda s:s**3*(7/(4+3*s**2))**(7/2)
    Omega_sw=3*0.687*Omega_redshift*(1-1/(1+2*HR/Uf)**0.5)*(kappa_sw*alpha/(1+alpha))**2*0.012*HR/cs
    f_sw=f_redshift*(2.6/1.65)*(1/HR)
    integral=np.sum([(LISA_noise[i+1][0]-LISA_noise[i][0])/2*(Omega_sw*S_fun(LISA_noise[i][0]/f_sw)/(LISA_noise[i][1]))**2 for i in range(0,len(LISA_noise)-1)])
    return (time*3.15*10**7*integral)**0.5


def r_comoving(T,T1):
    """Comoving size of a bubble nucleated at T' after growing until T"""
    vw=1
    T_range=np.linspace(T,T1)
    T_half=(T_range[1:]+T_range[:-1])/2
    T_diff=(T_range[1:]-T_range[:-1])
    Hubble_range=[1/Hubble_total(Temp) for Temp in T_half]
    integral=np.sum(np.array(Hubble_range)*T_diff)
    return vw*integral

def Gamma(T):
    """This function gives the nucleation rate at finite temperature """
    try:
        S_action=my_Action(T)*T
    except:
        S_action=np.inf
    if S_action==np.inf:
        return 0
    Gamma1=T**4*np.exp(-S_action/T)*np.sqrt((S_action/2/np.pi/T))**3
    return Gamma1


def I_volume_fraction_integrand(T,T1):
    """For given temperatures T1>T, it calculates the integrand of the volume fraction.
    Includes the factor 4pi/3."""
    if T>T1:
        print("incorrect setting of temperatures")
        return 
    Gam=Gamma(T1)/Hubble_total(T1)/T1**4
    if Gam==0:
        return 0
    r_vol=r_comoving(T,T1)
    if r_vol==0:
        return 0
    output=Gam*r_vol**3
    return 4*np.pi/3*output

def I_volume_fraction(T,vw):
    """For given temperature T. It calculates the volume fraction doing the integral of I_volume_fraction_integrand
    starting from T until the critial temperature found by nucleation_temp ("Tmax")"""
    n=20 ###This number should be changed on a case by case basis
    t_range=np.linspace(T,nuc_dict["Tmax"],n)
    I_list=[]
    for tempi in t_range:
        x=I_volume_fraction_integrand(T,tempi)
        I_list.append(x)
    fun_inter=interpolate.interp1d(t_range,I_list)
    result = integrate.quad(lambda Tx: fun_inter(Tx),t_range[0], t_range[-1])
    return vw**3*result[0]-0.34




def kappa(xi_w,alpha):
    """
    Fit for the efficiency factor 
    """
    c_s         = 1./np.sqrt(3.)
    #kappa_A     = xi_w**1.2 * 6.9*alpha/(1.39-0.0037*np.sqrt(alpha)+alpha)
    kappa_A     = xi_w**1.2 * 6.9*alpha/(1.36-0.037*np.sqrt(alpha)+alpha)
    #kappa_B     = alpha**0.4/(0.0017+(0.997+alpha)**0.4)
    kappa_B     = alpha**0.4/(0.017+(0.997+alpha)**0.4)
    #kappa_C     = np.sqrt(alpha)/(0.135+np.sqrt(0.98)+alpha)
    kappa_C     = np.sqrt(alpha)/(0.135+np.sqrt(0.98+alpha))
    #kappa_D     = alpha/(0.75+0.085*np.sqrt(alpha)+alpha)
    kappa_D     = alpha/(0.73 + 0.083*np.sqrt(alpha)+alpha)
    delta_kappa = -0.9*np.log(np.sqrt(alpha)/(1.+np.sqrt(alpha)))
    xi_w_J      = (np.sqrt(2./3.*alpha+alpha**2)+1./np.sqrt(3.))/(1.+alpha)

    if xi_w < c_s:
    # deflagration
        return c_s**2.2 * kappa_A * kappa_B / ( (c_s**2.2 - xi_w**2.2 )*kappa_B + xi_w * c_s**1.2 * kappa_A )
    elif xi_w < xi_w_J:
    # hybrid
        return (
            kappa_B
            + (xi_w -c_s)*delta_kappa
            + (xi_w-c_s)**3/(xi_w_J-c_s)**3 * ( kappa_C - kappa_B - (xi_w_J-c_s)*delta_kappa )
        )
    #else:
    # detonation
    return (xi_w_J-1.)**3 * (xi_w_J/xi_w)**2.5 * kappa_C * kappa_D / (
        ( (xi_w_J-1.)**3 - (xi_w-1.)**3 ) * xi_w_J**2.5 * kappa_C
        + (xi_w-1.)**3 * kappa_D
    )




def T_percolation(n,vw):
    """Having Tnuc it computes the percolation temperature using I=0.34 as optimization criteria."""
    t_range=np.linspace(nuc_dict["Tmin"],Tnuc,n)[::-1]
    I_list=[]
    t_range_1=[]
    for temp in t_range:
        x=I_volume_fraction(temp,vw)
        I_list.append(x)
        t_range_1.append(temp)
        if x>10:
            break
    fun_inter=interpolate.interp1d(t_range_1,I_list)
    def f_opt(t): 
        try: 
            return fun_inter(t)**2 
        except: 
            return 1e+100
    Tp = optimize.fmin(f_opt,(t_range_1[0]+t_range_1[-1])*0.5,xtol=0.0001)[0]
    volume_shrinks=Tp*misc.derivative(fun_inter, x0=Tp, dx=1e-5, n=1)<-3
    print("The physical volunme diminishes at Tp:",volume_shrinks)
    plt.plot(t_range_1,fun_inter(t_range_1))
    plt.ylim(-1,1)
    plt.axhline(y=0)
    plt.xlabel("$T (GeV)$")
    plt.title("$I(T)-0.34$")
    plt.show()
    return Tp,volume_shrinks


LISA_curve=pd.read_csv("LISA_integrated_curve.csv",index_col=[0])
def GW_signal(Temp,alpha,beta,vel):
    HR=(8*np.pi)**(1/3)*max(vel,cs)/beta ##eqn. (7.5)
    f_sw=2.6*1e-5/HR*(Temp/100)*(g_star(Temp)/100)**(1/6) ##eqn. (7.3)
    Sw = lambda f: (f/f_sw)**3*(4/7 + 3/7*(f/f_sw)**2)**(-7/2) ##eqn. (7.2)
    Uf=np.sqrt(3/4*alpha/(1+alpha)*kappa(vel,alpha))##eqn. (7.4)
    tauH = HR/Uf ##eqn. (7.4)
    prefactor=4.13*1e-7*HR*(1-1/np.sqrt(1+2*tauH))*(kappa(vel,alpha)*alpha/(1+alpha))**2 ##eqn. (7.1)
    Omega=lambda f: prefactor*(100/g_star(Temp))**(1/3)*Sw(f) ##eqn. (7.1)
    f_range=LISA_curve.f
    GW_tab=[Omega(f) for f in f_range]
    return np.array([list(f_range), list(GW_tab)])

def SNR_GW(signal):
    """Computes SNR given signal (f,Omega)"""
    time=4
    f,Om=signal
    Om=np.array(Om)
    On=np.array(LISA_curve.Omega_noise)
    integral=integrate.simps(Om**2/On**2,f)
    return (time*3.15*10**7*integral)**0.5


def find_nucleation(m):
    """Find min and max temperatures to search for nucleation. IT will be used by bisection method.
    Parameters
        ----------
        m: a model instance. In this case m=model1(kk=1/600**2) for example.
    Returns
        -------
        nuc_dict: a dictionary containing the relevant temperatures and phases indexes. 
                It will be used by the other methods to find the nucleation and percolation parameters  
    """
    if m.phases is None:
        try:
            #phases_dict=m.getPhases()
            #phases_dict=m.getPhases(tracingArgs={"dtstart":1e-3, "tjump":1e-3})
            #phases_dict=m.getPhases(tracingArgs={"dtstart":1e-5, "tjump":1e-4})
            phases_dict=my_getPhases(m)
        except:
            return {}
    else:
        phases_dict=m.phases
    if len(phases_dict)<=1:
        return {}
    from cosmoTransitions import transitionFinder as tf
    crit_temps=tf.findCriticalTemperatures(phases_dict, m.Vtot)
    Num_relevant_trans=0
    ###DETERMINE IF THERE COULD BE TWO-STEP FOPTs
    my_dicts=[]
    for elem in crit_temps:
        if elem["trantype"]==1 and (abs(elem["low_vev"][0]-elem["high_vev"][0])>10 or abs(elem["low_vev"][1]-elem["high_vev"][1])>10):
            print("Tunneling is relevant from phase " + str(elem["high_phase"])+ " to " + str(elem["low_phase"])  )
            Tmax=elem["Tcrit"]
            Tmin=phases_dict[elem["high_phase"]].T[0]
            print("high_vev", elem["high_vev"])
            print("low_vev", elem["low_vev"])
            print("max temperature is", Tmax)
            print("min temperature is", Tmin)
            Num_relevant_trans+=1
            high_phase_key=elem["high_phase"]
            low_phase_key=elem["low_phase"]
            dict_output= {"Tmin":Tmin, "Tmax":Tmax, "high_phase": high_phase_key,"low_phase": low_phase_key}
            #my_dicts.append(dict_output)   
            
            X0=m.phases[dict_output["high_phase"]].X[0]
            T0=m.phases[dict_output["high_phase"]].T[0]
            stable=not np.any(np.linalg.eig(m.d2V(X0,T0))[0]<=0)
            
            def findminT(T):
                """Function to find the minimum temperature at which the high_vev coexists. 
                Written in form for optimization"""
                Xmin=m.findMinimum(X0,T)
                dx=np.sum((Xmin-X0)**2)**0.5
                stable=not np.any(np.linalg.eig(m.d2V(Xmin,T))[0]<=0)
                if stable==False or (dx<1) == False or T<0:
                    return 5000
                else:
                    return  T
            Tmin_opt=optimize.fminbound(findminT,0,T0) 
            dict_output["Tmin"]=Tmin_opt
            my_dicts.append(dict_output)   
        else: 
            continue
        
    return my_dicts

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Compute the transition of model(s)

# %%
def findTnuc():
    """Finds the nucleation temperature and checks if it actually satisfies the condition Gamma/H^4==1"""
    fun_nucleation=lambda T: (Gamma(T)/Hubble_total(T)**4-1.)**4
    if nuc_dict["Tmin"]<1:
        Tnuc=optimize.fminbound(fun_nucleation,np.mean([nuc_dict["Tmin"]+1e-3,nuc_dict["Tmax"]]),nuc_dict["Tmax"])
    else:
        Tnuc=optimize.fminbound(fun_nucleation,nuc_dict["Tmin"]+1e-3,nuc_dict["Tmax"])   
    S_nuc=my_Action(Tnuc)
    check_nucleation=abs(Gamma_Hubble4(S_nuc*Tnuc,Tnuc)/Hubble_total(Tnuc)**4-1)<1e-3
    if check_nucleation==True:
        return Tnuc, S_nuc, True
    else:
        Tnuc=optimize.fminbound(nucleation_temp,nuc_dict["Tmin"],nuc_dict["Tmax"])
    S_nuc=my_Action(Tnuc)
    check_nucleation=abs(Gamma_Hubble4(S_nuc*Tnuc,Tnuc)/Hubble_total(Tnuc)**4-1)<1e-3
    if check_nucleation==True:
        return Tnuc, S_nuc, True
    else:
        return None, None, False

# %%
df=pd.read_csv("SCANS/BAU/sols_fullmodel_All.csv",index_col=[0])
df=df[df["vel_converged"]==True]
df=df[df.Lam_CP>df.ms]
df=df[df.Lam_CP>v]
df=df[df.Lam_CP>abs(df.mu3)]
df=df[df.Lam_CP>abs(df.muhs)]
df=df[df.alpha_max>1e-3]
df=df.sort_values("alpha_max")

hydrocolumns=['vw', 'Lh', 'dh', 'h0', 'Ls', 'ds', 'shigh', 'slow',
              'Type', 'alpha_p', 'vm', 'vp', 'xi_s', 'Tp/TN', 'vel_converged']

modi=np.random.randint(0,len(df))
modi=-1
print(modi)


num_points=1
for l in range(num_points):
    ms_val=df.iloc[modi]["ms"]
    theta_val=df.iloc[modi]["theta"]
    u_val=df.iloc[modi]["u"]
    mu3_val=df.iloc[modi]["mu3"]
    muhs_val=df.iloc[modi]["muhs"]
    Lam_val=df.iloc[modi]["Lam_CP"]
    m=model1(ms = ms_val, theta = theta_val,muhs= muhs_val ,u = u_val,mu3 = mu3_val,Lam=Lam_val)

    edm_Bool=d_eEDM([m.theta,m.ms,m.Lam])<d_eEDM_bound
    thbool=m.theory_consistent()
    EWSBbool=m.isEWSB()
    EWSB_new=EWSBbool[0]==True  or (sum(EWSBbool[1]**2)**.5>Mplanck)
    if not (edm_Bool==True and thbool==True and EWSB_new):
        break
    Pih=g1**2/16 + 3*g**2/16 + m.lamh/2 + m.yt**2/4 + m.lammix/24
    Pis=m.lammix/6 + m.lams/4
    lamh_tilde=m.lamh - m.lammix**2/4/m.lams
    dict_out={'ms':m.ms,'theta':m.theta, 'u':m.u,"muhs":m.muhs,"mu3":m.mu3,"yt":m.yt,
          "lamh":m.lamh,"lams":m.lams,"lammix":m.lammix,
          "muh2":m.muh2,"mus2":m.mus2,
          "Pih":Pih,"Pis":Pis,"lamh_tilde":lamh_tilde,"Lam_CP":m.Lam}
    dict_out.update({ "th_bool":thbool,"isEWSB": EWSBbool[0],"edm_Bool":edm_Bool})
     
    nuc_dicts=find_nucleation(m)
    phases_copy=m.phases.copy()
    if len(nuc_dicts)==0:
        continue
    else:
        num_dicts=len(nuc_dicts)
    dict_out.update({"num_FOPT":num_dicts})    

    for nuc_dict in nuc_dicts: 
        try:
            ###Parameters at nucleation temperature------------------------------------------------------------
            dict_out.update({"Tc_"+str(nuc_dicts.index(nuc_dict)):nuc_dict["Tmax"],
                             "Tmin_"+str(nuc_dicts.index(nuc_dict)):nuc_dict["Tmin"]})
            
            relevant_phases={nuc_dict["high_phase"]:m.phases[nuc_dict["high_phase"]],nuc_dict["low_phase"]:m.phases[nuc_dict["low_phase"]]}
            m.phases=relevant_phases
            nucleation= findTnuc()
            if nucleation[2]==False:
                m.phases=phases_copy
                continue
            else:
                Tnuc, S_nuc = nucleation[0], nucleation[1]
                dict_out.update({'Tnuc_'+str(nuc_dicts.index(nuc_dict)): Tnuc})
                dict_out.update({"action_Tn_"+str(nuc_dicts.index(nuc_dict)):S_nuc*Tnuc})
                

            m.findAllTransitions(tunnelFromPhase_args={"nuclCriterion":lambda S,T: S/(T+1e-100)-S_nuc})
            alltrans_Tnuc=m.TnTrans
            elem=alltrans_Tnuc[0] ###How many transitions??
            if abs(elem["action"]-S_nuc*Tnuc)>1 and abs(elem["Tnuc"]-Tnuc)>1:
                """check if all transitions indeed find the same S and T values"""
                m.phases=phases_copy
                continue
            dS_TdT_Tnuc=misc.derivative(S_profile, x0=Tnuc, dx=.01, n=1, args=(elem,),order=7)
            
            #--------vevs, energy density, pressure and wall velocity at Tnuc---------------------------------------------------------
            phi_stable_Tnuc=elem["low_vev"]
            dict_out.update({"h_low_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tnuc[0],
                             "s_low_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tnuc[1]})
            
            phi_meta_Tnuc=elem["high_vev"]
            dict_out.update({"h_high_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tnuc[0],
                             "s_high_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tnuc[1]})
            
            Delta_rho_Tnuc=m.energyDensity(phi_meta_Tnuc,Tnuc,include_radiation=True)-m.energyDensity(phi_stable_Tnuc,Tnuc,include_radiation=True)
            dict_out.update({"Delta_rho_Tnuc_"+str(nuc_dicts.index(nuc_dict)): Delta_rho_Tnuc})
            
            Delta_p_Tnuc=m.Vtot(phi_meta_Tnuc,Tnuc)-m.Vtot(phi_stable_Tnuc,Tnuc)
            dict_out.update({"Delta_p_Tnuc_"+str(nuc_dicts.index(nuc_dict)): Delta_p_Tnuc})
            
            alpha_Tnuc=alpha_GW(Tnuc,Delta_rho_Tnuc)
            dict_out.update({"alpha_Tnuc_"+str(nuc_dicts.index(nuc_dict)):alpha_Tnuc})
            
            beta_Tnuc=beta_GW(Tnuc,dS_TdT_Tnuc)
            dict_out.update({"beta_Tnuc_"+str(nuc_dicts.index(nuc_dict)):beta_Tnuc})
            
            xi_Jouguet=((alpha_Tnuc*(2+3*alpha_Tnuc))**0.5+1)/(3**0.5*(1+alpha_Tnuc))
            dV = m.Vtot(phi_meta_Tnuc,Tnuc)-m.Vtot(phi_stable_Tnuc,Tnuc)
            radiationDensity=np.pi**2/30*g_star(Tnuc)*Tnuc**4
            vwall=(dV/alpha_Tnuc/radiationDensity)**0.5 ##Analytic formula
            dict_out.update({"vwall_"+str(nuc_dicts.index(nuc_dict)): vwall,
                             "xi_Jouguet_"+str(nuc_dicts.index(nuc_dict)):xi_Jouguet}) 
            
            my_signal_Tnuc=GW_signal(Tnuc*(1+alpha_Tnuc)**0.25,alpha_Tnuc,beta_Tnuc,1)
            peak_vals_Tnuc=my_signal_Tnuc.T[my_signal_Tnuc[1]==max(my_signal_Tnuc[1])][0] ##Extract values at peak
            f_peak_Tnuc=peak_vals_Tnuc[0]
            Omega_peak_Tnuc=peak_vals_Tnuc[1]
            dict_out.update({"f_peak_Tnuc_"+str(nuc_dicts.index(nuc_dict)): f_peak_Tnuc,
                        "Omega_peak_Tnuc_"+str(nuc_dicts.index(nuc_dict)):Omega_peak_Tnuc})
            SNR_Tnuc=SNR_GW(my_signal_Tnuc)
            dict_out.update({"SNR_Tnuc_"+str(nuc_dicts.index(nuc_dict)): SNR_Tnuc})
            
            ##Parameters at PERCOLATION temperature Tp-------------------------------------- 
            Tp,volume_shrinks=T_percolation(20,df.iloc[modi]["vw"])
            dict_out.update({"Tp_"+str(nuc_dicts.index(nuc_dict)):Tp,
                             "volume_shrinks_"+str(nuc_dicts.index(nuc_dict)):volume_shrinks})
            
            S_p=my_Action(Tp)
            dict_out.update({"action_Tp_"+str(nuc_dicts.index(nuc_dict)):S_p*Tp})
            
            m.findAllTransitions(tunnelFromPhase_args={"nuclCriterion":lambda S,T: S/(T+1e-100)-S_p})
            alltrans_Tp=m.TnTrans
            elem=alltrans_Tp[0] ###How many transitions??
            if abs(elem["action"]-S_p*Tp)>1 and abs(elem["Tnuc"]-Tp)>1:
                """check if all transitions indeed finds the same S and T values"""
                m.phases=phases_copy
                continue
            dS_TdT_Tp=misc.derivative(S_profile, x0=Tp, dx=.01, n=1, args=(elem,),order=7)

            
            #-------vevs, energy density and pressure at Tp--------------------------------
            phi_stable_Tp=elem["low_vev"]
            dict_out.update({"s_low_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tp[1],
                             "h_low_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tp[0]})
            
            phi_meta_Tp=elem["high_vev"]
            dict_out.update({"s_high_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tp[1],
                             "h_high_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tp[0]})
            
            Delta_rho_Tp=m.energyDensity(phi_meta_Tp,Tp,include_radiation=True)-m.energyDensity(phi_stable_Tp,Tp,include_radiation=True)
            dict_out.update({"Delta_rho_Tp_"+str(nuc_dicts.index(nuc_dict)): Delta_rho_Tp})
            
            Delta_p_Tp=m.Vtot(phi_meta_Tp,Tp)-m.Vtot(phi_stable_Tp,Tp)
            dict_out.update({"Delta_p_Tp_"+str(nuc_dicts.index(nuc_dict)): Delta_p_Tp})
            
            alpha_Tp=alpha_GW(Tp,Delta_rho_Tp)
            dict_out.update({"alpha_Tp_"+str(nuc_dicts.index(nuc_dict)):alpha_GW(Tp,Delta_rho_Tp)})
            
            beta_Tp=beta_GW(Tp,dS_TdT_Tp)
            dict_out.update({"beta_Tp_"+str(nuc_dicts.index(nuc_dict)):beta_Tp})
            
            xi_Jouguet_Tp=((alpha_Tp*(2+3*alpha_Tp))**0.5+1)/(3**0.5*(1+alpha_Tp))
            dV_Tp = m.Vtot(phi_meta_Tp,Tp)-m.Vtot(phi_stable_Tp,Tp)
            radiationDensity_Tp=np.pi**2/30*g_star(Tp)*Tp**4
            vwall_Tp=(dV_Tp/alpha_Tp/radiationDensity_Tp)**0.5 ##Analytic formula
            dict_out.update({"vwall_Tp_"+str(nuc_dicts.index(nuc_dict)): vwall_Tp,
                             "xi_Jouguet_Tp_"+str(nuc_dicts.index(nuc_dict)):xi_Jouguet_Tp})
            
            my_signal_Tp=GW_signal(Tp*(1+alpha_Tp)**0.25,alpha_Tp,beta_Tp,df.iloc[modi]["vw"])
            peak_vals_Tp=my_signal_Tp.T[my_signal_Tp[1]==max(my_signal_Tp[1])][0] ##Extract values at peak
            f_peak_Tp=peak_vals_Tp[0]
            Omega_peak_Tp=peak_vals_Tp[1]
            dict_out.update({"f_peak_Tp_"+str(nuc_dicts.index(nuc_dict)): f_peak_Tp,
                             "Omega_peak_Tp_"+str(nuc_dicts.index(nuc_dict)):Omega_peak_Tp})
            SNR_Tp=SNR_GW(my_signal_Tp)
            dict_out.update({"SNR_Tp_"+str(nuc_dicts.index(nuc_dict)): SNR_Tp})
            dict_out.update(dict(df[hydrocolumns].iloc[modi]))####Comment out not for BAU

            #-----Fill dictionary------------------------------------------------------------
            print("\n ..........\n Current dictionary is: \n")
            print(dict_out)
        except:
            print("error ocurred")
            m.phases=phases_copy
            continue
# Out:
# -1
# doing (-5, -3)
# Tracing phase starting at x = [246.20000181  89.91373791] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# .........
# /Users/marcoantoniomerchandmedina/opt/anaconda3/envs/cosmoT/lib/python3.6/site-packages/cosmoTransitions/generic_potential_1.py:260: RuntimeWarning: overflow encountered in multiply
#   - 1.5)  + 2*n*m2*Mphys, axis=-1)
# ................................................................................................................................................................................................................
# Tracing phase starting at x = [1.39006376e-06 4.10139407e+01] ; t = 129.149425157976
# Tracing minimum down
# traceMinimum t0 = 129.149
# .........................................................................................................................................................................................................
# Tracing minimum up
# traceMinimum t0 = 129.149
# .................................................................................................................................................
# Tracing phase starting at x = [-8.53895005e-08  3.35565540e+01] ; t = 61.85952732132742
# Tracing minimum down
# traceMinimum t0 = 61.8595
# .................................................................................................................................................................................
# Tracing minimum up
# traceMinimum t0 = 61.8595
# ................
# Tunneling is relevant from phase 1 to 0
# high_vev [3.73049349e-06 3.89048669e+01]
# low_vev [184.42125364  89.36449768]
# max temperature is 118.90724750971269
# min temperature is 62.85968563158796
# Tunneling from phase 1 to phase 0 at T=82.98445
# high_vev = [2.12101959e-06 3.41593578e+01]
# low_vev = [231.96763657  89.86255703]
# Path deformation converged. 46 steps. fRatio = 1.93016e-02
# Path deformation converged. 20 steps. fRatio = 1.90350e-02
# Path deformation converged. 8 steps. fRatio = 1.88308e-02
# Path deformation converged. 6 steps. fRatio = 1.84182e-02
# Path deformation converged. 2 steps. fRatio = 1.96583e-02
# Path deformation converged. 3 steps. fRatio = 1.97328e-02
# Path deformation converged. 3 steps. fRatio = 1.96840e-02
# Path deformation converged. 3 steps. fRatio = 1.97433e-02
# Path deformation converged. 3 steps. fRatio = 1.98390e-02
# Path deformation converged. 3 steps. fRatio = 1.99853e-02
# Path deformation converged. 3 steps. fRatio = 1.96631e-02
# Path deformation converged. 3 steps. fRatio = 1.95788e-02
# Path deformation converged. 3 steps. fRatio = 1.95052e-02
# Path deformation converged. 3 steps. fRatio = 1.92177e-02
# Path deformation converged. 3 steps. fRatio = 1.93650e-02
# Path deformation converged. 3 steps. fRatio = 1.92936e-02
# Path deformation converged. 2 steps. fRatio = 1.98630e-02
# Path deformation converged. 3 steps. fRatio = 1.98309e-02
# Path deformation converged. 3 steps. fRatio = 1.94003e-02
# Path deformation converged. 3 steps. fRatio = 1.91209e-02
# Tunneling from phase 1 to phase 0 at T=96.70574
# high_vev = [4.08368753e-06 3.54257090e+01]
# low_vev = [220.68113906  89.79757821]
# Path deformation converged. 51 steps. fRatio = 1.84459e-02
# Path deformation converged. 11 steps. fRatio = 1.98703e-02
# Path deformation converged. 6 steps. fRatio = 1.75865e-02
# Path deformation converged. 2 steps. fRatio = 1.61738e-02
# Path deformation converged. 2 steps. fRatio = 1.63016e-02
# Path deformation converged. 2 steps. fRatio = 1.63878e-02
# Path deformation converged. 2 steps. fRatio = 1.63579e-02
# Path deformation converged. 2 steps. fRatio = 1.63123e-02
# Path deformation converged. 2 steps. fRatio = 1.62005e-02
# Path deformation converged. 2 steps. fRatio = 1.60389e-02
# Path deformation converged. 2 steps. fRatio = 1.58981e-02
# Path deformation converged. 2 steps. fRatio = 1.57631e-02
# Path deformation converged. 2 steps. fRatio = 1.56352e-02
# Path deformation converged. 2 steps. fRatio = 1.54865e-02
# Path deformation converged. 2 steps. fRatio = 1.52458e-02
# Path deformation converged. 2 steps. fRatio = 1.50984e-02
# Path deformation converged. 2 steps. fRatio = 1.49338e-02
# Path deformation converged. 2 steps. fRatio = 1.48143e-02
# Path deformation converged. 2 steps. fRatio = 1.46821e-02
# Path deformation converged. 2 steps. fRatio = 1.45508e-02
# Tunneling from phase 1 to phase 0 at T=105.186
# high_vev = [3.93204412e-06 3.65573727e+01]
# low_vev = [210.57910014  89.71649078]
# Path deformation converged. 51 steps. fRatio = 1.64448e-02
# Path deformation converged. 16 steps. fRatio = 1.85874e-02
# Path deformation converged. 2 steps. fRatio = 1.96172e-02
# Path deformation converged. 2 steps. fRatio = 1.85447e-02
# Path deformation converged. 2 steps. fRatio = 1.78610e-02
# Path deformation converged. 2 steps. fRatio = 1.72406e-02
# Path deformation converged. 2 steps. fRatio = 1.66259e-02
# Path deformation converged. 2 steps. fRatio = 1.60459e-02
# Path deformation converged. 2 steps. fRatio = 1.55122e-02
# Path deformation converged. 2 steps. fRatio = 1.50161e-02
# Path deformation converged. 2 steps. fRatio = 1.45649e-02
# Path deformation converged. 2 steps. fRatio = 1.41523e-02
# Path deformation converged. 2 steps. fRatio = 1.37611e-02
# Path deformation converged. 2 steps. fRatio = 1.34056e-02
# Path deformation converged. 2 steps. fRatio = 1.30858e-02
# Path deformation converged. 2 steps. fRatio = 1.28132e-02
# Path deformation converged. 2 steps. fRatio = 1.25316e-02
# Path deformation converged. 2 steps. fRatio = 1.22966e-02
# Path deformation converged. 2 steps. fRatio = 1.20799e-02
# Path deformation converged. 2 steps. fRatio = 1.18688e-02
# Tunneling from phase 1 to phase 0 at T=100.9458
# high_vev = [4.31771806e-06 3.59593182e+01]
# low_vev = [216.00958213  89.76307767]
# Path deformation converged. 54 steps. fRatio = 1.92281e-02
# Path deformation converged. 17 steps. fRatio = 1.55927e-02
# Path deformation converged. 2 steps. fRatio = 1.85932e-02
# Path deformation converged. 2 steps. fRatio = 1.80252e-02
# Path deformation converged. 2 steps. fRatio = 1.76713e-02
# Path deformation converged. 2 steps. fRatio = 1.73059e-02
# Path deformation converged. 2 steps. fRatio = 1.69043e-02
# Path deformation converged. 2 steps. fRatio = 1.64987e-02
# Path deformation converged. 2 steps. fRatio = 1.61105e-02
# Path deformation converged. 2 steps. fRatio = 1.57339e-02
# Path deformation converged. 2 steps. fRatio = 1.53836e-02
# Path deformation converged. 2 steps. fRatio = 1.50366e-02
# Path deformation converged. 2 steps. fRatio = 1.47347e-02
# Path deformation converged. 2 steps. fRatio = 1.44290e-02
# Path deformation converged. 2 steps. fRatio = 1.41547e-02
# Path deformation converged. 2 steps. fRatio = 1.39016e-02
# Path deformation converged. 2 steps. fRatio = 1.36655e-02
# Path deformation converged. 2 steps. fRatio = 1.34313e-02
# Path deformation converged. 2 steps. fRatio = 1.32325e-02
# Path deformation converged. 2 steps. fRatio = 1.30322e-02
# Tunneling from phase 1 to phase 0 at T=103.0659
# high_vev = [4.45153297e-06 3.62504183e+01]
# low_vev = [213.39963601  89.74160285]
# Path deformation converged. 51 steps. fRatio = 1.92184e-02
# Path deformation converged. 17 steps. fRatio = 1.69964e-02
# Path deformation converged. 2 steps. fRatio = 1.78570e-02
# Path deformation converged. 2 steps. fRatio = 1.67267e-02
# Path deformation converged. 2 steps. fRatio = 1.64323e-02
# Path deformation converged. 2 steps. fRatio = 1.60966e-02
# Path deformation converged. 2 steps. fRatio = 1.57356e-02
# Path deformation converged. 2 steps. fRatio = 1.53689e-02
# Path deformation converged. 2 steps. fRatio = 1.50066e-02
# Path deformation converged. 2 steps. fRatio = 1.46564e-02
# Path deformation converged. 2 steps. fRatio = 1.43310e-02
# Path deformation converged. 2 steps. fRatio = 1.40255e-02
# Path deformation converged. 2 steps. fRatio = 1.37310e-02
# Path deformation converged. 2 steps. fRatio = 1.34610e-02
# Path deformation converged. 2 steps. fRatio = 1.32004e-02
# Path deformation converged. 2 steps. fRatio = 1.29608e-02
# Path deformation converged. 2 steps. fRatio = 1.27529e-02
# Path deformation converged. 2 steps. fRatio = 1.25486e-02
# Path deformation converged. 2 steps. fRatio = 1.23644e-02
# Path deformation converged. 2 steps. fRatio = 1.21831e-02
# Tunneling from phase 1 to phase 0 at T=104.1259
# high_vev = [4.49072566e-06 3.64019282e+01]
# low_vev = [212.01723162  89.72954862]
# Path deformation converged. 51 steps. fRatio = 1.78100e-02
# Path deformation converged. 16 steps. fRatio = 1.71219e-02
# Path deformation converged. 2 steps. fRatio = 1.72125e-02
# Path deformation converged. 2 steps. fRatio = 1.64091e-02
# Path deformation converged. 2 steps. fRatio = 1.60039e-02
# Path deformation converged. 2 steps. fRatio = 1.55688e-02
# Path deformation converged. 2 steps. fRatio = 1.51448e-02
# Path deformation converged. 2 steps. fRatio = 1.47474e-02
# Path deformation converged. 2 steps. fRatio = 1.43564e-02
# Path deformation converged. 2 steps. fRatio = 1.49026e-02
# Path deformation converged. 2 steps. fRatio = 1.44266e-02
# Path deformation converged. 2 steps. fRatio = 1.40199e-02
# Path deformation converged. 2 steps. fRatio = 1.36596e-02
# Path deformation converged. 2 steps. fRatio = 1.33369e-02
# Path deformation converged. 2 steps. fRatio = 1.30410e-02
# Path deformation converged. 2 steps. fRatio = 1.27562e-02
# Path deformation converged. 2 steps. fRatio = 1.25259e-02
# Path deformation converged. 2 steps. fRatio = 1.22979e-02
# Path deformation converged. 2 steps. fRatio = 1.21039e-02
# Path deformation converged. 2 steps. fRatio = 1.19140e-02
# Tunneling from phase 1 to phase 0 at T=102.2561
# high_vev = [3.01819993e-06 3.61373422e+01]
# low_vev = [214.42012024  89.75019556]
# Path deformation converged. 54 steps. fRatio = 1.89939e-02
# Path deformation converged. 16 steps. fRatio = 1.91278e-02
# Path deformation converged. 4 steps. fRatio = 1.90650e-02
# Path deformation converged. 2 steps. fRatio = 1.77765e-02
# Path deformation converged. 2 steps. fRatio = 1.73228e-02
# Path deformation converged. 2 steps. fRatio = 1.69300e-02
# Path deformation converged. 2 steps. fRatio = 1.64916e-02
# Path deformation converged. 2 steps. fRatio = 1.60507e-02
# Path deformation converged. 2 steps. fRatio = 1.56327e-02
# Path deformation converged. 2 steps. fRatio = 1.52357e-02
# Path deformation converged. 2 steps. fRatio = 1.48570e-02
# Path deformation converged. 2 steps. fRatio = 1.45118e-02
# Path deformation converged. 2 steps. fRatio = 1.41943e-02
# Path deformation converged. 2 steps. fRatio = 1.38884e-02
# Path deformation converged. 2 steps. fRatio = 1.35943e-02
# Path deformation converged. 2 steps. fRatio = 1.33488e-02
# Path deformation converged. 2 steps. fRatio = 1.30967e-02
# Path deformation converged. 2 steps. fRatio = 1.28891e-02
# Path deformation converged. 2 steps. fRatio = 1.26688e-02
# Path deformation converged. 2 steps. fRatio = 1.24752e-02
# Tunneling from phase 1 to phase 0 at T=101.7556
# high_vev = [3.39000545e-06 3.60686230e+01]
# low_vev = [215.03604124  89.75525931]
# Path deformation converged. 51 steps. fRatio = 1.91493e-02
# Path deformation converged. 16 steps. fRatio = 1.93059e-02
# Path deformation converged. 4 steps. fRatio = 1.90735e-02
# Path deformation converged. 2 steps. fRatio = 1.76810e-02
# Path deformation converged. 2 steps. fRatio = 1.72862e-02
# Path deformation converged. 2 steps. fRatio = 1.69038e-02
# Path deformation converged. 2 steps. fRatio = 1.65085e-02
# Path deformation converged. 2 steps. fRatio = 1.61094e-02
# Path deformation converged. 2 steps. fRatio = 1.57278e-02
# Path deformation converged. 2 steps. fRatio = 1.53600e-02
# Path deformation converged. 2 steps. fRatio = 1.49880e-02
# Path deformation converged. 2 steps. fRatio = 1.46645e-02
# Path deformation converged. 2 steps. fRatio = 1.43417e-02
# Path deformation converged. 2 steps. fRatio = 1.40587e-02
# Path deformation converged. 2 steps. fRatio = 1.37824e-02
# Path deformation converged. 2 steps. fRatio = 1.35269e-02
# Path deformation converged. 2 steps. fRatio = 1.32905e-02
# Path deformation converged. 2 steps. fRatio = 1.30701e-02
# Path deformation converged. 2 steps. fRatio = 1.28642e-02
# Path deformation converged. 2 steps. fRatio = 1.26822e-02
# Tunneling from phase 1 to phase 0 at T=101.4463
# high_vev = [3.84223573e-06 3.60265957e+01]
# low_vev = [215.41122081  89.75829927]
# Path deformation converged. 54 steps. fRatio = 1.83270e-02
# Path deformation converged. 16 steps. fRatio = 1.99100e-02
# Path deformation converged. 4 steps. fRatio = 1.92835e-02
# Path deformation converged. 2 steps. fRatio = 1.78948e-02
# Path deformation converged. 2 steps. fRatio = 1.75185e-02
# Path deformation converged. 2 steps. fRatio = 1.71333e-02
# Path deformation converged. 2 steps. fRatio = 1.67348e-02
# Path deformation converged. 2 steps. fRatio = 1.63327e-02
# Path deformation converged. 2 steps. fRatio = 1.59554e-02
# Path deformation converged. 2 steps. fRatio = 1.55730e-02
# Path deformation converged. 2 steps. fRatio = 1.52139e-02
# Path deformation converged. 2 steps. fRatio = 1.48618e-02
# Path deformation converged. 2 steps. fRatio = 1.45594e-02
# Path deformation converged. 2 steps. fRatio = 1.42467e-02
# Path deformation converged. 2 steps. fRatio = 1.39888e-02
# Path deformation converged. 2 steps. fRatio = 1.37318e-02
# Path deformation converged. 2 steps. fRatio = 1.34666e-02
# Path deformation converged. 2 steps. fRatio = 1.32651e-02
# Path deformation converged. 2 steps. fRatio = 1.30460e-02
# Path deformation converged. 2 steps. fRatio = 1.28415e-02
# Tunneling from phase 1 to phase 0 at T=101.2552
# high_vev = [4.54211257e-06 3.60007922e+01]
# low_vev = [215.64102996  89.76014453]
# Path deformation converged. 54 steps. fRatio = 1.85646e-02
# Path deformation converged. 17 steps. fRatio = 1.53594e-02
# Path deformation converged. 2 steps. fRatio = 1.83362e-02
# Path deformation converged. 2 steps. fRatio = 1.78018e-02
# Path deformation converged. 2 steps. fRatio = 1.74193e-02
# Path deformation converged. 2 steps. fRatio = 1.70344e-02
# Path deformation converged. 2 steps. fRatio = 1.66118e-02
# Path deformation converged. 2 steps. fRatio = 1.62177e-02
# Path deformation converged. 2 steps. fRatio = 1.58171e-02
# Path deformation converged. 2 steps. fRatio = 1.54344e-02
# Path deformation converged. 2 steps. fRatio = 1.50816e-02
# Path deformation converged. 2 steps. fRatio = 1.47469e-02
# Path deformation converged. 2 steps. fRatio = 1.44361e-02
# Path deformation converged. 2 steps. fRatio = 1.41534e-02
# Path deformation converged. 2 steps. fRatio = 1.38933e-02
# Path deformation converged. 2 steps. fRatio = 1.36522e-02
# Path deformation converged. 2 steps. fRatio = 1.34103e-02
# Path deformation converged. 2 steps. fRatio = 1.31852e-02
# Path deformation converged. 2 steps. fRatio = 1.29962e-02
# Path deformation converged. 2 steps. fRatio = 1.28153e-02
# Tunneling from phase 1 to phase 0 at T=101.5645
# high_vev = [3.97439970e-06 3.60426075e+01]
# low_vev = [215.26840814  89.75714626]
# Path deformation converged. 53 steps. fRatio = 1.98834e-02
# Path deformation converged. 17 steps. fRatio = 1.52923e-02
# Path deformation converged. 2 steps. fRatio = 1.81257e-02
# Path deformation converged. 2 steps. fRatio = 1.75702e-02
# Path deformation converged. 2 steps. fRatio = 1.72009e-02
# Path deformation converged. 2 steps. fRatio = 1.67970e-02
# Path deformation converged. 2 steps. fRatio = 1.63959e-02
# Path deformation converged. 2 steps. fRatio = 1.59838e-02
# Path deformation converged. 2 steps. fRatio = 1.56041e-02
# Path deformation converged. 2 steps. fRatio = 1.52447e-02
# Path deformation converged. 2 steps. fRatio = 1.48912e-02
# Path deformation converged. 2 steps. fRatio = 1.45755e-02
# Path deformation converged. 2 steps. fRatio = 1.42627e-02
# Path deformation converged. 2 steps. fRatio = 1.39796e-02
# Path deformation converged. 2 steps. fRatio = 1.37158e-02
# Path deformation converged. 2 steps. fRatio = 1.34729e-02
# Path deformation converged. 2 steps. fRatio = 1.32470e-02
# Path deformation converged. 2 steps. fRatio = 1.30363e-02
# Path deformation converged. 2 steps. fRatio = 1.28407e-02
# Path deformation converged. 2 steps. fRatio = 1.26659e-02
# Tunneling from phase 1 to phase 0 at T=101.4614
# high_vev = [4.27450142e-06 3.60286316e+01]
# low_vev = [215.39305395  89.75815268]
# Path deformation converged. 54 steps. fRatio = 1.83107e-02
# Path deformation converged. 16 steps. fRatio = 1.98883e-02
# Path deformation converged. 4 steps. fRatio = 1.92749e-02
# Path deformation converged. 2 steps. fRatio = 1.79036e-02
# Path deformation converged. 2 steps. fRatio = 1.75027e-02
# Path deformation converged. 2 steps. fRatio = 1.71186e-02
# Path deformation converged. 2 steps. fRatio = 1.67400e-02
# Path deformation converged. 2 steps. fRatio = 1.63372e-02
# Path deformation converged. 2 steps. fRatio = 1.59536e-02
# Path deformation converged. 2 steps. fRatio = 1.55761e-02
# Path deformation converged. 2 steps. fRatio = 1.52153e-02
# Path deformation converged. 2 steps. fRatio = 1.48708e-02
# Path deformation converged. 2 steps. fRatio = 1.45627e-02
# Path deformation converged. 2 steps. fRatio = 1.42540e-02
# Path deformation converged. 2 steps. fRatio = 1.39685e-02
# Path deformation converged. 2 steps. fRatio = 1.37286e-02
# Path deformation converged. 2 steps. fRatio = 1.34767e-02
# Path deformation converged. 2 steps. fRatio = 1.32555e-02
# Path deformation converged. 2 steps. fRatio = 1.30547e-02
# Path deformation converged. 2 steps. fRatio = 1.28421e-02
# Tunneling from phase 1 to phase 0 at T=101.4707
# high_vev = [4.08448910e-06 3.60299015e+01]
# low_vev = [215.3817641   89.75806111]
# Path deformation converged. 54 steps. fRatio = 1.82984e-02
# Path deformation converged. 16 steps. fRatio = 1.98775e-02
# Path deformation converged. 4 steps. fRatio = 1.92837e-02
# Path deformation converged. 2 steps. fRatio = 1.78962e-02
# Path deformation converged. 2 steps. fRatio = 1.75144e-02
# Path deformation converged. 2 steps. fRatio = 1.71269e-02
# Path deformation converged. 2 steps. fRatio = 1.67206e-02
# Path deformation converged. 2 steps. fRatio = 1.63382e-02
# Path deformation converged. 2 steps. fRatio = 1.59491e-02
# Path deformation converged. 2 steps. fRatio = 1.55703e-02
# Path deformation converged. 2 steps. fRatio = 1.52150e-02
# Path deformation converged. 2 steps. fRatio = 1.48666e-02
# Path deformation converged. 2 steps. fRatio = 1.45593e-02
# Path deformation converged. 2 steps. fRatio = 1.42455e-02
# Path deformation converged. 2 steps. fRatio = 1.39896e-02
# Path deformation converged. 2 steps. fRatio = 1.37249e-02
# Path deformation converged. 2 steps. fRatio = 1.34708e-02
# Path deformation converged. 2 steps. fRatio = 1.32451e-02
# Path deformation converged. 2 steps. fRatio = 1.30537e-02
# Path deformation converged. 2 steps. fRatio = 1.28541e-02
# Tunneling from phase 1 to phase 0 at T=101.4668
# high_vev = [4.20047304e-06 3.60293649e+01]
# low_vev = [215.38650345  89.75809987]
# Path deformation converged. 54 steps. fRatio = 1.83034e-02
# Path deformation converged. 16 steps. fRatio = 1.98822e-02
# Path deformation converged. 4 steps. fRatio = 1.92735e-02
# Path deformation converged. 2 steps. fRatio = 1.78943e-02
# Path deformation converged. 2 steps. fRatio = 1.75094e-02
# Path deformation converged. 2 steps. fRatio = 1.71287e-02
# Path deformation converged. 2 steps. fRatio = 1.67459e-02
# Path deformation converged. 2 steps. fRatio = 1.63320e-02
# Path deformation converged. 2 steps. fRatio = 1.59386e-02
# Path deformation converged. 2 steps. fRatio = 1.55662e-02
# Path deformation converged. 2 steps. fRatio = 1.52105e-02
# Path deformation converged. 2 steps. fRatio = 1.48823e-02
# Path deformation converged. 2 steps. fRatio = 1.45482e-02
# Path deformation converged. 2 steps. fRatio = 1.42667e-02
# Path deformation converged. 2 steps. fRatio = 1.39846e-02
# Path deformation converged. 2 steps. fRatio = 1.37218e-02
# Path deformation converged. 2 steps. fRatio = 1.34833e-02
# Path deformation converged. 2 steps. fRatio = 1.32620e-02
# Path deformation converged. 2 steps. fRatio = 1.30375e-02
# Path deformation converged. 2 steps. fRatio = 1.28549e-02
# Tunneling from phase 1 to phase 0 at T=101.4696
# high_vev = [4.19489757e-06 3.60297464e+01]
# low_vev = [215.38310473  89.75807247]
# Path deformation converged. 54 steps. fRatio = 1.83000e-02
# Path deformation converged. 16 steps. fRatio = 1.98801e-02
# Path deformation converged. 4 steps. fRatio = 1.92773e-02
# Path deformation converged. 2 steps. fRatio = 1.78919e-02
# Path deformation converged. 2 steps. fRatio = 1.74876e-02
# Path deformation converged. 2 steps. fRatio = 1.71285e-02
# Path deformation converged. 2 steps. fRatio = 1.67338e-02
# Path deformation converged. 2 steps. fRatio = 1.63233e-02
# Path deformation converged. 2 steps. fRatio = 1.59544e-02
# Path deformation converged. 2 steps. fRatio = 1.55698e-02
# Path deformation converged. 2 steps. fRatio = 1.52153e-02
# Path deformation converged. 2 steps. fRatio = 1.48702e-02
# Path deformation converged. 2 steps. fRatio = 1.45531e-02
# Path deformation converged. 2 steps. fRatio = 1.42430e-02
# Path deformation converged. 2 steps. fRatio = 1.39770e-02
# Path deformation converged. 2 steps. fRatio = 1.37166e-02
# Path deformation converged. 2 steps. fRatio = 1.34792e-02
# Path deformation converged. 2 steps. fRatio = 1.32596e-02
# Path deformation converged. 2 steps. fRatio = 1.30544e-02
# Path deformation converged. 2 steps. fRatio = 1.28478e-02
# Tunneling from phase 1 to phase 0 at T=101.471
# high_vev = [4.18399764e-06 3.60299329e+01]
# low_vev = [215.38145933  89.75805857]
# Path deformation converged. 54 steps. fRatio = 1.82967e-02
# Path deformation converged. 16 steps. fRatio = 1.98794e-02
# Path deformation converged. 4 steps. fRatio = 1.92794e-02
# Path deformation converged. 2 steps. fRatio = 1.78933e-02
# Path deformation converged. 2 steps. fRatio = 1.75110e-02
# Path deformation converged. 2 steps. fRatio = 1.71264e-02
# Path deformation converged. 2 steps. fRatio = 1.67303e-02
# Path deformation converged. 2 steps. fRatio = 1.63367e-02
# Path deformation converged. 2 steps. fRatio = 1.59469e-02
# Path deformation converged. 2 steps. fRatio = 1.55718e-02
# Path deformation converged. 2 steps. fRatio = 1.52133e-02
# Path deformation converged. 2 steps. fRatio = 1.48651e-02
# Path deformation converged. 2 steps. fRatio = 1.45610e-02
# Path deformation converged. 2 steps. fRatio = 1.42508e-02
# Path deformation converged. 2 steps. fRatio = 1.39709e-02
# Path deformation converged. 2 steps. fRatio = 1.37105e-02
# Path deformation converged. 2 steps. fRatio = 1.34729e-02
# Path deformation converged. 2 steps. fRatio = 1.32565e-02
# Path deformation converged. 2 steps. fRatio = 1.30524e-02
# Path deformation converged. 2 steps. fRatio = 1.28481e-02
# Tunneling from phase 1 to phase 0 at T=101.5067
# high_vev = [3.57211076e-06 3.60347699e+01]
# low_vev = [215.33832374  89.75771194]
# Path deformation converged. 53 steps. fRatio = 1.99584e-02
# Path deformation converged. 17 steps. fRatio = 1.53487e-02
# Path deformation converged. 2 steps. fRatio = 1.80943e-02
# Path deformation converged. 2 steps. fRatio = 1.75455e-02
# Path deformation converged. 2 steps. fRatio = 1.71729e-02
# Path deformation converged. 2 steps. fRatio = 1.67978e-02
# Path deformation converged. 2 steps. fRatio = 1.63800e-02
# Path deformation converged. 2 steps. fRatio = 1.59971e-02
# Path deformation converged. 2 steps. fRatio = 1.56043e-02
# Path deformation converged. 2 steps. fRatio = 1.52520e-02
# Path deformation converged. 2 steps. fRatio = 1.49045e-02
# Path deformation converged. 2 steps. fRatio = 1.45782e-02
# Path deformation converged. 2 steps. fRatio = 1.42761e-02
# Path deformation converged. 2 steps. fRatio = 1.39817e-02
# Path deformation converged. 2 steps. fRatio = 1.37287e-02
# Path deformation converged. 2 steps. fRatio = 1.34981e-02
# Path deformation converged. 2 steps. fRatio = 1.32606e-02
# Path deformation converged. 2 steps. fRatio = 1.30413e-02
# Path deformation converged. 2 steps. fRatio = 1.28607e-02
# Path deformation converged. 2 steps. fRatio = 1.26842e-02
# Tunneling from phase 1 to phase 0 at T=101.4718
# high_vev = [3.97717262e-06 3.60300461e+01]
# low_vev = [215.38042762  89.75805031]
# Path deformation converged. 54 steps. fRatio = 1.82967e-02
# Path deformation converged. 16 steps. fRatio = 1.98776e-02
# Path deformation converged. 4 steps. fRatio = 1.92701e-02
# Path deformation converged. 2 steps. fRatio = 1.78930e-02
# Path deformation converged. 2 steps. fRatio = 1.75072e-02
# Path deformation converged. 2 steps. fRatio = 1.71213e-02
# Path deformation converged. 2 steps. fRatio = 1.67390e-02
# Path deformation converged. 2 steps. fRatio = 1.63331e-02
# Path deformation converged. 2 steps. fRatio = 1.59422e-02
# Path deformation converged. 2 steps. fRatio = 1.55643e-02
# Path deformation converged. 2 steps. fRatio = 1.52057e-02
# Path deformation converged. 2 steps. fRatio = 1.48744e-02
# Path deformation converged. 2 steps. fRatio = 1.45700e-02
# Path deformation converged. 2 steps. fRatio = 1.42619e-02
# Path deformation converged. 2 steps. fRatio = 1.39823e-02
# Path deformation converged. 2 steps. fRatio = 1.37148e-02
# Path deformation converged. 2 steps. fRatio = 1.34806e-02
# Path deformation converged. 2 steps. fRatio = 1.32669e-02
# Path deformation converged. 2 steps. fRatio = 1.30399e-02
# Path deformation converged. 2 steps. fRatio = 1.28532e-02
# Tunneling from phase 1 to phase 0 at T=101.472
# high_vev = [3.87209533e-06 3.60300727e+01]
# low_vev = [215.38020972  89.75804929]
# Path deformation converged. 54 steps. fRatio = 1.82971e-02
# Path deformation converged. 16 steps. fRatio = 1.98778e-02
# Path deformation converged. 4 steps. fRatio = 1.92679e-02
# Path deformation converged. 2 steps. fRatio = 1.78799e-02
# Path deformation converged. 2 steps. fRatio = 1.74942e-02
# Path deformation converged. 2 steps. fRatio = 1.71289e-02
# Path deformation converged. 2 steps. fRatio = 1.67420e-02
# Path deformation converged. 2 steps. fRatio = 1.63301e-02
# Path deformation converged. 2 steps. fRatio = 1.59292e-02
# Path deformation converged. 2 steps. fRatio = 1.55622e-02
# Path deformation converged. 2 steps. fRatio = 1.52083e-02
# Path deformation converged. 2 steps. fRatio = 1.48771e-02
# Path deformation converged. 2 steps. fRatio = 1.45447e-02
# Path deformation converged. 2 steps. fRatio = 1.42630e-02
# Path deformation converged. 2 steps. fRatio = 1.39839e-02
# Path deformation converged. 2 steps. fRatio = 1.37261e-02
# Path deformation converged. 2 steps. fRatio = 1.34901e-02
# Path deformation converged. 2 steps. fRatio = 1.32455e-02
# Path deformation converged. 2 steps. fRatio = 1.30495e-02
# Path deformation converged. 2 steps. fRatio = 1.28410e-02
# Tunneling from phase 1 to phase 0 at T=101.4853
# high_vev = [4.45209728e-06 3.60318674e+01]
# low_vev = [215.36421764  89.75791961]
# Path deformation converged. 53 steps. fRatio = 1.99857e-02
# Path deformation converged. 17 steps. fRatio = 1.53724e-02
# Path deformation converged. 2 steps. fRatio = 1.80878e-02
# Path deformation converged. 2 steps. fRatio = 1.75451e-02
# Path deformation converged. 2 steps. fRatio = 1.71874e-02
# Path deformation converged. 2 steps. fRatio = 1.67803e-02
# Path deformation converged. 2 steps. fRatio = 1.63790e-02
# Path deformation converged. 2 steps. fRatio = 1.59888e-02
# Path deformation converged. 2 steps. fRatio = 1.56119e-02
# Path deformation converged. 2 steps. fRatio = 1.52582e-02
# Path deformation converged. 2 steps. fRatio = 1.48981e-02
# Path deformation converged. 2 steps. fRatio = 1.45877e-02
# Path deformation converged. 2 steps. fRatio = 1.42766e-02
# Path deformation converged. 2 steps. fRatio = 1.39993e-02
# Path deformation converged. 2 steps. fRatio = 1.37392e-02
# Path deformation converged. 2 steps. fRatio = 1.34804e-02
# Path deformation converged. 2 steps. fRatio = 1.32636e-02
# Path deformation converged. 2 steps. fRatio = 1.30419e-02
# Path deformation converged. 2 steps. fRatio = 1.28567e-02
# Path deformation converged. 2 steps. fRatio = 1.26750e-02
# Tunneling from phase 1 to phase 0 at T=101.4733
# high_vev = [3.73552785e-06 3.60302495e+01]
# low_vev = [215.3786461   89.75803623]
# Path deformation converged. 54 steps. fRatio = 1.82959e-02
# Path deformation converged. 16 steps. fRatio = 1.98753e-02
# Path deformation converged. 4 steps. fRatio = 1.92646e-02
# Path deformation converged. 2 steps. fRatio = 1.78859e-02
# Path deformation converged. 2 steps. fRatio = 1.75027e-02
# Path deformation converged. 2 steps. fRatio = 1.71380e-02
# Path deformation converged. 2 steps. fRatio = 1.67289e-02
# Path deformation converged. 2 steps. fRatio = 1.63286e-02
# Path deformation converged. 2 steps. fRatio = 1.59543e-02
# Path deformation converged. 2 steps. fRatio = 1.55695e-02
# Path deformation converged. 2 steps. fRatio = 1.52132e-02
# Path deformation converged. 2 steps. fRatio = 1.48652e-02
# Path deformation converged. 2 steps. fRatio = 1.45451e-02
# Path deformation converged. 2 steps. fRatio = 1.42548e-02
# Path deformation converged. 2 steps. fRatio = 1.39843e-02
# Path deformation converged. 2 steps. fRatio = 1.37305e-02
# Path deformation converged. 2 steps. fRatio = 1.34674e-02
# Path deformation converged. 2 steps. fRatio = 1.32497e-02
# Path deformation converged. 2 steps. fRatio = 1.30428e-02
# Path deformation converged. 2 steps. fRatio = 1.28629e-02
# Tunneling from phase 1 to phase 0 at T=101.473
# high_vev = [4.07878534e-06 3.60302025e+01]
# low_vev = [215.37907597  89.75804057]
# Path deformation converged. 54 steps. fRatio = 1.82965e-02
# Path deformation converged. 16 steps. fRatio = 1.98739e-02
# Path deformation converged. 4 steps. fRatio = 1.92880e-02
# Path deformation converged. 2 steps. fRatio = 1.78963e-02
# Path deformation converged. 2 steps. fRatio = 1.75114e-02
# Path deformation converged. 2 steps. fRatio = 1.71263e-02
# Path deformation converged. 2 steps. fRatio = 1.67286e-02
# Path deformation converged. 2 steps. fRatio = 1.63253e-02
# Path deformation converged. 2 steps. fRatio = 1.59574e-02
# Path deformation converged. 2 steps. fRatio = 1.55739e-02
# Path deformation converged. 2 steps. fRatio = 1.52129e-02
# Path deformation converged. 2 steps. fRatio = 1.48716e-02
# Path deformation converged. 2 steps. fRatio = 1.45611e-02
# Path deformation converged. 2 steps. fRatio = 1.42572e-02
# Path deformation converged. 2 steps. fRatio = 1.39697e-02
# Path deformation converged. 2 steps. fRatio = 1.37130e-02
# Path deformation converged. 2 steps. fRatio = 1.34781e-02
# Path deformation converged. 2 steps. fRatio = 1.32604e-02
# Path deformation converged. 2 steps. fRatio = 1.30348e-02
# Path deformation converged. 2 steps. fRatio = 1.28521e-02
# Tunneling from phase 1 to phase 0 at T=101.4734
# high_vev = [3.88163054e-06 3.60302546e+01]
# low_vev = [215.3785909   89.75803515]
# Path deformation converged. 54 steps. fRatio = 1.82938e-02
# Path deformation converged. 16 steps. fRatio = 1.98766e-02
# Path deformation converged. 4 steps. fRatio = 1.92635e-02
# Path deformation converged. 2 steps. fRatio = 1.78885e-02
# Path deformation converged. 2 steps. fRatio = 1.75019e-02
# Path deformation converged. 2 steps. fRatio = 1.71430e-02
# Path deformation converged. 2 steps. fRatio = 1.67369e-02
# Path deformation converged. 2 steps. fRatio = 1.63206e-02
# Path deformation converged. 2 steps. fRatio = 1.59547e-02
# Path deformation converged. 2 steps. fRatio = 1.55731e-02
# Path deformation converged. 2 steps. fRatio = 1.52160e-02
# Path deformation converged. 2 steps. fRatio = 1.48687e-02
# Path deformation converged. 2 steps. fRatio = 1.45479e-02
# Path deformation converged. 2 steps. fRatio = 1.42621e-02
# Path deformation converged. 2 steps. fRatio = 1.39837e-02
# Path deformation converged. 2 steps. fRatio = 1.37282e-02
# Path deformation converged. 2 steps. fRatio = 1.34890e-02
# Path deformation converged. 2 steps. fRatio = 1.32644e-02
# Path deformation converged. 2 steps. fRatio = 1.30397e-02
# Path deformation converged. 2 steps. fRatio = 1.28565e-02
# Tunneling from phase 1 to phase 0 at T=101.4779
# high_vev = [4.06505405e-06 3.60308700e+01]
# low_vev = [215.37309984  89.75799091]
# Path deformation converged. 53 steps. fRatio = 1.99966e-02
# Path deformation converged. 17 steps. fRatio = 1.53795e-02
# Path deformation converged. 2 steps. fRatio = 1.80688e-02
# Path deformation converged. 2 steps. fRatio = 1.75199e-02
# Path deformation converged. 2 steps. fRatio = 1.71690e-02
# Path deformation converged. 2 steps. fRatio = 1.67870e-02
# Path deformation converged. 2 steps. fRatio = 1.63879e-02
# Path deformation converged. 2 steps. fRatio = 1.59915e-02
# Path deformation converged. 2 steps. fRatio = 1.56084e-02
# Path deformation converged. 2 steps. fRatio = 1.52521e-02
# Path deformation converged. 2 steps. fRatio = 1.48887e-02
# Path deformation converged. 2 steps. fRatio = 1.45780e-02
# Path deformation converged. 2 steps. fRatio = 1.42737e-02
# Path deformation converged. 2 steps. fRatio = 1.39930e-02
# Path deformation converged. 2 steps. fRatio = 1.37395e-02
# Path deformation converged. 2 steps. fRatio = 1.34973e-02
# Path deformation converged. 2 steps. fRatio = 1.32542e-02
# Path deformation converged. 2 steps. fRatio = 1.30519e-02
# Path deformation converged. 2 steps. fRatio = 1.28464e-02
# Path deformation converged. 2 steps. fRatio = 1.26817e-02
# Tunneling from phase 1 to phase 0 at T=101.4736
# high_vev = [4.28621621e-06 3.60302813e+01]
# low_vev = [215.37835358  89.75803365]
# Path deformation converged. 54 steps. fRatio = 1.82950e-02
# Path deformation converged. 16 steps. fRatio = 1.98759e-02
# Path deformation converged. 4 steps. fRatio = 1.92640e-02
# Path deformation converged. 2 steps. fRatio = 1.78892e-02
# Path deformation converged. 2 steps. fRatio = 1.75036e-02
# Path deformation converged. 2 steps. fRatio = 1.71148e-02
# Path deformation converged. 2 steps. fRatio = 1.67375e-02
# Path deformation converged. 2 steps. fRatio = 1.63301e-02
# Path deformation converged. 2 steps. fRatio = 1.59530e-02
# Path deformation converged. 2 steps. fRatio = 1.55628e-02
# Path deformation converged. 2 steps. fRatio = 1.52071e-02
# Path deformation converged. 2 steps. fRatio = 1.48715e-02
# Path deformation converged. 2 steps. fRatio = 1.45477e-02
# Path deformation converged. 2 steps. fRatio = 1.42526e-02
# Path deformation converged. 2 steps. fRatio = 1.39824e-02
# Path deformation converged. 2 steps. fRatio = 1.37309e-02
# Path deformation converged. 2 steps. fRatio = 1.34676e-02
# Path deformation converged. 2 steps. fRatio = 1.32644e-02
# Path deformation converged. 2 steps. fRatio = 1.30461e-02
# Path deformation converged. 2 steps. fRatio = 1.28407e-02
# Tunneling from phase 1 to phase 0 at T=101.4752
# high_vev = [3.34157180e-06 3.60305036e+01]
# low_vev = [215.37634905  89.75801815]
# Path deformation converged. 54 steps. fRatio = 1.82932e-02
# Path deformation converged. 16 steps. fRatio = 1.98742e-02
# Path deformation converged. 4 steps. fRatio = 1.92603e-02
# Path deformation converged. 2 steps. fRatio = 1.78853e-02
# Path deformation converged. 2 steps. fRatio = 1.74953e-02
# Path deformation converged. 2 steps. fRatio = 1.71119e-02
# Path deformation converged. 2 steps. fRatio = 1.67358e-02
# Path deformation converged. 2 steps. fRatio = 1.63266e-02
# Path deformation converged. 2 steps. fRatio = 1.59356e-02
# Path deformation converged. 2 steps. fRatio = 1.55596e-02
# Path deformation converged. 2 steps. fRatio = 1.52092e-02
# Path deformation converged. 2 steps. fRatio = 1.48768e-02
# Path deformation converged. 2 steps. fRatio = 1.45508e-02
# Path deformation converged. 2 steps. fRatio = 1.42651e-02
# Path deformation converged. 2 steps. fRatio = 1.39842e-02
# Path deformation converged. 2 steps. fRatio = 1.37253e-02
# Path deformation converged. 2 steps. fRatio = 1.34871e-02
# Path deformation converged. 2 steps. fRatio = 1.32492e-02
# Path deformation converged. 2 steps. fRatio = 1.30432e-02
# Path deformation converged. 2 steps. fRatio = 1.28583e-02
# Tunneling from phase 1 to phase 0 at T=101.4743
# high_vev = [3.86750886e-06 3.60303896e+01]
# low_vev = [215.37739698  89.75802651]
# Path deformation converged. 54 steps. fRatio = 1.82940e-02
# Path deformation converged. 16 steps. fRatio = 1.98750e-02
# Path deformation converged. 4 steps. fRatio = 1.92743e-02
# Path deformation converged. 2 steps. fRatio = 1.78949e-02
# Path deformation converged. 2 steps. fRatio = 1.75055e-02
# Path deformation converged. 2 steps. fRatio = 1.71205e-02
# Path deformation converged. 2 steps. fRatio = 1.67166e-02
# Path deformation converged. 2 steps. fRatio = 1.63309e-02
# Path deformation converged. 2 steps. fRatio = 1.59444e-02
# Path deformation converged. 2 steps. fRatio = 1.55697e-02
# Path deformation converged. 2 steps. fRatio = 1.52127e-02
# Path deformation converged. 2 steps. fRatio = 1.48650e-02
# Path deformation converged. 2 steps. fRatio = 1.45505e-02
# Path deformation converged. 2 steps. fRatio = 1.42509e-02
# Path deformation converged. 2 steps. fRatio = 1.39651e-02
# Path deformation converged. 2 steps. fRatio = 1.37321e-02
# Path deformation converged. 2 steps. fRatio = 1.34804e-02
# Path deformation converged. 2 steps. fRatio = 1.32584e-02
# Path deformation converged. 2 steps. fRatio = 1.30399e-02
# Path deformation converged. 2 steps. fRatio = 1.28523e-02
# Tunneling from phase 1 to phase 0 at T=101.4743
# high_vev = [3.97070996e-06 3.60303737e+01]
# low_vev = [215.3775029   89.75802627]
# Path deformation converged. 54 steps. fRatio = 1.82939e-02
# Path deformation converged. 16 steps. fRatio = 1.98747e-02
# Path deformation converged. 4 steps. fRatio = 1.92765e-02
# Path deformation converged. 2 steps. fRatio = 1.78930e-02
# Path deformation converged. 2 steps. fRatio = 1.75087e-02
# Path deformation converged. 2 steps. fRatio = 1.71191e-02
# Path deformation converged. 2 steps. fRatio = 1.67152e-02
# Path deformation converged. 2 steps. fRatio = 1.63326e-02
# Path deformation converged. 2 steps. fRatio = 1.59467e-02
# Path deformation converged. 2 steps. fRatio = 1.55716e-02
# Path deformation converged. 2 steps. fRatio = 1.52118e-02
# Path deformation converged. 2 steps. fRatio = 1.48796e-02
# Path deformation converged. 2 steps. fRatio = 1.45516e-02
# Path deformation converged. 2 steps. fRatio = 1.42416e-02
# Path deformation converged. 2 steps. fRatio = 1.39885e-02
# Path deformation converged. 2 steps. fRatio = 1.37309e-02
# Path deformation converged. 2 steps. fRatio = 1.34702e-02
# Path deformation converged. 2 steps. fRatio = 1.32594e-02
# Path deformation converged. 2 steps. fRatio = 1.30349e-02
# Path deformation converged. 2 steps. fRatio = 1.28539e-02
# Tunneling from phase 1 to phase 0 at T=101.4743
# high_vev = [4.07507678e-06 3.60303834e+01]
# low_vev = [215.37745289  89.75802638]
# Path deformation converged. 54 steps. fRatio = 1.82939e-02
# Path deformation converged. 16 steps. fRatio = 1.98749e-02
# Path deformation converged. 4 steps. fRatio = 1.92754e-02
# Path deformation converged. 2 steps. fRatio = 1.78906e-02
# Path deformation converged. 2 steps. fRatio = 1.75051e-02
# Path deformation converged. 2 steps. fRatio = 1.71206e-02
# Path deformation converged. 2 steps. fRatio = 1.67155e-02
# Path deformation converged. 2 steps. fRatio = 1.63398e-02
# Path deformation converged. 2 steps. fRatio = 1.59409e-02
# Path deformation converged. 2 steps. fRatio = 1.55700e-02
# Path deformation converged. 2 steps. fRatio = 1.52125e-02
# Path deformation converged. 2 steps. fRatio = 1.48816e-02
# Path deformation converged. 2 steps. fRatio = 1.45519e-02
# Path deformation converged. 2 steps. fRatio = 1.42545e-02
# Path deformation converged. 2 steps. fRatio = 1.39642e-02
# Path deformation converged. 2 steps. fRatio = 1.37112e-02
# Path deformation converged. 2 steps. fRatio = 1.34905e-02
# Path deformation converged. 2 steps. fRatio = 1.32573e-02
# Path deformation converged. 2 steps. fRatio = 1.30373e-02
# Path deformation converged. 2 steps. fRatio = 1.28550e-02
# Tunneling from phase 1 to phase 0 at T=101.4747
# high_vev = [4.16010464e-06 3.60304328e+01]
# low_vev = [215.37699456  89.75802283]
# Path deformation converged. 54 steps. fRatio = 1.82934e-02
# Path deformation converged. 16 steps. fRatio = 1.98737e-02
# Path deformation converged. 4 steps. fRatio = 1.92828e-02
# Path deformation converged. 2 steps. fRatio = 1.78998e-02
# Path deformation converged. 2 steps. fRatio = 1.75091e-02
# Path deformation converged. 2 steps. fRatio = 1.71289e-02
# Path deformation converged. 2 steps. fRatio = 1.67271e-02
# Path deformation converged. 2 steps. fRatio = 1.63168e-02
# Path deformation converged. 2 steps. fRatio = 1.59500e-02
# Path deformation converged. 2 steps. fRatio = 1.55739e-02
# Path deformation converged. 2 steps. fRatio = 1.51948e-02
# Path deformation converged. 2 steps. fRatio = 1.48733e-02
# Path deformation converged. 2 steps. fRatio = 1.45664e-02
# Path deformation converged. 2 steps. fRatio = 1.42514e-02
# Path deformation converged. 2 steps. fRatio = 1.39748e-02
# Path deformation converged. 2 steps. fRatio = 1.37128e-02
# Path deformation converged. 2 steps. fRatio = 1.34808e-02
# Path deformation converged. 2 steps. fRatio = 1.32609e-02
# Path deformation converged. 2 steps. fRatio = 1.30450e-02
# Path deformation converged. 2 steps. fRatio = 1.28537e-02
# Tunneling from phase 1 to phase 0 at T=101.4745
# high_vev = [3.88197029e-06 3.60304051e+01]
# low_vev = [215.37724616  89.75802506]
# Path deformation converged. 54 steps. fRatio = 1.82943e-02
# Path deformation converged. 16 steps. fRatio = 1.98722e-02
# Path deformation converged. 4 steps. fRatio = 1.92855e-02
# Path deformation converged. 2 steps. fRatio = 1.78790e-02
# Path deformation converged. 2 steps. fRatio = 1.75199e-02
# Path deformation converged. 2 steps. fRatio = 1.71305e-02
# Path deformation converged. 2 steps. fRatio = 1.67269e-02
# Path deformation converged. 2 steps. fRatio = 1.63388e-02
# Path deformation converged. 2 steps. fRatio = 1.59533e-02
# Path deformation converged. 2 steps. fRatio = 1.55707e-02
# Path deformation converged. 2 steps. fRatio = 1.51984e-02
# Path deformation converged. 2 steps. fRatio = 1.48718e-02
# Path deformation converged. 2 steps. fRatio = 1.45659e-02
# Path deformation converged. 2 steps. fRatio = 1.42481e-02
# Path deformation converged. 2 steps. fRatio = 1.39702e-02
# Path deformation converged. 2 steps. fRatio = 1.37156e-02
# Path deformation converged. 2 steps. fRatio = 1.34762e-02
# Path deformation converged. 2 steps. fRatio = 1.32552e-02
# Path deformation converged. 2 steps. fRatio = 1.30459e-02
# Path deformation converged. 2 steps. fRatio = 1.28500e-02
# Tunneling from phase 1 to phase 0 at T=101.4744
# high_vev = [3.86095547e-06 3.60303948e+01]
# low_vev = [215.37733618  89.75802538]
# Path deformation converged. 54 steps. fRatio = 1.82942e-02
# Path deformation converged. 16 steps. fRatio = 1.98750e-02
# Path deformation converged. 4 steps. fRatio = 1.92723e-02
# Path deformation converged. 2 steps. fRatio = 1.78924e-02
# Path deformation converged. 2 steps. fRatio = 1.75046e-02
# Path deformation converged. 2 steps. fRatio = 1.71228e-02
# Path deformation converged. 2 steps. fRatio = 1.67148e-02
# Path deformation converged. 2 steps. fRatio = 1.63132e-02
# Path deformation converged. 2 steps. fRatio = 1.59505e-02
# Path deformation converged. 2 steps. fRatio = 1.55692e-02
# Path deformation converged. 2 steps. fRatio = 1.52129e-02
# Path deformation converged. 2 steps. fRatio = 1.48799e-02
# Path deformation converged. 2 steps. fRatio = 1.45585e-02
# Path deformation converged. 2 steps. fRatio = 1.42516e-02
# Path deformation converged. 2 steps. fRatio = 1.39632e-02
# Path deformation converged. 2 steps. fRatio = 1.37293e-02
# Path deformation converged. 2 steps. fRatio = 1.34791e-02
# Path deformation converged. 2 steps. fRatio = 1.32458e-02
# Path deformation converged. 2 steps. fRatio = 1.30565e-02
# Path deformation converged. 2 steps. fRatio = 1.28529e-02
# Tunneling from phase 1 to phase 0 at T=101.4744
# high_vev = [3.89205107e-06 3.60303913e+01]
# low_vev = [215.3773747   89.75802672]
# Path deformation converged. 54 steps. fRatio = 1.82940e-02
# Path deformation converged. 16 steps. fRatio = 1.98751e-02
# Path deformation converged. 4 steps. fRatio = 1.92734e-02
# Path deformation converged. 2 steps. fRatio = 1.78906e-02
# Path deformation converged. 2 steps. fRatio = 1.75068e-02
# Path deformation converged. 2 steps. fRatio = 1.71184e-02
# Path deformation converged. 2 steps. fRatio = 1.67150e-02
# Path deformation converged. 2 steps. fRatio = 1.63321e-02
# Path deformation converged. 2 steps. fRatio = 1.59463e-02
# Path deformation converged. 2 steps. fRatio = 1.55681e-02
# Path deformation converged. 2 steps. fRatio = 1.52144e-02
# Path deformation converged. 2 steps. fRatio = 1.48790e-02
# Path deformation converged. 2 steps. fRatio = 1.45516e-02
# Path deformation converged. 2 steps. fRatio = 1.42389e-02
# Path deformation converged. 2 steps. fRatio = 1.39868e-02
# Path deformation converged. 2 steps. fRatio = 1.37151e-02
# Path deformation converged. 2 steps. fRatio = 1.34669e-02
# Path deformation converged. 2 steps. fRatio = 1.32482e-02
# Path deformation converged. 2 steps. fRatio = 1.30382e-02
# Path deformation converged. 2 steps. fRatio = 1.28549e-02
# Tunneling from phase 1 to phase 0 at T=101.4743
# high_vev = [4.20068523e-06 3.60303856e+01]
# low_vev = [215.37742134  89.75802712]
# Path deformation converged. 54 steps. fRatio = 1.82939e-02
# Path deformation converged. 16 steps. fRatio = 1.98750e-02
# Path deformation converged. 4 steps. fRatio = 1.92751e-02
# Path deformation converged. 2 steps. fRatio = 1.78953e-02
# Path deformation converged. 2 steps. fRatio = 1.75075e-02
# Path deformation converged. 2 steps. fRatio = 1.71196e-02
# Path deformation converged. 2 steps. fRatio = 1.67133e-02
# Path deformation converged. 2 steps. fRatio = 1.63319e-02
# Path deformation converged. 2 steps. fRatio = 1.59461e-02
# Path deformation converged. 2 steps. fRatio = 1.55694e-02
# Path deformation converged. 2 steps. fRatio = 1.52115e-02
# Path deformation converged. 2 steps. fRatio = 1.48808e-02
# Path deformation converged. 2 steps. fRatio = 1.45509e-02
# Path deformation converged. 2 steps. fRatio = 1.42417e-02
# Path deformation converged. 2 steps. fRatio = 1.39644e-02
# Path deformation converged. 2 steps. fRatio = 1.37309e-02
# Path deformation converged. 2 steps. fRatio = 1.34797e-02
# Path deformation converged. 2 steps. fRatio = 1.32484e-02
# Path deformation converged. 2 steps. fRatio = 1.30407e-02
# Path deformation converged. 2 steps. fRatio = 1.28554e-02
# Tunneling from phase 1 to phase 0 at T=101.4743
# high_vev = [3.87258302e-06 3.60303859e+01]
# low_vev = [215.37742958  89.75802689]
# Path deformation converged. 54 steps. fRatio = 1.82939e-02
# Path deformation converged. 16 steps. fRatio = 1.98749e-02
# Path deformation converged. 4 steps. fRatio = 1.92740e-02
# Path deformation converged. 2 steps. fRatio = 1.78885e-02
# Path deformation converged. 2 steps. fRatio = 1.75048e-02
# Path deformation converged. 2 steps. fRatio = 1.71266e-02
# Path deformation converged. 2 steps. fRatio = 1.67172e-02
# Path deformation converged. 2 steps. fRatio = 1.63170e-02
# Path deformation converged. 2 steps. fRatio = 1.59446e-02
# Path deformation converged. 2 steps. fRatio = 1.55709e-02
# Path deformation converged. 2 steps. fRatio = 1.52140e-02
# Path deformation converged. 2 steps. fRatio = 1.48651e-02
# Path deformation converged. 2 steps. fRatio = 1.45532e-02
# Path deformation converged. 2 steps. fRatio = 1.42433e-02
# Path deformation converged. 2 steps. fRatio = 1.39899e-02
# Path deformation converged. 2 steps. fRatio = 1.37180e-02
# Path deformation converged. 2 steps. fRatio = 1.34907e-02
# Path deformation converged. 2 steps. fRatio = 1.32520e-02
# Path deformation converged. 2 steps. fRatio = 1.30569e-02
# Path deformation converged. 2 steps. fRatio = 1.28449e-02
# Tunneling from phase 1 to phase 0 at T=101.4743
# high_vev = [3.81376307e-06 3.60303856e+01]
# low_vev = [215.37741505  89.75802579]
# Path deformation converged. 54 steps. fRatio = 1.82940e-02
# Path deformation converged. 16 steps. fRatio = 1.98751e-02
# Path deformation converged. 4 steps. fRatio = 1.92741e-02
# Path deformation converged. 2 steps. fRatio = 1.78916e-02
# Path deformation converged. 2 steps. fRatio = 1.75070e-02
# Path deformation converged. 2 steps. fRatio = 1.71184e-02
# Path deformation converged. 2 steps. fRatio = 1.67145e-02
# Path deformation converged. 2 steps. fRatio = 1.63317e-02
# Path deformation converged. 2 steps. fRatio = 1.59457e-02
# Path deformation converged. 2 steps. fRatio = 1.55696e-02
# Path deformation converged. 2 steps. fRatio = 1.52114e-02
# Path deformation converged. 2 steps. fRatio = 1.48807e-02
# Path deformation converged. 2 steps. fRatio = 1.45514e-02
# Path deformation converged. 2 steps. fRatio = 1.42420e-02
# Path deformation converged. 2 steps. fRatio = 1.39736e-02
# Path deformation converged. 2 steps. fRatio = 1.37297e-02
# Path deformation converged. 2 steps. fRatio = 1.34774e-02
# ...
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Tunneling from phase 1 to phase 0 at T=62.86019
# high_vev = [1.70734978e-08 3.36356234e+01]
# low_vev = [241.34726738  89.89986528]
# Path deformation converged. 47 steps. fRatio = 1.99995e-02
# Path deformation converged. 18 steps. fRatio = 1.82375e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Path deformation converged. 19 steps. fRatio = 1.95624e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Path deformation converged. 16 steps. fRatio = 1.99512e-02
# Path deformation converged. 20 steps. fRatio = 1.99028e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Tunneling from phase 1 to phase 0 at T=95.5048
# high_vev = [3.64173584e-06 3.52865363e+01]
# low_vev = [221.88596515  89.8057047 ]
# Path deformation converged. 51 steps. fRatio = 1.72986e-02
# Path deformation converged. 13 steps. fRatio = 1.96621e-02
# Path deformation converged. 5 steps. fRatio = 1.88825e-02
# Path deformation converged. 2 steps. fRatio = 1.75197e-02
# Path deformation converged. 2 steps. fRatio = 1.75643e-02
# Path deformation converged. 2 steps. fRatio = 1.76009e-02
# Path deformation converged. 2 steps. fRatio = 1.75583e-02
# Path deformation converged. 2 steps. fRatio = 1.74430e-02
# Path deformation converged. 2 steps. fRatio = 1.73173e-02
# Path deformation converged. 2 steps. fRatio = 1.71645e-02
# Path deformation converged. 2 steps. fRatio = 1.69828e-02
# Path deformation converged. 2 steps. fRatio = 1.68117e-02
# Path deformation converged. 2 steps. fRatio = 1.66193e-02
# Path deformation converged. 2 steps. fRatio = 1.64491e-02
# Path deformation converged. 2 steps. fRatio = 1.62601e-02
# Path deformation converged. 2 steps. fRatio = 1.61019e-02
# Path deformation converged. 2 steps. fRatio = 1.59179e-02
# Path deformation converged. 2 steps. fRatio = 1.57698e-02
# Path deformation converged. 2 steps. fRatio = 1.56026e-02
# Path deformation converged. 2 steps. fRatio = 1.54689e-02
# Tunneling from phase 1 to phase 0 at T=111.8271
# high_vev = [6.41874856e-06 3.76181386e+01]
# low_vev = [200.0394212   89.60303511]
# Path deformation converged. 54 steps. fRatio = 1.89885e-02
# Path deformation converged. 13 steps. fRatio = 1.99101e-02
# Path deformation converged. 1 steps. fRatio = 8.23920e-02
# Tunneling from phase 1 to phase 0 at T=96.47448
# high_vev = [4.23699399e-06 3.53984931e+01]
# low_vev = [220.91694894  89.79919316]
# Path deformation converged. 51 steps. fRatio = 1.74835e-02
# Path deformation converged. 13 steps. fRatio = 1.87080e-02
# Path deformation converged. 8 steps. fRatio = 1.92205e-02
# Path deformation converged. 2 steps. fRatio = 1.88125e-02
# Path deformation converged. 2 steps. fRatio = 1.86547e-02
# Path deformation converged. 2 steps. fRatio = 1.84932e-02
# Path deformation converged. 2 steps. fRatio = 1.82174e-02
# Path deformation converged. 2 steps. fRatio = 1.79337e-02
# Path deformation converged. 2 steps. fRatio = 1.76590e-02
# Path deformation converged. 2 steps. fRatio = 1.73630e-02
# Path deformation converged. 2 steps. fRatio = 1.70629e-02
# Path deformation converged. 2 steps. fRatio = 1.67745e-02
# Path deformation converged. 2 steps. fRatio = 1.65262e-02
# Path deformation converged. 2 steps. fRatio = 1.62720e-02
# Path deformation converged. 2 steps. fRatio = 1.60679e-02
# Path deformation converged. 2 steps. fRatio = 1.58537e-02
# Path deformation converged. 2 steps. fRatio = 1.56365e-02
# Path deformation converged. 2 steps. fRatio = 1.54462e-02
# Path deformation converged. 2 steps. fRatio = 1.52664e-02
# Path deformation converged. 2 steps. fRatio = 1.50940e-02
# Tunneling from phase 1 to phase 0 at T=99.01821
# high_vev = [3.96133681e-06 3.57086251e+01]
# low_vev = [218.21829617  89.77999849]
# Path deformation converged. 51 steps. fRatio = 1.78301e-02
# Path deformation converged. 17 steps. fRatio = 1.67672e-02
# Path deformation converged. 3 steps. fRatio = 1.99853e-02
# Path deformation converged. 2 steps. fRatio = 1.91926e-02
# Path deformation converged. 2 steps. fRatio = 1.88472e-02
# Path deformation converged. 2 steps. fRatio = 1.84570e-02
# Path deformation converged. 2 steps. fRatio = 1.80749e-02
# Path deformation converged. 2 steps. fRatio = 1.76751e-02
# Path deformation converged. 2 steps. fRatio = 1.72795e-02
# Path deformation converged. 2 steps. fRatio = 1.68886e-02
# Path deformation converged. 2 steps. fRatio = 1.65140e-02
# Path deformation converged. 2 steps. fRatio = 1.61781e-02
# Path deformation converged. 2 steps. fRatio = 1.58554e-02
# Path deformation converged. 2 steps. fRatio = 1.55566e-02
# Path deformation converged. 2 steps. fRatio = 1.52537e-02
# Path deformation converged. 2 steps. fRatio = 1.49827e-02
# Path deformation converged. 2 steps. fRatio = 1.47518e-02
# Path deformation converged. 2 steps. fRatio = 1.45157e-02
# Path deformation converged. 2 steps. fRatio = 1.42981e-02
# Path deformation converged. 2 steps. fRatio = 1.40961e-02
# Tunneling from phase 1 to phase 0 at T=99.30891
# high_vev = [4.08911641e-06 3.57455728e+01]
# low_vev = [217.89462788  89.77758853]
# Path deformation converged. 51 steps. fRatio = 1.90015e-02
# Path deformation converged. 16 steps. fRatio = 1.73543e-02
# Path deformation converged. 4 steps. fRatio = 1.96540e-02
# Path deformation converged. 2 steps. fRatio = 1.84687e-02
# Path deformation converged. 2 steps. fRatio = 1.81708e-02
# Path deformation converged. 2 steps. fRatio = 1.78397e-02
# Path deformation converged. 2 steps. fRatio = 1.75052e-02
# Path deformation converged. 2 steps. fRatio = 1.71536e-02
# Path deformation converged. 2 steps. fRatio = 1.67885e-02
# Path deformation converged. 2 steps. fRatio = 1.64560e-02
# Path deformation converged. 2 steps. fRatio = 1.61260e-02
# Path deformation converged. 2 steps. fRatio = 1.58164e-02
# Path deformation converged. 2 steps. fRatio = 1.55254e-02
# Path deformation converged. 2 steps. fRatio = 1.52485e-02
# Path deformation converged. 2 steps. fRatio = 1.49777e-02
# Path deformation converged. 2 steps. fRatio = 1.47451e-02
# Path deformation converged. 2 steps. fRatio = 1.45137e-02
# Path deformation converged. 2 steps. fRatio = 1.42948e-02
# Path deformation converged. 2 steps. fRatio = 1.40928e-02
# Path deformation converged. 2 steps. fRatio = 1.39051e-02
# Tunneling from phase 1 to phase 0 at T=99.32796
# high_vev = [4.02549977e-06 3.57480019e+01]
# low_vev = [217.87331259  89.77742903]
# Path deformation converged. 51 steps. fRatio = 1.89886e-02
# Path deformation converged. 16 steps. fRatio = 1.73284e-02
# Path deformation converged. 4 steps. fRatio = 1.94650e-02
# Path deformation converged. 2 steps. fRatio = 1.85702e-02
# Path deformation converged. 2 steps. fRatio = 1.82488e-02
# Path deformation converged. 2 steps. fRatio = 1.79283e-02
# Path deformation converged. 2 steps. fRatio = 1.75678e-02
# Path deformation converged. 2 steps. fRatio = 1.72090e-02
# Path deformation converged. 2 steps. fRatio = 1.68584e-02
# Path deformation converged. 2 steps. fRatio = 1.64979e-02
# Path deformation converged. 2 steps. fRatio = 1.61677e-02
# Path deformation converged. 2 steps. fRatio = 1.58533e-02
# Path deformation converged. 2 steps. fRatio = 1.55572e-02
# Path deformation converged. 2 steps. fRatio = 1.52536e-02
# Path deformation converged. 2 steps. fRatio = 1.49932e-02
# Path deformation converged. 2 steps. fRatio = 1.47562e-02
# Path deformation converged. 2 steps. fRatio = 1.45147e-02
# Path deformation converged. 2 steps. fRatio = 1.42927e-02
# Path deformation converged. 2 steps. fRatio = 1.40879e-02
# Path deformation converged. 2 steps. fRatio = 1.38950e-02
# Tunneling from phase 1 to phase 0 at T=99.32847
# high_vev = [4.07617908e-06 3.57480696e+01]
# low_vev = [217.87273809  89.77742562]
# Path deformation converged. 51 steps. fRatio = 1.89907e-02
# Path deformation converged. 16 steps. fRatio = 1.73323e-02
# Path deformation converged. 4 steps. fRatio = 1.94559e-02
# Path deformation converged. 2 steps. fRatio = 1.85513e-02
# Path deformation converged. 2 steps. fRatio = 1.82516e-02
# Path deformation converged. 2 steps. fRatio = 1.79127e-02
# Path deformation converged. 2 steps. fRatio = 1.75696e-02
# Path deformation converged. 2 steps. fRatio = 1.71949e-02
# Path deformation converged. 2 steps. fRatio = 1.68437e-02
# Path deformation converged. 2 steps. fRatio = 1.64856e-02
# Path deformation converged. 2 steps. fRatio = 1.61724e-02
# Path deformation converged. 2 steps. fRatio = 1.58433e-02
# Path deformation converged. 2 steps. fRatio = 1.55442e-02
# Path deformation converged. 2 steps. fRatio = 1.52604e-02
# Path deformation converged. 2 steps. fRatio = 1.50030e-02
# Path deformation converged. 2 steps. fRatio = 1.47435e-02
# Path deformation converged. 2 steps. fRatio = 1.45035e-02
# Path deformation converged. 2 steps. fRatio = 1.43004e-02
# Path deformation converged. 2 steps. fRatio = 1.40933e-02
# Path deformation converged. 2 steps. fRatio = 1.39020e-02
#
#  ..........
#  Current dictionary is:
#
# {'ms': 468.9372894907104, 'theta': 0.0007790391283424017, 'u': 89.91373817155652, 'muhs': -655.8700955736117, 'mu3': 677.6488485142712, 'yt': 0.9915178727762072, 'lamh': 0.12907511859003615, 'lams': 3.695840079026444, 'lammix': 7.287248819407041, 'muh2': -21691.10621218125, 'mus2': -31268.84755760216, 'Pih': 0.6984513316910521, 'Pis': 2.1385014896577843, 'lamh_tilde': -3.463071336644164, 'Lam_CP': 685.9336453027445, 'th_bool': True, 'isEWSB': False, 'edm_Bool': True, 'num_FOPT': 1, 'Tc_0': 118.90724750971269, 'Tmin_0': 60.78193334607271, 'Tnuc_0': 101.4743311337999, 'action_Tn_0': 15295.78923030148, 'h_low_Tnuc_0': 215.37756166644724, 's_low_Tnuc_0': 89.75802721230977, 'h_high_Tnuc_0': 3.879393458223877e-06, 's_high_Tnuc_0': 36.03037130327669, 'Delta_rho_Tnuc_0': 61320073.90750733, 'Delta_p_Tnuc_0': 22849152.539099455, 'alpha_Tnuc_0': 0.01725477811749181, 'beta_Tnuc_0': 883.2627464814185, 'vwall_0': 0.6104269703242264, 'xi_Jouguet_0': 0.6743465749045187, 'f_peak_Tnuc_0': 0.008015894192303568, 'Omega_peak_Tnuc_0': 3.077844584548443e-17, 'SNR_Tnuc_0': 0.0006156559673737794, 'Tp_0': 99.3283820394339, 'volume_shrinks_0': True, 'action_Tp_0': 13356.510715353934, 's_low_Tp_0': 89.77742561955111, 'h_low_Tp_0': 217.87273808534775, 's_high_Tp_0': 35.74806955992206, 'h_high_Tp_0': 4.076179075701311e-06, 'Delta_rho_Tp_0': 62867328.03446916, 'Delta_p_Tp_0': 25641705.56709087, 'alpha_Tp_0': 0.019305906392105887, 'beta_Tp_0': 637.7938940346721, 'vwall_Tp_0': 0.638647112976978, 'xi_Jouguet_Tp_0': 0.6793151097968263, 'f_peak_Tp_0': 0.008442347639983097, 'Omega_peak_Tp_0': 6.984633650969382e-16, 'SNR_Tp_0': 0.01293590805818664, 'vw': 0.6722948691854073, 'Lh': 0.03632949419262154, 'dh': 0.0, 'h0': 186.17893856384623, 'Ls': 0.03632945020943367, 'ds': -0.999999999999999, 'shigh': 38.60543948163557, 'slow': 89.43565923700817, 'Type': 'Hybrid', 'alpha_p': 0.009827089535920128, 'vm': 0.5773502691896258, 'vp': 0.4909902123621112, 'xi_s': 0.6732763064200605, 'Tp/TN': 1.1726483988585437, 'vel_converged': True}

# %%
nuc_dicts
# Out:
# [{'Tmin': 60.78193334607271,
#   'Tmax': 118.90724750971269,
#   'high_phase': 1,
#   'low_phase': 0}]

# %%
dict_out
# Out:
# {'ms': 468.9372894907104,
#  'theta': 0.0007790391283424017,
#  'u': 89.91373817155652,
#  'muhs': -655.8700955736117,
#  'mu3': 677.6488485142712,
#  'yt': 0.9915178727762072,
#  'lamh': 0.12907511859003615,
#  'lams': 3.695840079026444,
#  'lammix': 7.287248819407041,
#  'muh2': -21691.10621218125,
#  'mus2': -31268.84755760216,
#  'Pih': 0.6984513316910521,
#  'Pis': 2.1385014896577843,
#  'lamh_tilde': -3.463071336644164,
#  'Lam_CP': 685.9336453027445,
#  'th_bool': True,
#  'isEWSB': False,
#  'edm_Bool': True,
#  'num_FOPT': 1,
#  'Tc_0': 118.90724750971269,
#  'Tmin_0': 60.78193334607271,
#  'Tnuc_0': 101.4743311337999,
#  'action_Tn_0': 15295.78923030148,
#  'h_low_Tnuc_0': 215.37756166644724,
#  's_low_Tnuc_0': 89.75802721230977,
#  'h_high_Tnuc_0': 3.879393458223877e-06,
#  's_high_Tnuc_0': 36.03037130327669,
#  'Delta_rho_Tnuc_0': 61320073.90750733,
#  'Delta_p_Tnuc_0': 22849152.539099455,
#  'alpha_Tnuc_0': 0.01725477811749181,
#  'beta_Tnuc_0': 883.2627464814185,
#  'vwall_0': 0.6104269703242264,
#  'xi_Jouguet_0': 0.6743465749045187,
#  'f_peak_Tnuc_0': 0.008015894192303568,
#  'Omega_peak_Tnuc_0': 3.077844584548443e-17,
#  'SNR_Tnuc_0': 0.0006156559673737794,
#  'Tp_0': 99.3283820394339,
#  'volume_shrinks_0': True,
#  'action_Tp_0': 13356.510715353934,
#  's_low_Tp_0': 89.77742561955111,
#  'h_low_Tp_0': 217.87273808534775,
#  's_high_Tp_0': 35.74806955992206,
#  'h_high_Tp_0': 4.076179075701311e-06,
#  'Delta_rho_Tp_0': 62867328.03446916,
#  'Delta_p_Tp_0': 25641705.56709087,
#  'alpha_Tp_0': 0.019305906392105887,
#  'beta_Tp_0': 637.7938940346721,
#  'vwall_Tp_0': 0.638647112976978,
#  'xi_Jouguet_Tp_0': 0.6793151097968263,
#  'f_peak_Tp_0': 0.008442347639983097,
#  'Omega_peak_Tp_0': 6.984633650969382e-16,
#  'SNR_Tp_0': 0.01293590805818664,
#  'vw': 0.6722948691854073,
#  'Lh': 0.03632949419262154,
#  'dh': 0.0,
#  'h0': 186.17893856384623,
#  'Ls': 0.03632945020943367,
#  'ds': -0.999999999999999,
#  'shigh': 38.60543948163557,
#  'slow': 89.43565923700817,
#  'Type': 'Hybrid',
#  'alpha_p': 0.009827089535920128,
#  'vm': 0.5773502691896258,
#  'vp': 0.4909902123621112,
#  'xi_s': 0.6732763064200605,
#  'Tp/TN': 1.1726483988585437,
#  'vel_converged': True}

# %%
###Obtained from 
#df=pd.read_csv("SCANS/BAU/Z2_breaking_sols_BAU_All.csv",index_col=[0]).sort_values("alpha_max").drop_duplicates()
#df=df[df.num_FOPT>1]


Temp, alpha, beta, vel=dict_out["Tp_0"],dict_out["alpha_Tp_0"],dict_out["beta_Tp_0"],df.iloc[modi].vw
my_signal=GW_signal(Temp, alpha, beta, vel)
SNR=SNR_GW(my_signal)
Temp, alpha, beta, vel1=dict_out["Tp_0"],dict_out["alpha_Tp_0"],dict_out["beta_Tp_0"],1
my_signal_1=GW_signal(Temp, alpha, beta, vel1)
SNR_1=SNR_GW(my_signal_1)

thick_size=16
label_size=20

plt.plot(my_signal[0],my_signal[1],
         label= "SNR="+str(np.round(SNR,2))+", $v_w=$" +str(np.round(vel,2)))
plt.plot(my_signal_1[0],my_signal_1[1],linestyle="--",
         label="SNR="+str(np.round(SNR_1,2))+ ", $v_w=$"+str(np.round(vel1,2)))
plt.plot(LISA_curve.f,LISA_curve.Omega_lim,alpha=0.05,color="g")
plt.fill_between(LISA_curve.f, LISA_curve.Omega_lim, 1e-2, alpha=0.05,color="g")
plt.figtext(.5, .72, "LISA", fontsize=label_size)

plt.xlabel("$f$ (Hz)",size=label_size)
plt.ylabel("$\\Omega_{SW}$",size=label_size)
plt.xscale("log")
plt.yscale("log")           
plt.xticks(fontsize=thick_size)
plt.yticks(fontsize=thick_size)
plt.grid(True)
plt.legend(loc="lower left",prop={'size': label_size})
#plt.title("Benchmark P2",size=label_size)



#plt.legend(prop={'size': label_size})
plt.tight_layout()
#plt.savefig('SCANS/bubble_PLOTS/GW_spectum_P2.pdf', dpi=300)
plt.show()

# %%
df=pd.read_csv("SCANS/BAU/Z2_breaking_sols_BAU_All.csv",index_col=[0])
df=df.sort_values("alpha_max").drop_duplicates()
df=df[-3:-1:]
hydrocolumns=['vw', 'Lh', 'dh', 'h0', 'Ls', 'ds', 'shigh', 'slow',
            'Type', 'alpha_p', 'vm', 'vp', 'xi_s', 'Tp/TN']

df[hydrocolumns]
# Out:
#            vw        Lh   dh          h0        Ls        ds       shigh  \
# 430  0.713273  0.036556  0.0  219.210927  0.031297  0.345047  162.088603
# 431  0.713756  0.035020  0.0  213.909737  0.035020  0.010920  246.198479
#
#            slow    Type   alpha_p       vm        vp      xi_s     Tp/TN
# 430  198.027926  Hybrid  0.016493  0.57735  0.463557  0.713961  1.251347
# 431  305.900453  Hybrid  0.016652  0.57735  0.462971  0.714491  1.252538
