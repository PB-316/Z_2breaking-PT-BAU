# %%
import numpy as np
from cosmoTransitions import generic_potential_1
import matplotlib.pyplot as plt
import pandas as pd
from scipy import optimize
import scipy.integrate as integrate
import random
from scipy import interpolate, special
import seaborn as sns
from scipy import misc


# %config InlineBackend.figure_format = 'retina'
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams["figure.figsize"] = (8, 6)  #set default figure size



####Some definitions##
v2 = 246.2**2
mh=125.09
v=246.2
alpha=1/137
sinthw=np.sqrt(0.223)
g1=np.sqrt(4*np.pi*alpha/(1-sinthw**2))
g=np.sqrt(4*np.pi*alpha)/sinthw
Mplanck=2.4*10**18
cs=1/3**0.5 ##Sound speed constant


####This code uses an interpoaltion function for the number of degrees of freedom as function of temperature
###Data is obtained from https://member.ipmu.jp/satoshi.shirai/EOS2018
data = np.loadtxt( 'satoshi_dof.dat' )[500:3900]
Temperature_d=(data.T)[0]
dof_d=(data.T)[1]#relativistic degrees of freedom  
dof_s=(data.T)[3]#entropic degrees of freedom
g_star = interpolate.interp1d(Temperature_d, dof_d, kind='cubic')
g_star_s = interpolate.interp1d(Temperature_d, dof_s, kind='cubic')


class model1(generic_potential_1.generic_potential):
    def init(self, ms = 50, theta = 0, muhs = 0, u = 100, mu3 = 0,Lam=500):
        self.Lam=Lam
        self.yt=1/(1+u**2/Lam**2)**.5
        self.Ndim = 2
        self.renormScaleSq = v2
        self.ms = ms
        self.theta = theta
        self.muhs = muhs
        self.u = u
        self.mu3 = mu3
        self.lamh = 1/(4*v2)*(mh**2+self.ms**2 + (mh**2 - ms**2)*np.cos(2*self.theta))
        #self.lams = 1/(2*self.u**2)*(mh**2*np.sin(self.theta)**2+self.ms**2*np.cos(self.theta)**2 + self.mu3*self.u + self.muhs*v**2/(2*self.u))
        self.lams = 1/(4*self.u**3)*(mh**2*self.u + ms**2*self.u + 2*self.u**2*self.mu3 + v**2*self.muhs - (mh**2-ms**2)*self.u*np.cos(2*self.theta))
        self.lammix = 1/(v*self.u)*(-(self.ms**2-mh**2)*np.sin(self.theta)*np.cos(self.theta) - self.muhs*v)
        self.muh2 = self.lamh*v2 + self.muhs*self.u + self.lammix/2*self.u**2
        self.mus2 = -self.mu3*self.u + self.lams*self.u**2 + self.muhs*v2/(2*self.u) + self.lammix/2*v2

    def forbidPhaseCrit(self, X):
        return any([np.array([X])[...,0] < -5.0])
        #return any([np.array([X])[...,0] < -5.0, np.array([X])[...,1] < -5.0])

    def V0(self, X):
        X = np.asanyarray(X)
        h, s = X[...,0], X[...,1]
        pot = -1/2*self.muh2*h**2 + 1/4*self.lamh*h**4 - 1/2*self.mus2*s**2 - 1/3*self.mu3*s**3 + 1/4*self.lams*s**4 + 1/2*self.muhs*h**2*s + 1/4*self.lammix*h**2*s**2
        return pot

    def boson_massSq(self, X, T):
        X = np.array(X)
        h, s = X[...,0], X[...,1]

       #####Scalar thermal masses, obtained from appendix of 1702.06124
        Pi_h = T**2*(g1**2/16 + 3*g**2/16 + self.lamh/2 + self.yt**2/4 + self.lammix/24)
        Pi_s= T**2*(self.lammix/6 + self.lams/4)

        ##Scalar mass matrix##
        a=3*h**2*self.lamh + s**2*self.lammix/2 - self.muh2 + s*self.muhs + Pi_h
        b=h**2*self.lammix/2 + 3*s**2*self.lams - 2*s*self.mu3 - self.mus2 + Pi_s
        cc=h*s*self.lammix  + h*self.muhs
        A=(a+b)/2
        B=1/2*np.sqrt((a-b)**2+4*cc**2)
        m1=A+B
        m2=A-B

        ####Gauge boson masses (Longitudinal)
        mWL = g**2*h**2/4 + 11/6*g**2*T**2
        ag=g**2*h**2/4 + 11/6*g**2*T**2
        bg=1/4*g1**2*h**2 + 11/6*g1**2*T**2
        ccg=-1/4*g1*g*h**2
        Ag=(ag+bg)/2
        Bg=1/2*np.sqrt((ag-bg)**2+4*ccg**2)
        mZL=Ag+Bg
        mPh=Ag-Bg


        M = np.array([m1,m2,g**2*h**2/4,h**2/4*(g**2+g1**2),mWL,mZL])
        if self.ms<mh:
            Mphys = np.array([mh**2,self.ms**2,g**2*v**2/4,v**2/4*(g**2+g1**2),g**2*v**2/4,v**2/4*(g**2+g1**2)])
        else:
            Mphys = np.array([self.ms**2,mh**2,g**2*v**2/4,v**2/4*(g**2+g1**2),g**2*v**2/4,v**2/4*(g**2+g1**2)])

        # At this point, we have an array of boson masses, but each entry might
        # be an array itself. This happens if the input X is an array of points.
        # The generic_potential class requires that the output of this function
        # have the different masses lie along the last axis, just like the
        # different fields lie along the last axis of X, so we need to reorder
        # the axes. The next line does this, and should probably be included in
        # all subclasses.
        M = np.rollaxis(M, 0, len(M.shape))
        Mphys = np.rollaxis(Mphys, 0, len(Mphys.shape))

        # The number of degrees of freedom for the masses. This should be a
        # one-dimensional array with the same number of entries as there are
        # masses.

        dof = np.array([1,1,4,2 , 2,1]) ##Longitudinal at the end


        # c is a constant for each particle used in the Coleman-Weinberg
        # potential using MS-bar renormalization. It equals 1.5 for all scalars
        # and the longitudinal polarizations of the gauge bosons, and 0.5 for
        # transverse gauge bosons.
        #c = np.array([1.5,1.5,1.5,1.5,1.5,1.5,1.5])
        c = np.array([1.5,1.5,1.5,1.5,1.5,1.5])

        return M, dof, c, Mphys

   


    def fermion_massSq(self, X):
        X = np.array(X)
        h,s = X[...,0], X[...,1]
        mt=self.yt**2*h**2/2*(1+s**2/self.Lam**2)
        #mt=self.yt**2*h**2/2
        M = np.array([mt])
        Mphys = np.array([v**2/2])

        # At this point, we have an array of boson masses, but each entry might
        # be an array itself. This happens if the input X is an array of points.
        # The generic_potential class requires that the output of this function
        # have the different masses lie along the last axis, just like the
        # different fields lie along the last axis of X, so we need to reorder
        # the axes. The next line does this, and should probably be included in
        # all subclasses.
        M = np.rollaxis(M, 0, len(M.shape))
        Mphys = np.rollaxis(Mphys, 0, len(Mphys.shape))

        dof = np.array([12])
        return M, dof, Mphys


    def approxZeroTMin(self):
        # There are generically two minima at zero temperature in this model,
        # and we want to include both of them.

        return [np.array([v,self.u])]

    def theory_consistent(self):
        perturbative_limit=4*np.pi
        perturbativity=self.lamh<=perturbative_limit and self.lams<=perturbative_limit and abs(self.lammix)<=perturbative_limit
        positivity=(self.lamh>0) and (self.lams>0) and (self.lammix>-2*(self.lamh*self.lams)**.5)
        if perturbativity and positivity:
            #print("Model is theoretically consistent \n")
            return True
        else:
            #print("Model is NOT theoretically consistent \n")
            return False


    def print_couplings(self):
        print("Potential parameters are given by \n ")
        print("mus2=",self.mus2, "muh2=",self.muh2,"lamh=",self.lamh,"lams=",self.lams,"lammix=",self.lammix,"\n")
        print("Model parameters are \n")
        print("ms=",self.ms,"theta=",self.theta,"muhs=",self.muhs,"u=",self.u,"mu3=",self.mu3,"\n")

    def isEWSB(self):
        """Method to find the deepest minima of the potential at T=0.
        Doesn't work for Z_2 symmetric potential!!!"""
        n=100
        X_EW=np.array([v,self.u])
        minima=[]
        if self.muhs==0 and self.mu3==0:
            #print("Model has a Z2 symmetry in the potential \n")
            #print("isEWSB=True \n")
            return True,X_EW
        #------------
        X0=self.findMinimum([0,100],0)
        if self.Vtot(X0,0)<=self.Vtot(X_EW,0) and abs(abs(X0[0])-v)>10 and abs(self.Vtot(X0,0)-self.Vtot(X_EW,0))>1:
            #print("Global minimum found at X=",X0,"\n")
            #print("isEWSB=False \n")
            return False, X0
        X0=self.findMinimum([0,-100],0)
        if self.Vtot(X0,0)<=self.Vtot(X_EW,0) and abs(abs(X0[0])-v)>10 and abs(self.Vtot(X0,0)-self.Vtot(X_EW,0))>1:
            #print("Global minimum found at X=",X0,"\n")
            #print("isEWSB=False \n")
            return False, X0
         
        ###This loop search for a global minima randomly
        for i in range(n):
            x1=np.random.uniform(-100,4*self.Tmax)
            x2=np.random.uniform(-4*self.Tmax,4*self.Tmax)
            X0=self.findMinimum([x1,x2], T=0.0)
            if self.Vtot(X0,0)<=self.Vtot(X_EW,0) and abs(X0[0])-v>10 and abs(self.Vtot(X0,0)-self.Vtot(X_EW,0))>1e2:
                #print("Global minimum found at X=",X0,"\n")
                #print("isEWSB=False \n")
                return False, X0
        #print("isEWSB=True \n")
        return True,X_EW


#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTION
#######HERE ARE MY OWN FUNCTIONS#######HERE ARE MY OWN FUNCTIONS
#######HERE ARE MY OWN FUNCTIONS

def g_loop(z):
    """Loop integral for EDM. Extracted from (A.2) of 1712.09613"""
    g_integrand=lambda x: np.log(x*(1-x)/z)/(x*(1-x)-z)
    integral=integrate.quad(g_integrand,0,1)[0]
    return z*0.5*integral


def d_eEDM(X):
    X=np.array(X)
    theta,ms,Lam=X[...,0],X[...,1],X[...,2]
    G_f=1/2**.5/v**2
    ee=g1
    me=0.5*1e-3
    mt=172.9
    alpha=1/137
    numeric=ee/3/np.pi**2*alpha*G_f*v/2**.5/np.pi/mt*me*(v/2**.5/Lam)
    out=np.sin(theta)*np.cos(theta)*(-g_loop(mt**2/mh**2) + g_loop(mt**2/ms**2))
    return np.abs(numeric*out)

d_eEDM_bound=1.89*10**(-16) 

def alpha_GW(Tnuc,Drho):
    ####This code gives the parameter alpha relevant for stochastic GW spectrum
    ##AS APPEAR IN FORMULA (8.2) OF 1912.12634
    num_dof=g_star(Tnuc)
    radiationDensity=np.pi**2/30*num_dof*Tnuc**4
    latentHeat=Drho
    return latentHeat/radiationDensity


def trans_class(SymNR):
    """Classify the transition according to the following characteristics:
    ---------
    phi-sym: transition happens in the s-field direction
    phi-symNR: transition happens in the s-field direction (symmetry is not restored at T=1000)
    """
    SNR="sym"
    if SymNR==True:
        SNR="SNR"

    if dh>10 and ds>10:
        return "hs-"+SNR
    elif dh>10 and ds<1:
        return "h-"+SNR
    elif ds>10 and dh<1:
        return "s-"+SNR
    else:
        return "none"+SNR

def beta_GW(Tnuc,dS_TdT):
    ###This code defines the parameter beta relevant for stochastic GW spectrum
    beta=Tnuc*dS_TdT
    return beta

def S_profile(T,elem):
    """This function calculates the Euclidean action from a model m at temperature T
    after knowing its phase history. If more than one FOPT is found it uses "elem" from the list. 
    """
    profile=elem["instanton"].profile1D
    alpha_ode=2
    temp=T
    r, phi, dphi, phivector = profile.R, profile.Phi, profile.dPhi, elem["instanton"].Phi
    phi_meta=elem["high_vev"]
    # Find the area of an n-sphere (alpha=n):
    d = alpha_ode+1  # Number of dimensions in the integration
    area = r**alpha_ode * 2*np.pi**(d*.5)/special.gamma(d*.5) ##4 pi r^2 the surface of a sphere
    # And integrate the profile
    integrand = 0.5 * dphi**2 + m.Vtot(phivector,temp) - m.Vtot(phi_meta,temp)
    integrand *= area
    S = integrate.simps(integrand, r)
    # Find the bulk term in the bubble interior
    volume = r[0]**d * np.pi**(d*.5)/special.gamma(d*.5 + 1)
    S += volume * (m.Vtot(phivector[0],temp) - m.Vtot(phi_meta,temp))

    return S/T

#####
def my_getPhases(m):
    myexps=[(-5,-3),(-5,-5),(-5,-4),(-3,-3)]
    for nord in myexps:
        print("doing",nord)
        try:
            m.getPhases(tracingArgs={"dtstart":10**(nord[0]), "tjump":10**(nord[1])})
            phases_out=m.phases
        except:
            phases_out={}
        finally:
            if len(phases_out)>1:
                break
    return phases_out




##DEFINE Nucleation FUNCTION (TO BE OPTIMIZED)
def nucleation_temp(T):
    """DEFINE Nucleation FUNCTION (TO BE OPTIMIZED)
    """
    from cosmoTransitions import transitionFinder as tf
    try:
        S=tf._tunnelFromPhaseAtT(T=T, phases=m.phases, start_phase=m.phases[nuc_dict["high_phase"]], V=m.Vtot, 
                                 dV=m.gradV,phitol=1e-15, overlapAngle=45, nuclCriterion=lambda S,T: Gamma_Hubble4(S,T)-Hubble_total(T)**4,
                                 fullTunneling_params={}, verbose=True, outdict={})
    except:
        return 1e+100
    
    if np.isnan(S):
        return 1e+100
    else:
        return S**2
    
def Hubble_vacuum(T):
    """Hubble parameter for matter density alone. Second term in formula 2.6 of 1809.08242 """
    if m.phases is None:
        phases_dict=m.getPhases()
    else:
        phases_dict=m.phases
    if T<nuc_dict["Tmin"] or T>nuc_dict["Tmax"]:
        return 0
    from cosmoTransitions import transitionFinder as tf
    crit_temps=tf.findCriticalTemperatures(phases_dict, m.Vtot)
    Delta_V=0.0
    for tran_barrier in crit_temps:
        if tran_barrier["trantype"] ==2:
            continue
        ###LOOKS FOR TWO-STEP TRANSITIONS
        #elif T>tran_barrier["Tcrit"] or ((abs(tran_barrier["high_vev"][0]-tran_barrier["low_vev"][0])<1) and (abs(tran_barrier["high_vev"][1]-tran_barrier["low_vev"][1])<1)):
        elif T>tran_barrier["Tcrit"]: ##This is redundant
            continue
        else:
            V_high=m.Vtot(phases_dict[tran_barrier["high_phase"]].valAt(T),T)
            V_low=m.Vtot(phases_dict[tran_barrier["low_phase"]].valAt(T),T)
            if V_high>V_low: 
                Delta_V += V_high - V_low

    return (Delta_V/3)**0.5/Mplanck

def Hubble_radiation(T):
    num_dof=g_star(T)
    Hubble_rad_squared=num_dof*np.pi**2/90*T**4/Mplanck**2
    return Hubble_rad_squared**.5

def Hubble_total(T):
    num_dof=g_star(T)
    Hubble_rad_squared=num_dof*np.pi**2/90*T**4/Mplanck**2
    return (Hubble_rad_squared+Hubble_vacuum(T)**2)**0.5


def Gamma_Hubble4(S,T):
    """Nucleation probability per Hubble volume, including matter contribution. 
    Integrand in formula (2.2) 1809.08242 """
    Gamma1=T**4*np.exp(-S/T)*np.sqrt((S/2/np.pi/T))**3
    return Gamma1

##DEFINE ACTION FUNCTION
def my_Action(T):
    """Calculates S/T at T"""
    from cosmoTransitions import transitionFinder as tf
    try:
        S=tf._tunnelFromPhaseAtT(T=T, phases=m.phases, start_phase=m.phases[nuc_dict["high_phase"]], V=m.Vtot, 
                             dV=m.gradV, phitol=1e-15, overlapAngle=45, nuclCriterion=lambda S,T: S/T ,
                             fullTunneling_params={}, verbose=True, outdict={})
    except:
        S=np.inf
    return S



####This codes the GW signal and SNR given T,alpha, beta and vw. 
LISA_data = np.loadtxt( 'PLS_ESACallv1-2_04yr.txt' )
LISA_data=LISA_data[::20]
LISA_noise=LISA_data[::,0::2]
LISA_data=LISA_data[::,0::3]


def GW_signal_old(Temp,alpha,beta,vel):
    f_redshift=1.65*10**(-5)*(Temp/100)*(g_star(Temp)/100)**(1/6)
    Omega_redshift=1.67*10**(-5)*(100/g_star(Temp))**(1/3)
    kappa_sw=alpha/(0.73+0.083*alpha**0.5+alpha)
    Uf=(3/4*alpha/(1+alpha)*kappa_sw)**0.5
    HR=(8*np.pi)**(1/3)*max(vel,cs)/beta
    HRb=(vel-cs)/vel*HR
    Htau_sw=HR/Uf
    S_fun=lambda s:s**3*(7/(4+3*s**2))**(7/2)
    Omega_sw=3*0.687*Omega_redshift*(1-1/(1+2*HR/Uf)**0.5)*(kappa_sw*alpha/(1+alpha))**2*0.012*HR/cs
    f_sw=f_redshift*(2.6/1.65)*(1/HR)
    GW_tab=[Omega_sw*S_fun(f/f_sw) for f in LISA_noise[::,0]]
    return np.array([LISA_noise[::,0],GW_tab])

def SNR_GW_old(Temp,alpha,beta,vel):
    time=4
    f_redshift=1.65*10**(-5)*(Temp/100)*(g_star(Temp)/100)**(1/6)
    Omega_redshift=1.67*10**(-5)*(100/g_star(Temp))**(1/3)
    kappa_sw=alpha/(0.73+0.083*alpha**0.5+alpha)
    Uf=(3/4*alpha/(1+alpha)*kappa_sw)**0.5
    HR=(8*np.pi)**(1/3)*max(vel,cs)/beta
    HRb=(vel-cs)/vel*HR
    Htau_sw=HR/Uf
    S_fun=lambda s:s**3*(7/(4+3*s**2))**(7/2)
    Omega_sw=3*0.687*Omega_redshift*(1-1/(1+2*HR/Uf)**0.5)*(kappa_sw*alpha/(1+alpha))**2*0.012*HR/cs
    f_sw=f_redshift*(2.6/1.65)*(1/HR)
    integral=np.sum([(LISA_noise[i+1][0]-LISA_noise[i][0])/2*(Omega_sw*S_fun(LISA_noise[i][0]/f_sw)/(LISA_noise[i][1]))**2 for i in range(0,len(LISA_noise)-1)])
    return (time*3.15*10**7*integral)**0.5


def r_comoving(T,T1):
    """Comoving size of a bubble nucleated at T' after growing until T"""
    vw=1
    T_range=np.linspace(T,T1)
    T_half=(T_range[1:]+T_range[:-1])/2
    T_diff=(T_range[1:]-T_range[:-1])
    Hubble_range=[1/Hubble_total(Temp) for Temp in T_half]
    integral=np.sum(np.array(Hubble_range)*T_diff)
    return vw*integral

def Gamma(T):
    """This function gives the nucleation rate at finite temperature """
    try:
        S_action=my_Action(T)*T
    except:
        S_action=np.inf
    if S_action==np.inf:
        return 0
    Gamma1=T**4*np.exp(-S_action/T)*np.sqrt((S_action/2/np.pi/T))**3
    return Gamma1


def I_volume_fraction_integrand(T,T1):
    """For given temperatures T1>T, it calculates the integrand of the volume fraction.
    Includes the factor 4pi/3."""
    if T>T1:
        print("incorrect setting of temperatures")
        return 
    Gam=Gamma(T1)/Hubble_total(T1)/T1**4
    if Gam==0:
        return 0
    r_vol=r_comoving(T,T1)
    if r_vol==0:
        return 0
    output=Gam*r_vol**3
    return 4*np.pi/3*output

def I_volume_fraction(T,vw):
    """For given temperature T. It calculates the volume fraction doing the integral of I_volume_fraction_integrand
    starting from T until the critial temperature found by nucleation_temp ("Tmax")"""
    n=20 ###This number should be changed on a case by case basis
    t_range=np.linspace(T,nuc_dict["Tmax"],n)
    I_list=[]
    for tempi in t_range:
        x=I_volume_fraction_integrand(T,tempi)
        I_list.append(x)
    fun_inter=interpolate.interp1d(t_range,I_list)
    result = integrate.quad(lambda Tx: fun_inter(Tx),t_range[0], t_range[-1])
    return vw**3*result[0]-0.34




def kappa(xi_w,alpha):
    """
    Fit for the efficiency factor 
    """
    c_s         = 1./np.sqrt(3.)
    #kappa_A     = xi_w**1.2 * 6.9*alpha/(1.39-0.0037*np.sqrt(alpha)+alpha)
    kappa_A     = xi_w**1.2 * 6.9*alpha/(1.36-0.037*np.sqrt(alpha)+alpha)
    #kappa_B     = alpha**0.4/(0.0017+(0.997+alpha)**0.4)
    kappa_B     = alpha**0.4/(0.017+(0.997+alpha)**0.4)
    #kappa_C     = np.sqrt(alpha)/(0.135+np.sqrt(0.98)+alpha)
    kappa_C     = np.sqrt(alpha)/(0.135+np.sqrt(0.98+alpha))
    #kappa_D     = alpha/(0.75+0.085*np.sqrt(alpha)+alpha)
    kappa_D     = alpha/(0.73 + 0.083*np.sqrt(alpha)+alpha)
    delta_kappa = -0.9*np.log(np.sqrt(alpha)/(1.+np.sqrt(alpha)))
    xi_w_J      = (np.sqrt(2./3.*alpha+alpha**2)+1./np.sqrt(3.))/(1.+alpha)

    if xi_w < c_s:
    # deflagration
        return c_s**2.2 * kappa_A * kappa_B / ( (c_s**2.2 - xi_w**2.2 )*kappa_B + xi_w * c_s**1.2 * kappa_A )
    elif xi_w < xi_w_J:
    # hybrid
        return (
            kappa_B
            + (xi_w -c_s)*delta_kappa
            + (xi_w-c_s)**3/(xi_w_J-c_s)**3 * ( kappa_C - kappa_B - (xi_w_J-c_s)*delta_kappa )
        )
    #else:
    # detonation
    return (xi_w_J-1.)**3 * (xi_w_J/xi_w)**2.5 * kappa_C * kappa_D / (
        ( (xi_w_J-1.)**3 - (xi_w-1.)**3 ) * xi_w_J**2.5 * kappa_C
        + (xi_w-1.)**3 * kappa_D
    )




def T_percolation(n,vw):
    """Having Tnuc it computes the percolation temperature using I=0.34 as optimization criteria."""
    t_range=np.linspace(nuc_dict["Tmin"],Tnuc,n)[::-1]
    I_list=[]
    t_range_1=[]
    for temp in t_range:
        x=I_volume_fraction(temp,vw)
        I_list.append(x)
        t_range_1.append(temp)
        if x>10:
            break
    fun_inter=interpolate.interp1d(t_range_1,I_list)
    def f_opt(t): 
        try: 
            return fun_inter(t)**2 
        except: 
            return 1e+100
    Tp = optimize.fmin(f_opt,(t_range_1[0]+t_range_1[-1])*0.5,xtol=0.0001)[0]
    volume_shrinks=Tp*misc.derivative(fun_inter, x0=Tp, dx=1e-5, n=1)<-3
    print("The physical volunme diminishes at Tp:",volume_shrinks)
    plt.plot(t_range_1,fun_inter(t_range_1))
    plt.ylim(-1,1)
    plt.axhline(y=0)
    plt.xlabel("$T (GeV)$")
    plt.title("$I(T)-0.34$")
    plt.show()
    return Tp,volume_shrinks


LISA_curve=pd.read_csv("LISA_integrated_curve.csv",index_col=[0])
def GW_signal(Temp,alpha,beta,vel):
    HR=(8*np.pi)**(1/3)*max(vel,cs)/beta ##eqn. (7.5)
    f_sw=2.6*1e-5/HR*(Temp/100)*(g_star(Temp)/100)**(1/6) ##eqn. (7.3)
    Sw = lambda f: (f/f_sw)**3*(4/7 + 3/7*(f/f_sw)**2)**(-7/2) ##eqn. (7.2)
    Uf=np.sqrt(3/4*alpha/(1+alpha)*kappa(vel,alpha))##eqn. (7.4)
    tauH = HR/Uf ##eqn. (7.4)
    prefactor=4.13*1e-7*HR*(1-1/np.sqrt(1+2*tauH))*(kappa(vel,alpha)*alpha/(1+alpha))**2 ##eqn. (7.1)
    Omega=lambda f: prefactor*(100/g_star(Temp))**(1/3)*Sw(f) ##eqn. (7.1)
    f_range=LISA_curve.f
    GW_tab=[Omega(f) for f in f_range]
    return np.array([list(f_range), list(GW_tab)])

def SNR_GW(signal):
    """Computes SNR given signal (f,Omega)"""
    time=4
    f,Om=signal
    Om=np.array(Om)
    On=np.array(LISA_curve.Omega_noise)
    integral=integrate.simps(Om**2/On**2,f)
    return (time*3.15*10**7*integral)**0.5


def find_nucleation(m):
    """Find min and max temperatures to search for nucleation. IT will be used by bisection method.
    Parameters
        ----------
        m: a model instance. In this case m=model1(kk=1/600**2) for example.
    Returns
        -------
        nuc_dict: a dictionary containing the relevant temperatures and phases indexes. 
                It will be used by the other methods to find the nucleation and percolation parameters  
    """
    if m.phases is None:
        try:
            #phases_dict=m.getPhases()
            #phases_dict=m.getPhases(tracingArgs={"dtstart":1e-3, "tjump":1e-3})
            #phases_dict=m.getPhases(tracingArgs={"dtstart":1e-5, "tjump":1e-4})
            phases_dict=my_getPhases(m)
        except:
            return {}
    else:
        phases_dict=m.phases
    if len(phases_dict)<=1:
        return {}
    from cosmoTransitions import transitionFinder as tf
    crit_temps=tf.findCriticalTemperatures(phases_dict, m.Vtot)
    Num_relevant_trans=0
    ###DETERMINE IF THERE COULD BE TWO-STEP FOPTs
    my_dicts=[]
    for elem in crit_temps:
        if elem["trantype"]==1 and (abs(elem["low_vev"][0]-elem["high_vev"][0])>10 or abs(elem["low_vev"][1]-elem["high_vev"][1])>10):
            print("Tunneling is relevant from phase " + str(elem["high_phase"])+ " to " + str(elem["low_phase"])  )
            Tmax=elem["Tcrit"]
            Tmin=phases_dict[elem["high_phase"]].T[0]
            print("high_vev", elem["high_vev"])
            print("low_vev", elem["low_vev"])
            print("max temperature is", Tmax)
            print("min temperature is", Tmin)
            Num_relevant_trans+=1
            high_phase_key=elem["high_phase"]
            low_phase_key=elem["low_phase"]
            dict_output= {"Tmin":Tmin, "Tmax":Tmax, "high_phase": high_phase_key,"low_phase": low_phase_key}
            #my_dicts.append(dict_output)   
            
            X0=m.phases[dict_output["high_phase"]].X[0]
            T0=m.phases[dict_output["high_phase"]].T[0]
            stable=not np.any(np.linalg.eig(m.d2V(X0,T0))[0]<=0)
            
            def findminT(T):
                """Function to find the minimum temperature at which the high_vev coexists. 
                Written in form for optimization"""
                Xmin=m.findMinimum(X0,T)
                dx=np.sum((Xmin-X0)**2)**0.5
                stable=not np.any(np.linalg.eig(m.d2V(Xmin,T))[0]<=0)
                if stable==False or (dx<1) == False or T<0:
                    return 5000
                else:
                    return  T
            Tmin_opt=optimize.fminbound(findminT,0,T0) 
            dict_output["Tmin"]=Tmin_opt
            my_dicts.append(dict_output)   
        else: 
            continue
        
    return my_dicts

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Compute the transition of model(s)

# %%
def findTnuc():
    """Finds the nucleation temperature and checks if it actually satisfies the condition Gamma/H^4==1"""
    fun_nucleation=lambda T: (Gamma(T)/Hubble_total(T)**4-1.)**4
    if nuc_dict["Tmin"]<1:
        Tnuc=optimize.fminbound(fun_nucleation,np.mean([nuc_dict["Tmin"]+1e-3,nuc_dict["Tmax"]]),nuc_dict["Tmax"])
    else:
        Tnuc=optimize.fminbound(fun_nucleation,nuc_dict["Tmin"]+1e-3,nuc_dict["Tmax"])   
    S_nuc=my_Action(Tnuc)
    check_nucleation=abs(Gamma_Hubble4(S_nuc*Tnuc,Tnuc)/Hubble_total(Tnuc)**4-1)<1e-3
    if check_nucleation==True:
        return Tnuc, S_nuc, True
    else:
        Tnuc=optimize.fminbound(nucleation_temp,nuc_dict["Tmin"],nuc_dict["Tmax"])
    S_nuc=my_Action(Tnuc)
    check_nucleation=abs(Gamma_Hubble4(S_nuc*Tnuc,Tnuc)/Hubble_total(Tnuc)**4-1)<1e-3
    if check_nucleation==True:
        return Tnuc, S_nuc, True
    else:
        return None, None, False

# %%
df=pd.read_csv("SCANS/BAU/sols_fullmodel_All.csv",index_col=[0])
df=df[df["vel_converged"]==True]
df=df[df.Lam_CP>df.ms]
df=df[df.Lam_CP>v]
df=df[df.Lam_CP>abs(df.mu3)]
df=df[df.Lam_CP>abs(df.muhs)]
df=df.sort_values("alpha_max")

dict(df.iloc[1]).keys()
# Out:
# dict_keys(['ms', 'theta', 'u', 'muhs', 'mu3', 'yt', 'lamh', 'lams', 'lammix', 'muh2', 'mus2', 'Pih', 'Pis', 'lamh_tilde', 'Lam_CP', 'th_bool', 'isEWSB', 'edm_Bool', 'h_low_0', 's_low_0', 'h_high_0', 's_high_0', 'Tnuc_0', 'dT_0', 'alpha_0', 'vwf_0', 'xi_J_0', 'v_calculable_0', 'num_FOPT', 'alpha_max', 'dT_max', 'tran_type', 'h_low_1', 's_low_1', 'h_high_1', 's_high_1', 'Tnuc_1', 'dT_1', 'alpha_1', 'vwf_1', 'xi_J_1', 'v_calculable_1', 'vw', 'Lh', 'dh', 'h0', 'Ls', 'ds', 'shigh', 'slow', 'Type', 'alpha_p', 'vm', 'vp', 'xi_s', 'Tp/TN', 'vel_converged', 'Tc', 'LT', 'eta_BAU', 'h_low_2', 's_low_2', 'h_high_2', 's_high_2', 'Tnuc_2', 'dT_2', 'alpha_2', 'vwf_2', 'xi_J_2', 'v_calculable_2'])

# %%
df=pd.read_csv("SCANS/BAU/sols_fullmodel_All.csv",index_col=[0])
df=df[df["vel_converged"]==True]
df=df[df.Lam_CP>df.ms]
df=df[df.Lam_CP>v]
df=df[df.Lam_CP>abs(df.mu3)]
df=df[df.Lam_CP>abs(df.muhs)]
df=df.sort_values("alpha_max")

hydrocolumns=['vw', 'Lh', 'dh', 'h0', 'Ls', 'ds', 'shigh', 'slow',
              'Type', 'alpha_p', 'vm', 'vp', 'xi_s', 'Tp/TN', 'vel_converged']

modi=np.random.randint(0,len(df))
modi=-1
print(modi)


num_points=1
for l in range(num_points):
    ms_val=df.iloc[modi]["ms"]
    theta_val=df.iloc[modi]["theta"]
    u_val=df.iloc[modi]["u"]
    mu3_val=df.iloc[modi]["mu3"]
    muhs_val=df.iloc[modi]["muhs"]
    Lam_val=df.iloc[modi]["Lam_CP"]
    m=model1(ms = ms_val, theta = theta_val,muhs= muhs_val ,u = u_val,mu3 = mu3_val,Lam=Lam_val)

    edm_Bool=d_eEDM([m.theta,m.ms,m.Lam])<d_eEDM_bound
    thbool=m.theory_consistent()
    EWSBbool=m.isEWSB()
    EWSB_new=EWSBbool[0]==True  or (sum(EWSBbool[1]**2)**.5>Mplanck)
    if not (edm_Bool==True and thbool==True and EWSB_new):
        break
    Pih=g1**2/16 + 3*g**2/16 + m.lamh/2 + m.yt**2/4 + m.lammix/24
    Pis=m.lammix/6 + m.lams/4
    lamh_tilde=m.lamh - m.lammix**2/4/m.lams
    dict_out={'ms':m.ms,'theta':m.theta, 'u':m.u,"muhs":m.muhs,"mu3":m.mu3,"yt":m.yt,
          "lamh":m.lamh,"lams":m.lams,"lammix":m.lammix,
          "muh2":m.muh2,"mus2":m.mus2,
          "Pih":Pih,"Pis":Pis,"lamh_tilde":lamh_tilde,"Lam_CP":m.Lam}
    dict_out.update({ "th_bool":thbool,"isEWSB": EWSBbool[0],"edm_Bool":edm_Bool})
     
    nuc_dicts=find_nucleation(m)
    phases_copy=m.phases.copy()
    if len(nuc_dicts)==0:
        continue
    else:
        num_dicts=len(nuc_dicts)
    dict_out.update({"num_FOPT":num_dicts})    

    for nuc_dict in nuc_dicts: 
        try:
            ###Parameters at nucleation temperature------------------------------------------------------------
            dict_out.update({"Tc_"+str(nuc_dicts.index(nuc_dict)):nuc_dict["Tmax"],
                             "Tmin_"+str(nuc_dicts.index(nuc_dict)):nuc_dict["Tmin"]})
            
            relevant_phases={nuc_dict["high_phase"]:m.phases[nuc_dict["high_phase"]],nuc_dict["low_phase"]:m.phases[nuc_dict["low_phase"]]}
            m.phases=relevant_phases
            nucleation= findTnuc()
            if nucleation[2]==False:
                m.phases=phases_copy
                continue
            else:
                Tnuc, S_nuc = nucleation[0], nucleation[1]
                dict_out.update({'Tnuc_'+str(nuc_dicts.index(nuc_dict)): Tnuc})
                dict_out.update({"action_Tn_"+str(nuc_dicts.index(nuc_dict)):S_nuc*Tnuc})
                

            m.findAllTransitions(tunnelFromPhase_args={"nuclCriterion":lambda S,T: S/(T+1e-100)-S_nuc})
            alltrans_Tnuc=m.TnTrans
            elem=alltrans_Tnuc[0] ###How many transitions??
            if abs(elem["action"]-S_nuc*Tnuc)>1 and abs(elem["Tnuc"]-Tnuc)>1:
                """check if all transitions indeed find the same S and T values"""
                m.phases=phases_copy
                continue
            dS_TdT_Tnuc=misc.derivative(S_profile, x0=Tnuc, dx=.01, n=1, args=(elem,),order=7)
            
            #--------vevs, energy density, pressure and wall velocity at Tnuc---------------------------------------------------------
            phi_stable_Tnuc=elem["low_vev"]
            dict_out.update({"h_low_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tnuc[0],
                             "s_low_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tnuc[1]})
            
            phi_meta_Tnuc=elem["high_vev"]
            dict_out.update({"h_high_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tnuc[0],
                             "s_high_Tnuc_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tnuc[1]})
            
            Delta_rho_Tnuc=m.energyDensity(phi_meta_Tnuc,Tnuc,include_radiation=True)-m.energyDensity(phi_stable_Tnuc,Tnuc,include_radiation=True)
            dict_out.update({"Delta_rho_Tnuc_"+str(nuc_dicts.index(nuc_dict)): Delta_rho_Tnuc})
            
            Delta_p_Tnuc=m.Vtot(phi_meta_Tnuc,Tnuc)-m.Vtot(phi_stable_Tnuc,Tnuc)
            dict_out.update({"Delta_p_Tnuc_"+str(nuc_dicts.index(nuc_dict)): Delta_p_Tnuc})
            
            alpha_Tnuc=alpha_GW(Tnuc,Delta_rho_Tnuc)
            dict_out.update({"alpha_Tnuc_"+str(nuc_dicts.index(nuc_dict)):alpha_Tnuc})
            
            beta_Tnuc=beta_GW(Tnuc,dS_TdT_Tnuc)
            dict_out.update({"beta_Tnuc_"+str(nuc_dicts.index(nuc_dict)):beta_Tnuc})
            
            xi_Jouguet=((alpha_Tnuc*(2+3*alpha_Tnuc))**0.5+1)/(3**0.5*(1+alpha_Tnuc))
            dV = m.Vtot(phi_meta_Tnuc,Tnuc)-m.Vtot(phi_stable_Tnuc,Tnuc)
            radiationDensity=np.pi**2/30*g_star(Tnuc)*Tnuc**4
            vwall=(dV/alpha_Tnuc/radiationDensity)**0.5 ##Analytic formula
            dict_out.update({"vwall_"+str(nuc_dicts.index(nuc_dict)): vwall,
                             "xi_Jouguet_"+str(nuc_dicts.index(nuc_dict)):xi_Jouguet}) 
            
            my_signal_Tnuc=GW_signal(Tnuc*(1+alpha_Tnuc)**0.25,alpha_Tnuc,beta_Tnuc,1)
            peak_vals_Tnuc=my_signal_Tnuc.T[my_signal_Tnuc[1]==max(my_signal_Tnuc[1])][0] ##Extract values at peak
            f_peak_Tnuc=peak_vals_Tnuc[0]
            Omega_peak_Tnuc=peak_vals_Tnuc[1]
            dict_out.update({"f_peak_Tnuc_"+str(nuc_dicts.index(nuc_dict)): f_peak_Tnuc,
                        "Omega_peak_Tnuc_"+str(nuc_dicts.index(nuc_dict)):Omega_peak_Tnuc})
            SNR_Tnuc=SNR_GW(my_signal_Tnuc)
            dict_out.update({"SNR_Tnuc_"+str(nuc_dicts.index(nuc_dict)): SNR_Tnuc})
            
            ##Parameters at PERCOLATION temperature Tp-------------------------------------- 
            Tp,volume_shrinks=T_percolation(20,df.iloc[modi]["vw"])
            dict_out.update({"Tp_"+str(nuc_dicts.index(nuc_dict)):Tp,
                             "volume_shrinks_"+str(nuc_dicts.index(nuc_dict)):volume_shrinks})
            
            S_p=my_Action(Tp)
            dict_out.update({"action_Tp_"+str(nuc_dicts.index(nuc_dict)):S_p*Tp})
            
            m.findAllTransitions(tunnelFromPhase_args={"nuclCriterion":lambda S,T: S/(T+1e-100)-S_p})
            alltrans_Tp=m.TnTrans
            elem=alltrans_Tp[0] ###How many transitions??
            if abs(elem["action"]-S_p*Tp)>1 and abs(elem["Tnuc"]-Tp)>1:
                """check if all transitions indeed finds the same S and T values"""
                m.phases=phases_copy
                continue
            dS_TdT_Tp=misc.derivative(S_profile, x0=Tp, dx=.01, n=1, args=(elem,),order=7)

            
            #-------vevs, energy density and pressure at Tp--------------------------------
            phi_stable_Tp=elem["low_vev"]
            dict_out.update({"s_low_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tp[1],
                             "h_low_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_stable_Tp[0]})
            
            phi_meta_Tp=elem["high_vev"]
            dict_out.update({"s_high_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tp[1],
                             "h_high_Tp_"+str(nuc_dicts.index(nuc_dict)):phi_meta_Tp[0]})
            
            Delta_rho_Tp=m.energyDensity(phi_meta_Tp,Tp,include_radiation=True)-m.energyDensity(phi_stable_Tp,Tp,include_radiation=True)
            dict_out.update({"Delta_rho_Tp_"+str(nuc_dicts.index(nuc_dict)): Delta_rho_Tp})
            
            Delta_p_Tp=m.Vtot(phi_meta_Tp,Tp)-m.Vtot(phi_stable_Tp,Tp)
            dict_out.update({"Delta_p_Tp_"+str(nuc_dicts.index(nuc_dict)): Delta_p_Tp})
            
            alpha_Tp=alpha_GW(Tp,Delta_rho_Tp)
            dict_out.update({"alpha_Tp_"+str(nuc_dicts.index(nuc_dict)):alpha_GW(Tp,Delta_rho_Tp)})
            
            beta_Tp=beta_GW(Tp,dS_TdT_Tp)
            dict_out.update({"beta_Tp_"+str(nuc_dicts.index(nuc_dict)):beta_Tp})
            
            xi_Jouguet_Tp=((alpha_Tp*(2+3*alpha_Tp))**0.5+1)/(3**0.5*(1+alpha_Tp))
            dV_Tp = m.Vtot(phi_meta_Tp,Tp)-m.Vtot(phi_stable_Tp,Tp)
            radiationDensity_Tp=np.pi**2/30*g_star(Tp)*Tp**4
            vwall_Tp=(dV_Tp/alpha_Tp/radiationDensity_Tp)**0.5 ##Analytic formula
            dict_out.update({"vwall_Tp_"+str(nuc_dicts.index(nuc_dict)): vwall_Tp,
                             "xi_Jouguet_Tp_"+str(nuc_dicts.index(nuc_dict)):xi_Jouguet_Tp})
            
            my_signal_Tp=GW_signal(Tp*(1+alpha_Tp)**0.25,alpha_Tp,beta_Tp,df.iloc[modi]["vw"])
            peak_vals_Tp=my_signal_Tp.T[my_signal_Tp[1]==max(my_signal_Tp[1])][0] ##Extract values at peak
            f_peak_Tp=peak_vals_Tp[0]
            Omega_peak_Tp=peak_vals_Tp[1]
            dict_out.update({"f_peak_Tp_"+str(nuc_dicts.index(nuc_dict)): f_peak_Tp,
                             "Omega_peak_Tp_"+str(nuc_dicts.index(nuc_dict)):Omega_peak_Tp})
            SNR_Tp=SNR_GW(my_signal_Tp)
            dict_out.update({"SNR_Tp_"+str(nuc_dicts.index(nuc_dict)): SNR_Tp})
            dict_out.update(dict(df[hydrocolumns].iloc[modi]))####Comment out not for BAU

            #-----Fill dictionary------------------------------------------------------------
            print("\n ..........\n Current dictionary is: \n")
            print(dict_out)
        except:
            print("error ocurred")
            m.phases=phases_copy
            continue
# Out:
# -1
# doing (-5, -3)
# Tracing phase starting at x = [246.20000181  89.91373791] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ..........
# /Users/marcoantoniomerchandmedina/opt/anaconda3/envs/cosmoT/lib/python3.6/site-packages/cosmoTransitions/generic_potential_1.py:260: RuntimeWarning: overflow encountered in multiply
#   - 1.5)  + 2*n*m2*Mphys, axis=-1)
# /Users/marcoantoniomerchandmedina/opt/anaconda3/envs/cosmoT/lib/python3.6/site-packages/cosmoTransitions/generic_potential_1.py:259: RuntimeWarning: overflow encountered in multiply
#   y -= np.sum(n*m2*m2 * (np.log(np.abs(m2/Mphys) + 1e-100)
# ...............................................................................................................................................................................................................
# Tracing phase starting at x = [1.39006376e-06 4.10139407e+01] ; t = 129.149425157976
# Tracing minimum down
# traceMinimum t0 = 129.149
# .........................................................................................................................................................................................................
# Tracing minimum up
# traceMinimum t0 = 129.149
# .................................................................................................................................................
# Tracing phase starting at x = [-8.53895005e-08  3.35565540e+01] ; t = 61.85952732132742
# Tracing minimum down
# traceMinimum t0 = 61.8595
# .................................................................................................................................................................................
# Tracing minimum up
# traceMinimum t0 = 61.8595
# ................
# Tunneling is relevant from phase 1 to 0
# high_vev [3.73049349e-06 3.89048669e+01]
# low_vev [184.42125364  89.36449768]
# max temperature is 118.90724750971269
# min temperature is 62.85968563158796
# Tunneling from phase 1 to phase 0 at T=82.98445
# high_vev = [2.12101959e-06 3.41593578e+01]
# low_vev = [231.96763657  89.86255703]
# Tunneling from phase 1 to phase 0 at T=96.70574
# high_vev = [4.08368753e-06 3.54257090e+01]
# low_vev = [220.68113906  89.79757821]
# Path deformation converged. 51 steps. fRatio = 1.84459e-02
# Path deformation converged. 11 steps. fRatio = 1.98703e-02
# Path deformation converged. 6 steps. fRatio = 1.75865e-02
# Path deformation converged. 2 steps. fRatio = 1.61738e-02
# Path deformation converged. 2 steps. fRatio = 1.63016e-02
# Path deformation converged. 2 steps. fRatio = 1.63878e-02
# Path deformation converged. 2 steps. fRatio = 1.63579e-02
# Path deformation converged. 2 steps. fRatio = 1.63123e-02
# Path deformation converged. 2 steps. fRatio = 1.62005e-02
# Path deformation converged. 2 steps. fRatio = 1.60389e-02
# Path deformation converged. 2 steps. fRatio = 1.58981e-02
# Path deformation converged. 2 steps. fRatio = 1.57631e-02
# Path deformation converged. 2 steps. fRatio = 1.56352e-02
# Path deformation converged. 2 steps. fRatio = 1.54865e-02
# Path deformation converged. 2 steps. fRatio = 1.52458e-02
# Path deformation converged. 2 steps. fRatio = 1.50984e-02
# Path deformation converged. 2 steps. fRatio = 1.49338e-02
# Path deformation converged. 2 steps. fRatio = 1.48143e-02
# Path deformation converged. 2 steps. fRatio = 1.46821e-02
# Path deformation converged. 2 steps. fRatio = 1.45508e-02
# Tunneling from phase 1 to phase 0 at T=74.50422
# high_vev = [1.38856381e-06 3.37400400e+01]
# low_vev = [236.76197496  89.88332578]
# Path deformation converged. 42 steps. fRatio = 1.71804e-02
# Path deformation converged. 18 steps. fRatio = 1.89459e-02
# Path deformation converged. 15 steps. fRatio = 1.91599e-02
# Path deformation converged. 11 steps. fRatio = 1.89314e-02
# Path deformation converged. 8 steps. fRatio = 1.89074e-02
# Path deformation converged. 8 steps. fRatio = 1.70572e-02
# Path deformation converged. 7 steps. fRatio = 1.85556e-02
# Path deformation converged. 7 steps. fRatio = 1.84664e-02
# Path deformation converged. 7 steps. fRatio = 1.81618e-02
# Path deformation converged. 6 steps. fRatio = 1.98233e-02
# Path deformation converged. 6 steps. fRatio = 1.97855e-02
# Path deformation converged. 7 steps. fRatio = 1.81444e-02
# Path deformation converged. 6 steps. fRatio = 1.97190e-02
# Path deformation converged. 6 steps. fRatio = 1.99555e-02
# Path deformation converged. 6 steps. fRatio = 1.99940e-02
# Path deformation converged. 7 steps. fRatio = 1.80760e-02
# Path deformation converged. 6 steps. fRatio = 1.96570e-02
# Path deformation converged. 6 steps. fRatio = 1.96521e-02
# Path deformation converged. 7 steps. fRatio = 1.80662e-02
# Path deformation converged. 6 steps. fRatio = 1.93505e-02
# Tunneling from phase 1 to phase 0 at T=89.84509
# high_vev = [2.23951351e-06 3.47031625e+01]
# low_vev = [226.95907064  89.83669499]
# Path deformation converged. 51 steps. fRatio = 1.84333e-02
# Path deformation converged. 13 steps. fRatio = 1.64578e-02
# Path deformation converged. 11 steps. fRatio = 1.83347e-02
# Path deformation converged. 2 steps. fRatio = 1.96374e-02
# Path deformation converged. 2 steps. fRatio = 1.90377e-02
# Path deformation converged. 2 steps. fRatio = 1.96427e-02
# Path deformation converged. 3 steps. fRatio = 1.91226e-02
# Path deformation converged. 2 steps. fRatio = 1.88915e-02
# Path deformation converged. 2 steps. fRatio = 1.96383e-02
# Path deformation converged. 3 steps. fRatio = 1.90309e-02
# Path deformation converged. 2 steps. fRatio = 1.68039e-02
# Path deformation converged. 2 steps. fRatio = 1.81614e-02
# Path deformation converged. 2 steps. fRatio = 1.86377e-02
# Path deformation converged. 2 steps. fRatio = 1.96998e-02
# Path deformation converged. 2 steps. fRatio = 1.76819e-02
# Path deformation converged. 2 steps. fRatio = 1.81892e-02
# Path deformation converged. 5 steps. fRatio = 1.83288e-02
# Path deformation converged. 2 steps. fRatio = 1.26994e-02
# Path deformation converged. 2 steps. fRatio = 1.48478e-02
# Path deformation converged. 2 steps. fRatio = 1.48941e-02
# Tunneling from phase 1 to phase 0 at T=79.74529
# high_vev = [1.85544178e-06 3.39658808e+01]
# low_vev = [233.96448387  89.87166002]
# Path deformation converged. 46 steps. fRatio = 1.81766e-02
# Path deformation converged. 19 steps. fRatio = 1.32430e-02
# Path deformation converged. 8 steps. fRatio = 1.89744e-02
# Path deformation converged. 6 steps. fRatio = 1.99092e-02
# Path deformation converged. 5 steps. fRatio = 1.93462e-02
# Path deformation converged. 4 steps. fRatio = 1.97405e-02
# Path deformation converged. 4 steps. fRatio = 1.97316e-02
# Path deformation converged. 4 steps. fRatio = 1.96765e-02
# Path deformation converged. 4 steps. fRatio = 1.95848e-02
# Path deformation converged. 4 steps. fRatio = 1.94597e-02
# Path deformation converged. 4 steps. fRatio = 1.93530e-02
# Path deformation converged. 4 steps. fRatio = 1.92576e-02
# Path deformation converged. 3 steps. fRatio = 1.99119e-02
# Path deformation converged. 4 steps. fRatio = 1.94112e-02
# Path deformation converged. 4 steps. fRatio = 1.92249e-02
# Path deformation converged. 3 steps. fRatio = 1.98246e-02
# Path deformation converged. 4 steps. fRatio = 1.93184e-02
# Path deformation converged. 3 steps. fRatio = 1.99061e-02
# Path deformation converged. 4 steps. fRatio = 1.93353e-02
# Path deformation converged. 3 steps. fRatio = 1.99240e-02
# Tunneling from phase 1 to phase 0 at T=85.60498
# high_vev = [1.94927343e-06 3.43457031e+01]
# low_vev = [230.18673094  89.85387073]
# Path deformation converged. 50 steps. fRatio = 1.99571e-02
# Path deformation converged. 18 steps. fRatio = 1.58119e-02
# Path deformation converged. 7 steps. fRatio = 1.78667e-02
# Path deformation converged. 2 steps. fRatio = 1.73974e-02
# Path deformation converged. 4 steps. fRatio = 1.89758e-02
# Path deformation converged. 2 steps. fRatio = 1.64478e-02
# Path deformation converged. 3 steps. fRatio = 1.97814e-02
# Path deformation converged. 2 steps. fRatio = 1.91997e-02
# Path deformation converged. 2 steps. fRatio = 1.98009e-02
# Path deformation converged. 2 steps. fRatio = 1.83276e-02
# Path deformation converged. 3 steps. fRatio = 1.95826e-02
# Path deformation converged. 2 steps. fRatio = 1.99599e-02
# Path deformation converged. 2 steps. fRatio = 1.84576e-02
# Path deformation converged. 3 steps. fRatio = 1.95920e-02
# Path deformation converged. 2 steps. fRatio = 1.99445e-02
# Path deformation converged. 2 steps. fRatio = 1.83445e-02
# Path deformation converged. 3 steps. fRatio = 1.95343e-02
# Path deformation converged. 2 steps. fRatio = 1.98281e-02
# Path deformation converged. 3 steps. fRatio = 1.98736e-02
# Path deformation converged. 2 steps. fRatio = 1.93206e-02
# Tunneling from phase 1 to phase 0 at T=81.7472
# high_vev = [1.72244198e-06 3.40806290e+01]
# low_vev = [232.7560937   89.86623175]
# Path deformation converged. 46 steps. fRatio = 1.81819e-02
# Path deformation converged. 18 steps. fRatio = 1.87571e-02
# Path deformation converged. 8 steps. fRatio = 1.86557e-02
# Path deformation converged. 6 steps. fRatio = 1.85401e-02
# Path deformation converged. 3 steps. fRatio = 1.95291e-02
# Path deformation converged. 2 steps. fRatio = 1.52770e-02
# Path deformation converged. 5 steps. fRatio = 1.90482e-02
# Path deformation converged. 3 steps. fRatio = 1.97965e-02
# Path deformation converged. 3 steps. fRatio = 1.99065e-02
# Path deformation converged. 2 steps. fRatio = 1.43118e-02
# Path deformation converged. 5 steps. fRatio = 1.86847e-02
# Path deformation converged. 3 steps. fRatio = 1.97010e-02
# Path deformation converged. 2 steps. fRatio = 1.98800e-02
# Path deformation converged. 3 steps. fRatio = 1.98664e-02
# Path deformation converged. 4 steps. fRatio = 1.91784e-02
# Path deformation converged. 2 steps. fRatio = 1.98641e-02
# Path deformation converged. 3 steps. fRatio = 1.99443e-02
# Path deformation converged. 4 steps. fRatio = 1.90024e-02
# Path deformation converged. 2 steps. fRatio = 1.96762e-02
# Path deformation converged. 3 steps. fRatio = 1.98347e-02
# Tunneling from phase 1 to phase 0 at T=83.9854
# high_vev = [2.05890593e-06 3.42274006e+01]
# low_vev = [231.30556384  89.85939101]
# Path deformation converged. 49 steps. fRatio = 1.99220e-02
# Path deformation converged. 18 steps. fRatio = 1.75412e-02
# Path deformation converged. 8 steps. fRatio = 1.75950e-02
# Path deformation converged. 3 steps. fRatio = 1.94875e-02
# Path deformation converged. 7 steps. fRatio = 1.78865e-02
# Path deformation converged. 2 steps. fRatio = 1.47810e-02
# Path deformation converged. 2 steps. fRatio = 1.33233e-02
# Path deformation converged. 5 steps. fRatio = 1.99284e-02
# Path deformation converged. 2 steps. fRatio = 1.40665e-02
# Path deformation converged. 2 steps. fRatio = 1.51496e-02
# Path deformation converged. 2 steps. fRatio = 1.56591e-02
# Path deformation converged. 4 steps. fRatio = 1.91950e-02
# Path deformation converged. 2 steps. fRatio = 1.33429e-02
# Path deformation converged. 2 steps. fRatio = 1.33608e-02
# Path deformation converged. 10 steps. fRatio = 1.89764e-02
# Path deformation converged. 2 steps. fRatio = 1.82835e-02
# Path deformation converged. 5 steps. fRatio = 1.95995e-02
# Path deformation converged. 2 steps. fRatio = 1.44534e-02
# Path deformation converged. 2 steps. fRatio = 1.38739e-02
# Path deformation converged. 5 steps. fRatio = 1.95810e-02
# Tunneling from phase 1 to phase 0 at T=82.51186
# high_vev = [1.87068717e-06 3.41285852e+01]
# low_vev = [232.27264768  89.86399045]
# Path deformation converged. 41 steps. fRatio = 1.85308e-02
# Path deformation converged. 18 steps. fRatio = 1.82414e-02
# Path deformation converged. 8 steps. fRatio = 1.79021e-02
# Path deformation converged. 5 steps. fRatio = 1.94947e-02
# Path deformation converged. 2 steps. fRatio = 1.96851e-02
# Path deformation converged. 4 steps. fRatio = 1.91397e-02
# Path deformation converged. 3 steps. fRatio = 1.94615e-02
# Path deformation converged. 3 steps. fRatio = 1.96218e-02
# Path deformation converged. 3 steps. fRatio = 1.97190e-02
# Path deformation converged. 3 steps. fRatio = 1.96897e-02
# Path deformation converged. 3 steps. fRatio = 1.97305e-02
# Path deformation converged. 3 steps. fRatio = 1.96883e-02
# Path deformation converged. 3 steps. fRatio = 1.96238e-02
# Path deformation converged. 3 steps. fRatio = 1.95611e-02
# Path deformation converged. 3 steps. fRatio = 1.94628e-02
# Path deformation converged. 4 steps. fRatio = 1.90524e-02
# Path deformation converged. 2 steps. fRatio = 1.99612e-02
# Path deformation converged. 2 steps. fRatio = 1.99385e-02
# Path deformation converged. 3 steps. fRatio = 1.96180e-02
# Path deformation converged. 3 steps. fRatio = 1.94211e-02
# Tunneling from phase 1 to phase 0 at T=83.36678
# high_vev = [2.14421505e-06 3.41848902e+01]
# low_vev = [231.71734243  89.86136935]
# Path deformation converged. 46 steps. fRatio = 1.81015e-02
# Path deformation converged. 18 steps. fRatio = 1.78521e-02
# Path deformation converged. 8 steps. fRatio = 1.70521e-02
# Path deformation converged. 3 steps. fRatio = 1.98902e-02
# Path deformation converged. 2 steps. fRatio = 1.52817e-02
# Path deformation converged. 5 steps. fRatio = 1.89180e-02
# Path deformation converged. 2 steps. fRatio = 1.49060e-02
# Path deformation converged. 2 steps. fRatio = 1.53652e-02
# Path deformation converged. 5 steps. fRatio = 1.84856e-02
# Path deformation converged. 2 steps. fRatio = 1.46572e-02
# Path deformation converged. 4 steps. fRatio = 1.89371e-02
# Path deformation converged. 2 steps. fRatio = 1.46542e-02
# Path deformation converged. 2 steps. fRatio = 1.52221e-02
# Path deformation converged. 4 steps. fRatio = 1.96198e-02
# Path deformation converged. 2 steps. fRatio = 1.49326e-02
# Path deformation converged. 7 steps. fRatio = 1.98990e-02
# Path deformation converged. 2 steps. fRatio = 1.50768e-02
# Path deformation converged. 8 steps. fRatio = 1.95048e-02
# Path deformation converged. 2 steps. fRatio = 1.48560e-02
# Path deformation converged. 4 steps. fRatio = 1.93324e-02
# Tunneling from phase 1 to phase 0 at T=82.80393
# high_vev = [2.03005411e-06 3.41475013e+01]
# low_vev = [232.08470936  89.86311002]
# Path deformation converged. 46 steps. fRatio = 1.95323e-02
# Path deformation converged. 18 steps. fRatio = 1.77771e-02
# Path deformation converged. 8 steps. fRatio = 1.79714e-02
# Path deformation converged. 5 steps. fRatio = 1.90153e-02
# Path deformation converged. 2 steps. fRatio = 1.93956e-02
# Path deformation converged. 3 steps. fRatio = 1.96149e-02
# Path deformation converged. 3 steps. fRatio = 1.97702e-02
# Path deformation converged. 3 steps. fRatio = 1.99625e-02
# Path deformation converged. 4 steps. fRatio = 1.90451e-02
# Path deformation converged. 3 steps. fRatio = 1.93332e-02
# Path deformation converged. 3 steps. fRatio = 1.95729e-02
# Path deformation converged. 3 steps. fRatio = 1.96162e-02
# Path deformation converged. 3 steps. fRatio = 1.96208e-02
# Path deformation converged. 3 steps. fRatio = 1.92741e-02
# Path deformation converged. 3 steps. fRatio = 1.95803e-02
# Path deformation converged. 4 steps. fRatio = 1.96082e-02
# Path deformation converged. 2 steps. fRatio = 1.90737e-02
# Path deformation converged. 2 steps. fRatio = 1.99188e-02
# Path deformation converged. 3 steps. fRatio = 1.95793e-02
# Path deformation converged. 2 steps. fRatio = 1.98977e-02
# Tunneling from phase 1 to phase 0 at T=83.13048
# high_vev = [2.10696877e-06 3.41690439e+01]
# low_vev = [231.87241161  89.86210581]
# Path deformation converged. 46 steps. fRatio = 1.90515e-02
# Path deformation converged. 20 steps. fRatio = 1.91986e-02
# Path deformation converged. 8 steps. fRatio = 1.64000e-02
# Path deformation converged. 6 steps. fRatio = 1.83951e-02
# Path deformation converged. 6 steps. fRatio = 1.87762e-02
# Path deformation converged. 2 steps. fRatio = 1.95463e-02
# Path deformation converged. 4 steps. fRatio = 1.89988e-02
# Path deformation converged. 2 steps. fRatio = 1.99350e-02
# Path deformation converged. 3 steps. fRatio = 1.97984e-02
# Path deformation converged. 3 steps. fRatio = 1.96273e-02
# Path deformation converged. 3 steps. fRatio = 1.95857e-02
# Path deformation converged. 3 steps. fRatio = 1.94724e-02
# Path deformation converged. 3 steps. fRatio = 1.93934e-02
# Path deformation converged. 3 steps. fRatio = 1.95261e-02
# Path deformation converged. 3 steps. fRatio = 1.93380e-02
# Path deformation converged. 3 steps. fRatio = 1.93623e-02
# Path deformation converged. 2 steps. fRatio = 1.98052e-02
# Path deformation converged. 3 steps. fRatio = 1.98483e-02
# Path deformation converged. 2 steps. fRatio = 1.93586e-02
# Path deformation converged. 3 steps. fRatio = 1.91988e-02
# Tunneling from phase 1 to phase 0 at T=82.9155
# high_vev = [2.17346200e-06 3.41548154e+01]
# low_vev = [232.01243946  89.86276984]
# Path deformation converged. 43 steps. fRatio = 1.70243e-02
# Path deformation converged. 18 steps. fRatio = 1.98589e-02
# Path deformation converged. 8 steps. fRatio = 1.77717e-02
# Path deformation converged. 4 steps. fRatio = 1.97917e-02
# Path deformation converged. 3 steps. fRatio = 1.94145e-02
# Path deformation converged. 3 steps. fRatio = 1.93112e-02
# Path deformation converged. 4 steps. fRatio = 1.90896e-02
# Path deformation converged. 2 steps. fRatio = 1.95314e-02
# Path deformation converged. 3 steps. fRatio = 1.95190e-02
# Path deformation converged. 3 steps. fRatio = 1.95339e-02
# Path deformation converged. 3 steps. fRatio = 1.94530e-02
# Path deformation converged. 3 steps. fRatio = 1.97507e-02
# Path deformation converged. 3 steps. fRatio = 1.92369e-02
# Path deformation converged. 3 steps. fRatio = 1.91843e-02
# Path deformation converged. 2 steps. fRatio = 1.99298e-02
# Path deformation converged. 3 steps. fRatio = 1.96476e-02
# Path deformation converged. 3 steps. fRatio = 1.93938e-02
# Path deformation converged. 4 steps. fRatio = 1.90143e-02
# Path deformation converged. 2 steps. fRatio = 1.98693e-02
# Path deformation converged. 3 steps. fRatio = 1.96629e-02
# Tunneling from phase 1 to phase 0 at T=83.04023
# high_vev = [2.01159899e-06 3.41630481e+01]
# low_vev = [231.93132006  89.86238528]
# Path deformation converged. 46 steps. fRatio = 1.84099e-02
# Path deformation converged. 18 steps. fRatio = 1.81129e-02
# Path deformation converged. 8 steps. fRatio = 1.76856e-02
# Path deformation converged. 3 steps. fRatio = 1.96960e-02
# Path deformation converged. 3 steps. fRatio = 1.97492e-02
# Path deformation converged. 3 steps. fRatio = 1.99602e-02
# Path deformation converged. 3 steps. fRatio = 1.99924e-02
# Path deformation converged. 3 steps. fRatio = 1.99824e-02
# Path deformation converged. 3 steps. fRatio = 1.99069e-02
# Path deformation converged. 4 steps. fRatio = 1.90736e-02
# Path deformation converged. 3 steps. fRatio = 1.97508e-02
# Path deformation converged. 3 steps. fRatio = 1.98895e-02
# Path deformation converged. 3 steps. fRatio = 1.92336e-02
# Path deformation converged. 3 steps. fRatio = 1.98206e-02
# Path deformation converged. 3 steps. fRatio = 1.96239e-02
# Path deformation converged. 3 steps. fRatio = 1.96634e-02
# Path deformation converged. 3 steps. fRatio = 1.95019e-02
# Path deformation converged. 3 steps. fRatio = 1.93872e-02
# Path deformation converged. 2 steps. fRatio = 1.99431e-02
# Path deformation converged. 3 steps. fRatio = 1.97982e-02
# Tunneling from phase 1 to phase 0 at T=82.95811
# high_vev = [2.15096310e-06 3.41576201e+01]
# low_vev = [231.98476407  89.86263838]
# Path deformation converged. 50 steps. fRatio = 1.87314e-02
# Path deformation converged. 18 steps. fRatio = 1.81177e-02
# Path deformation converged. 8 steps. fRatio = 1.80151e-02
# Path deformation converged. 5 steps. fRatio = 1.92798e-02
# Path deformation converged. 2 steps. fRatio = 1.99440e-02
# Path deformation converged. 3 steps. fRatio = 1.99740e-02
# Path deformation converged. 4 steps. fRatio = 1.92416e-02
# Path deformation converged. 3 steps. fRatio = 1.93430e-02
# Path deformation converged. 3 steps. fRatio = 1.93187e-02
# Path deformation converged. 3 steps. fRatio = 1.94565e-02
# Path deformation converged. 3 steps. fRatio = 1.92315e-02
# Path deformation converged. 3 steps. fRatio = 1.96531e-02
# Path deformation converged. 3 steps. fRatio = 1.92025e-02
# Path deformation converged. 2 steps. fRatio = 1.98431e-02
# Path deformation converged. 4 steps. fRatio = 1.88870e-02
# Path deformation converged. 2 steps. fRatio = 1.92204e-02
# Path deformation converged. 2 steps. fRatio = 1.99178e-02
# Path deformation converged. 4 steps. fRatio = 1.87163e-02
# Path deformation converged. 2 steps. fRatio = 1.89572e-02
# Path deformation converged. 3 steps. fRatio = 1.91339e-02
# Tunneling from phase 1 to phase 0 at T=83.00575
# high_vev = [2.13883137e-06 3.41607646e+01]
# low_vev = [231.95377554  89.86249174]
# Path deformation converged. 46 steps. fRatio = 1.94103e-02
# Path deformation converged. 20 steps. fRatio = 1.90333e-02
# Path deformation converged. 8 steps. fRatio = 1.87817e-02
# Path deformation converged. 5 steps. fRatio = 1.94361e-02
# Path deformation converged. 3 steps. fRatio = 1.96475e-02
# Path deformation converged. 3 steps. fRatio = 1.98825e-02
# Path deformation converged. 4 steps. fRatio = 1.91226e-02
# Path deformation converged. 4 steps. fRatio = 1.92063e-02
# Path deformation converged. 3 steps. fRatio = 1.93098e-02
# Path deformation converged. 3 steps. fRatio = 1.93817e-02
# Path deformation converged. 3 steps. fRatio = 1.95753e-02
# Path deformation converged. 3 steps. fRatio = 1.94477e-02
# Path deformation converged. 3 steps. fRatio = 1.93953e-02
# Path deformation converged. 3 steps. fRatio = 1.93675e-02
# Path deformation converged. 3 steps. fRatio = 1.92478e-02
# Path deformation converged. 2 steps. fRatio = 1.99763e-02
# Path deformation converged. 3 steps. fRatio = 1.96046e-02
# Path deformation converged. 3 steps. fRatio = 1.93742e-02
# Path deformation converged. 3 steps. fRatio = 1.93665e-02
# Path deformation converged. 3 steps. fRatio = 1.91525e-02
# Tunneling from phase 1 to phase 0 at T=82.97439
# high_vev = [2.01939131e-06 3.41586944e+01]
# low_vev = [231.97418009  89.86258856]
# Path deformation converged. 46 steps. fRatio = 1.84896e-02
# Path deformation converged. 18 steps. fRatio = 1.79933e-02
# Path deformation converged. 8 steps. fRatio = 1.78255e-02
# Path deformation converged. 5 steps. fRatio = 1.92038e-02
# Path deformation converged. 2 steps. fRatio = 1.98884e-02
# Path deformation converged. 3 steps. fRatio = 1.98351e-02
# Path deformation converged. 4 steps. fRatio = 1.90426e-02
# Path deformation converged. 3 steps. fRatio = 1.93863e-02
# Path deformation converged. 3 steps. fRatio = 1.93505e-02
# Path deformation converged. 3 steps. fRatio = 1.93622e-02
# Path deformation converged. 3 steps. fRatio = 1.94665e-02
# Path deformation converged. 3 steps. fRatio = 1.93852e-02
# Path deformation converged. 3 steps. fRatio = 1.93617e-02
# Path deformation converged. 3 steps. fRatio = 1.91429e-02
# Path deformation converged. 3 steps. fRatio = 1.92374e-02
# Path deformation converged. 2 steps. fRatio = 1.98933e-02
# Path deformation converged. 3 steps. fRatio = 1.94744e-02
# Path deformation converged. 3 steps. fRatio = 1.93263e-02
# Path deformation converged. 3 steps. fRatio = 1.91126e-02
# Path deformation converged. 2 steps. fRatio = 1.99627e-02
# Tunneling from phase 1 to phase 0 at T=82.99258
# high_vev = [2.11388041e-06 3.41598949e+01]
# low_vev = [231.96234485  89.8625322 ]
# Path deformation converged. 46 steps. fRatio = 1.85048e-02
# Path deformation converged. 18 steps. fRatio = 1.81471e-02
# Path deformation converged. 8 steps. fRatio = 1.75678e-02
# Path deformation converged. 4 steps. fRatio = 1.97620e-02
# Path deformation converged. 3 steps. fRatio = 1.98144e-02
# Path deformation converged. 4 steps. fRatio = 1.90993e-02
# Path deformation converged. 3 steps. fRatio = 1.96032e-02
# Path deformation converged. 3 steps. fRatio = 1.94908e-02
# Path deformation converged. 3 steps. fRatio = 1.95116e-02
# Path deformation converged. 3 steps. fRatio = 1.96035e-02
# Path deformation converged. 3 steps. fRatio = 1.96919e-02
# Path deformation converged. 3 steps. fRatio = 1.95825e-02
# Path deformation converged. 3 steps. fRatio = 1.93620e-02
# Path deformation converged. 3 steps. fRatio = 1.94028e-02
# Path deformation converged. 2 steps. fRatio = 1.99652e-02
# Path deformation converged. 3 steps. fRatio = 1.98769e-02
# Path deformation converged. 3 steps. fRatio = 1.94743e-02
# Path deformation converged. 3 steps. fRatio = 1.92302e-02
# Path deformation converged. 3 steps. fRatio = 1.92438e-02
# Path deformation converged. 2 steps. fRatio = 1.99795e-02
# Tunneling from phase 1 to phase 0 at T=82.9806
# high_vev = [2.04498909e-06 3.41591034e+01]
# low_vev = [231.97014013  89.86256941]
# Path deformation converged. 46 steps. fRatio = 1.94267e-02
# Path deformation converged. 20 steps. fRatio = 1.90930e-02
# Path deformation converged. 8 steps. fRatio = 1.89102e-02
# Path deformation converged. 5 steps. fRatio = 1.97125e-02
# Path deformation converged. 3 steps. fRatio = 1.98823e-02
# Path deformation converged. 4 steps. fRatio = 1.93438e-02
# Path deformation converged. 3 steps. fRatio = 1.95414e-02
# Path deformation converged. 3 steps. fRatio = 1.98245e-02
# Path deformation converged. 3 steps. fRatio = 1.97537e-02
# Path deformation converged. 3 steps. fRatio = 1.98370e-02
# Path deformation converged. 3 steps. fRatio = 1.95843e-02
# Path deformation converged. 3 steps. fRatio = 1.96039e-02
# Path deformation converged. 3 steps. fRatio = 1.95254e-02
# Path deformation converged. 2 steps. fRatio = 1.94369e-02
# Path deformation converged. 3 steps. fRatio = 1.99142e-02
# Path deformation converged. 3 steps. fRatio = 1.98159e-02
# Path deformation converged. 3 steps. fRatio = 1.94327e-02
# Path deformation converged. 3 steps. fRatio = 1.91407e-02
# Path deformation converged. 3 steps. fRatio = 1.93819e-02
# Path deformation converged. 3 steps. fRatio = 1.91289e-02
# Tunneling from phase 1 to phase 0 at T=82.98755
# high_vev = [2.01687010e-06 3.41595631e+01]
# low_vev = [231.9656181   89.86254767]
# Path deformation converged. 50 steps. fRatio = 1.87080e-02
# Path deformation converged. 18 steps. fRatio = 1.82085e-02
# Path deformation converged. 8 steps. fRatio = 1.79572e-02
# Path deformation converged. 5 steps. fRatio = 1.90425e-02
# Path deformation converged. 2 steps. fRatio = 1.98245e-02
# Path deformation converged. 3 steps. fRatio = 1.99464e-02
# Path deformation converged. 4 steps. fRatio = 1.91533e-02
# Path deformation converged. 2 steps. fRatio = 1.99009e-02
# Path deformation converged. 3 steps. fRatio = 1.98847e-02
# Path deformation converged. 3 steps. fRatio = 1.98522e-02
# Path deformation converged. 3 steps. fRatio = 1.98664e-02
# Path deformation converged. 3 steps. fRatio = 1.94531e-02
# Path deformation converged. 3 steps. fRatio = 1.95388e-02
# Path deformation converged. 3 steps. fRatio = 1.92311e-02
# Path deformation converged. 3 steps. fRatio = 1.92631e-02
# Path deformation converged. 3 steps. fRatio = 1.92502e-02
# Path deformation converged. 2 steps. fRatio = 1.99357e-02
# Path deformation converged. 3 steps. fRatio = 1.96960e-02
# Path deformation converged. 3 steps. fRatio = 1.92879e-02
# Path deformation converged. 3 steps. fRatio = 1.90945e-02
# Tunneling from phase 1 to phase 0 at T=82.98298
# high_vev = [2.04989519e-06 3.41592612e+01]
# low_vev = [231.96859191  89.86256218]
# Path deformation converged. 46 steps. fRatio = 1.92964e-02
# Path deformation converged. 20 steps. fRatio = 1.91238e-02
# Path deformation converged. 8 steps. fRatio = 1.88801e-02
# Path deformation converged. 5 steps. fRatio = 1.97085e-02
# Path deformation converged. 3 steps. fRatio = 1.99773e-02
# Path deformation converged. 4 steps. fRatio = 1.91056e-02
# Path deformation converged. 3 steps. fRatio = 1.96196e-02
# Path deformation converged. 3 steps. fRatio = 1.98015e-02
# Path deformation converged. 3 steps. fRatio = 1.97398e-02
# Path deformation converged. 3 steps. fRatio = 1.99221e-02
# Path deformation converged. 3 steps. fRatio = 1.98040e-02
# Path deformation converged. 3 steps. fRatio = 1.96321e-02
# Path deformation converged. 3 steps. fRatio = 1.93593e-02
# Path deformation converged. 3 steps. fRatio = 1.94230e-02
# Path deformation converged. 3 steps. fRatio = 1.93568e-02
# Path deformation converged. 3 steps. fRatio = 1.92109e-02
# Path deformation converged. 2 steps. fRatio = 1.98293e-02
# Path deformation converged. 3 steps. fRatio = 1.96773e-02
# Path deformation converged. 3 steps. fRatio = 1.93640e-02
# Path deformation converged. 3 steps. fRatio = 1.92889e-02
# Tunneling from phase 1 to phase 0 at T=82.98563
# high_vev = [2.23054289e-06 3.41594380e+01]
# low_vev = [231.96686835  89.86255336]
# Path deformation converged. 46 steps. fRatio = 1.93062e-02
# Path deformation converged. 20 steps. fRatio = 1.90525e-02
# Path deformation converged. 8 steps. fRatio = 1.89076e-02
# Path deformation converged. 5 steps. fRatio = 1.98957e-02
# Path deformation converged. 3 steps. fRatio = 1.98990e-02
# Path deformation converged. 4 steps. fRatio = 1.91762e-02
# Path deformation converged. 3 steps. fRatio = 1.97073e-02
# Path deformation converged. 3 steps. fRatio = 1.98084e-02
# Path deformation converged. 3 steps. fRatio = 1.96568e-02
# Path deformation converged. 3 steps. fRatio = 1.98984e-02
# Path deformation converged. 3 steps. fRatio = 1.97566e-02
# Path deformation converged. 3 steps. fRatio = 1.95690e-02
# Path deformation converged. 3 steps. fRatio = 1.94691e-02
# Path deformation converged. 3 steps. fRatio = 1.95255e-02
# Path deformation converged. 3 steps. fRatio = 1.93685e-02
# Path deformation converged. 3 steps. fRatio = 1.92711e-02
# Path deformation converged. 3 steps. fRatio = 1.92097e-02
# Path deformation converged. 3 steps. fRatio = 1.91530e-02
# Path deformation converged. 2 steps. fRatio = 1.99999e-02
# Path deformation converged. 3 steps. fRatio = 1.94951e-02
# Tunneling from phase 1 to phase 0 at T=82.98389
# high_vev = [2.09567925e-06 3.41593215e+01]
# low_vev = [231.9680029   89.86255867]
# Path deformation converged. 50 steps. fRatio = 1.87142e-02
# Path deformation converged. 18 steps. fRatio = 1.81954e-02
# Path deformation converged. 8 steps. fRatio = 1.79211e-02
# Path deformation converged. 5 steps. fRatio = 1.89505e-02
# Path deformation converged. 2 steps. fRatio = 1.98191e-02
# Path deformation converged. 4 steps. fRatio = 1.90487e-02
# Path deformation converged. 3 steps. fRatio = 1.94165e-02
# Path deformation converged. 3 steps. fRatio = 1.96521e-02
# Path deformation converged. 3 steps. fRatio = 1.94500e-02
# Path deformation converged. 3 steps. fRatio = 1.96291e-02
# Path deformation converged. 3 steps. fRatio = 1.95510e-02
# Path deformation converged. 3 steps. fRatio = 1.93687e-02
# Path deformation converged. 3 steps. fRatio = 1.94057e-02
# Path deformation converged. 3 steps. fRatio = 1.91511e-02
# Path deformation converged. 3 steps. fRatio = 1.92172e-02
# Path deformation converged. 2 steps. fRatio = 1.97323e-02
# Path deformation converged. 3 steps. fRatio = 1.98636e-02
# Path deformation converged. 3 steps. fRatio = 1.94040e-02
# Path deformation converged. 3 steps. fRatio = 1.91072e-02
# Path deformation converged. 3 steps. fRatio = 1.92000e-02
# Tunneling from phase 1 to phase 0 at T=82.9849
# high_vev = [2.13654338e-06 3.41593875e+01]
# low_vev = [231.96734427  89.86255619]
# Path deformation converged. 46 steps. fRatio = 1.93034e-02
# Path deformation converged. 20 steps. fRatio = 1.90812e-02
# Path deformation converged. 8 steps. fRatio = 1.89505e-02
# Path deformation converged. 5 steps. fRatio = 1.98287e-02
# Path deformation converged. 3 steps. fRatio = 1.99021e-02
# Path deformation converged. 4 steps. fRatio = 1.92020e-02
# Path deformation converged. 3 steps. fRatio = 1.94336e-02
# Path deformation converged. 3 steps. fRatio = 1.98283e-02
# Path deformation converged. 3 steps. fRatio = 1.96447e-02
# Path deformation converged. 3 steps. fRatio = 1.99235e-02
# Path deformation converged. 3 steps. fRatio = 1.97173e-02
# Path deformation converged. 3 steps. fRatio = 1.98329e-02
# Path deformation converged. 3 steps. fRatio = 1.93866e-02
# Path deformation converged. 3 steps. fRatio = 1.93979e-02
# Path deformation converged. 3 steps. fRatio = 1.93353e-02
# Path deformation converged. 3 steps. fRatio = 1.92400e-02
# Path deformation converged. 2 steps. fRatio = 1.98561e-02
# Path deformation converged. 3 steps. fRatio = 1.98290e-02
# Path deformation converged. 3 steps. fRatio = 1.94758e-02
# Path deformation converged. 3 steps. fRatio = 1.91286e-02
# Tunneling from phase 1 to phase 0 at T=82.98423
# high_vev = [2.04326531e-06 3.41593431e+01]
# low_vev = [231.96778352  89.86255705]
# Path deformation converged. 46 steps. fRatio = 1.93010e-02
# Path deformation converged. 20 steps. fRatio = 1.90914e-02
# Path deformation converged. 8 steps. fRatio = 1.88422e-02
# Path deformation converged. 5 steps. fRatio = 1.97210e-02
# Path deformation converged. 4 steps. fRatio = 1.93295e-02
# Path deformation converged. 3 steps. fRatio = 1.96258e-02
# Path deformation converged. 3 steps. fRatio = 1.96688e-02
# Path deformation converged. 3 steps. fRatio = 1.99293e-02
# Path deformation converged. 3 steps. fRatio = 1.97892e-02
# Path deformation converged. 3 steps. fRatio = 1.98329e-02
# Path deformation converged. 3 steps. fRatio = 1.97247e-02
# Path deformation converged. 3 steps. fRatio = 1.97698e-02
# Path deformation converged. 3 steps. fRatio = 1.95805e-02
# Path deformation converged. 3 steps. fRatio = 1.92877e-02
# Path deformation converged. 3 steps. fRatio = 1.95049e-02
# Path deformation converged. 3 steps. fRatio = 1.92641e-02
# Path deformation converged. 2 steps. fRatio = 1.99348e-02
# Path deformation converged. 4 steps. fRatio = 1.87572e-02
# Path deformation converged. 2 steps. fRatio = 1.94329e-02
# Path deformation converged. 3 steps. fRatio = 1.91416e-02
# Tunneling from phase 1 to phase 0 at T=82.98462
# high_vev = [2.01704544e-06 3.41593698e+01]
# low_vev = [231.96752568  89.86255691]
# Path deformation converged. 46 steps. fRatio = 1.93023e-02
# Path deformation converged. 20 steps. fRatio = 1.90881e-02
# Path deformation converged. 8 steps. fRatio = 1.89333e-02
# Path deformation converged. 5 steps. fRatio = 1.98201e-02
# Path deformation converged. 3 steps. fRatio = 1.98440e-02
# Path deformation converged. 4 steps. fRatio = 1.91390e-02
# Path deformation converged. 3 steps. fRatio = 1.95297e-02
# Path deformation converged. 3 steps. fRatio = 1.98387e-02
# Path deformation converged. 3 steps. fRatio = 1.98106e-02
# Path deformation converged. 3 steps. fRatio = 1.97526e-02
# Path deformation converged. 3 steps. fRatio = 1.96016e-02
# Path deformation converged. 3 steps. fRatio = 1.97782e-02
# Path deformation converged. 3 steps. fRatio = 1.93936e-02
# Path deformation converged. 3 steps. fRatio = 1.93577e-02
# Path deformation converged. 3 steps. fRatio = 1.94528e-02
# Path deformation converged. 2 steps. fRatio = 1.99969e-02
# Path deformation converged. 3 steps. fRatio = 1.97272e-02
# Path deformation converged. 3 steps. fRatio = 1.94905e-02
# Path deformation converged. 3 steps. fRatio = 1.94095e-02
# Path deformation converged. 3 steps. fRatio = 1.91811e-02
# Tunneling from phase 1 to phase 0 at T=82.98436
# high_vev = [1.92906062e-06 3.41593529e+01]
# low_vev = [231.96769118  89.86255791]
# Path deformation converged. 46 steps. fRatio = 1.93014e-02
# Path deformation converged. 20 steps. fRatio = 1.90952e-02
# Path deformation converged. 8 steps. fRatio = 1.89487e-02
# Path deformation converged. 5 steps. fRatio = 1.96128e-02
# Path deformation converged. 4 steps. fRatio = 1.92466e-02
# Path deformation converged. 3 steps. fRatio = 1.95557e-02
# Path deformation converged. 3 steps. fRatio = 1.96135e-02
# Path deformation converged. 3 steps. fRatio = 1.98908e-02
# Path deformation converged. 3 steps. fRatio = 1.98496e-02
# Path deformation converged. 3 steps. fRatio = 1.95742e-02
# Path deformation converged. 3 steps. fRatio = 1.99079e-02
# Path deformation converged. 3 steps. fRatio = 1.97662e-02
# Path deformation converged. 3 steps. fRatio = 1.95290e-02
# Path deformation converged. 3 steps. fRatio = 1.95230e-02
# Path deformation converged. 3 steps. fRatio = 1.94843e-02
# Path deformation converged. 3 steps. fRatio = 1.93691e-02
# Path deformation converged. 2 steps. fRatio = 1.99312e-02
# Path deformation converged. 3 steps. fRatio = 1.96485e-02
# Path deformation converged. 3 steps. fRatio = 1.94963e-02
# Path deformation converged. 3 steps. fRatio = 1.91418e-02
# Tunneling from phase 1 to phase 0 at T=82.98451
# high_vev = [1.99085666e-06 3.41593627e+01]
# low_vev = [231.9675913   89.86255751]
# Path deformation converged. 46 steps. fRatio = 1.93019e-02
# Path deformation converged. 20 steps. fRatio = 1.90819e-02
# Path deformation converged. 8 steps. fRatio = 1.87714e-02
# Path deformation converged. 5 steps. fRatio = 1.99007e-02
# Path deformation converged. 4 steps. fRatio = 1.92621e-02
# Path deformation converged. 3 steps. fRatio = 1.95438e-02
# Path deformation converged. 3 steps. fRatio = 1.98861e-02
# Path deformation converged. 4 steps. fRatio = 1.90466e-02
# Path deformation converged. 2 steps. fRatio = 1.97658e-02
# Path deformation converged. 3 steps. fRatio = 1.98676e-02
# Path deformation converged. 3 steps. fRatio = 1.98078e-02
# Path deformation converged. 3 steps. fRatio = 1.97332e-02
# Path deformation converged. 3 steps. fRatio = 1.94066e-02
# Path deformation converged. 3 steps. fRatio = 1.93138e-02
# Path deformation converged. 3 steps. fRatio = 1.94275e-02
# Path deformation converged. 3 steps. fRatio = 1.92486e-02
# Path deformation converged. 3 steps. fRatio = 1.92607e-02
# Path deformation converged. 2 steps. fRatio = 1.98911e-02
# Path deformation converged. 3 steps. fRatio = 1.95568e-02
# Path deformation converged. 3 steps. fRatio = 1.94165e-02
# Tunneling from phase 1 to phase 0 at T=82.98441
# high_vev = [2.14394273e-06 3.41593553e+01]
# low_vev = [231.96765696  89.86255795]
# Path deformation converged. 46 steps. fRatio = 1.93016e-02
# Path deformation converged. 20 steps. fRatio = 1.90933e-02
# Path deformation converged. 8 steps. fRatio = 1.88238e-02
# Path deformation converged. 5 steps. fRatio = 1.97516e-02
# Path deformation converged. 3 steps. fRatio = 1.99967e-02
# Path deformation converged. 4 steps. fRatio = 1.93056e-02
# Path deformation converged. 3 steps. fRatio = 1.96780e-02
# Path deformation converged. 3 steps. fRatio = 1.97871e-02
# Path deformation converged. 4 steps. fRatio = 1.89943e-02
# Path deformation converged. 2 steps. fRatio = 1.97137e-02
# Path deformation converged. 3 steps. fRatio = 1.97066e-02
# Path deformation converged. 3 steps. fRatio = 1.95943e-02
# Path deformation converged. 3 steps. fRatio = 1.94345e-02
# Path deformation converged. 3 steps. fRatio = 1.95149e-02
# Path deformation converged. 3 steps. fRatio = 1.93147e-02
# Path deformation converged. 2 steps. fRatio = 1.99448e-02
# Path deformation converged. 3 steps. fRatio = 1.96911e-02
# Path deformation converged. 3 steps. fRatio = 1.94140e-02
# Path deformation converged. 3 steps. fRatio = 1.91631e-02
# Path deformation converged. 3 steps. fRatio = 1.91633e-02
# Tunneling from phase 1 to phase 0 at T=82.98447
# high_vev = [2.14803203e-06 3.41593591e+01]
# low_vev = [231.96762101  89.86255677]
# Path deformation converged. 46 steps. fRatio = 1.93017e-02
# Path deformation converged. 20 steps. fRatio = 1.90349e-02
# Path deformation converged. 8 steps. fRatio = 1.89172e-02
# Path deformation converged. 5 steps. fRatio = 1.99743e-02
# Path deformation converged. 3 steps. fRatio = 1.99620e-02
# Path deformation converged. 4 steps. fRatio = 1.92123e-02
# Path deformation converged. 3 steps. fRatio = 1.97228e-02
# Path deformation converged. 3 steps. fRatio = 1.98833e-02
# Path deformation converged. 3 steps. fRatio = 1.98549e-02
# Path deformation converged. 3 steps. fRatio = 1.98237e-02
# Path deformation converged. 3 steps. fRatio = 1.96788e-02
# Path deformation converged. 3 steps. fRatio = 1.96063e-02
# Path deformation converged. 3 steps. fRatio = 1.94295e-02
# Path deformation converged. 3 steps. fRatio = 1.95958e-02
# Path deformation converged. 3 steps. fRatio = 1.94003e-02
# Path deformation converged. 3 steps. fRatio = 1.91742e-02
# Path deformation converged. 2 steps. fRatio = 1.99586e-02
# Path deformation converged. 3 steps. fRatio = 1.98073e-02
# Path deformation converged. 3 steps. fRatio = 1.93424e-02
# Path deformation converged. 3 steps. fRatio = 1.92652e-02
# Tunneling from phase 1 to phase 0 at T=82.98443
# high_vev = [2.04529902e-06 3.41593566e+01]
# low_vev = [231.96764386  89.86255717]
# Path deformation converged. 46 steps. fRatio = 1.93016e-02
# Path deformation converged. 20 steps. fRatio = 1.90347e-02
# Path deformation converged. 8 steps. fRatio = 1.88765e-02
# Path deformation converged. 5 steps. fRatio = 1.98412e-02
# Path deformation converged. 4 steps. fRatio = 1.92050e-02
# Path deformation converged. 3 steps. fRatio = 1.96637e-02
# Path deformation converged. 3 steps. fRatio = 1.99253e-02
# Path deformation converged. 3 steps. fRatio = 1.98646e-02
# Path deformation converged. 4 steps. fRatio = 1.89937e-02
# Path deformation converged. 2 steps. fRatio = 1.99813e-02
# Path deformation converged. 3 steps. fRatio = 1.96905e-02
# Path deformation converged. 3 steps. fRatio = 1.96419e-02
# Path deformation converged. 3 steps. fRatio = 1.96229e-02
# Path deformation converged. 3 steps. fRatio = 1.94407e-02
# Path deformation converged. 3 steps. fRatio = 1.92555e-02
# Path deformation converged. 3 steps. fRatio = 1.94074e-02
# Path deformation converged. 2 steps. fRatio = 1.98812e-02
# Path deformation converged. 3 steps. fRatio = 1.95549e-02
# Path deformation converged. 3 steps. fRatio = 1.96180e-02
# Path deformation converged. 3 steps. fRatio = 1.91438e-02
# Tunneling from phase 1 to phase 0 at T=82.98446
# high_vev = [1.96466463e-06 3.41593597e+01]
# low_vev = [231.96763534  89.86255793]
# Path deformation converged. 46 steps. fRatio = 1.93019e-02
# Path deformation converged. 20 steps. fRatio = 1.90926e-02
# Path deformation converged. 8 steps. fRatio = 1.88640e-02
# Path deformation converged. 5 steps. fRatio = 1.97872e-02
# Path deformation converged. 3 steps. fRatio = 1.99505e-02
# Path deformation converged. 4 steps. fRatio = 1.92037e-02
# Path deformation converged. 3 steps. fRatio = 1.95794e-02
# Path deformation converged. 3 steps. fRatio = 1.98909e-02
# Path deformation converged. 3 steps. fRatio = 1.96907e-02
# Path deformation converged. 3 steps. fRatio = 1.97007e-02
# Path deformation converged. 3 steps. fRatio = 1.97368e-02
# Path deformation converged. 3 steps. fRatio = 1.95550e-02
# Path deformation converged. 3 steps. fRatio = 1.95944e-02
# Path deformation converged. 3 steps. fRatio = 1.94476e-02
# Path deformation converged. 3 steps. fRatio = 1.94104e-02
# Path deformation converged. 3 steps. fRatio = 1.93233e-02
# Path deformation converged. 3 steps. fRatio = 1.92814e-02
# Path deformation converged. 2 steps. fRatio = 1.99862e-02
# Path deformation converged. 3 steps. fRatio = 1.95577e-02
# Path deformation converged. 3 steps. fRatio = 1.93631e-02
# Tunneling from phase 1 to phase 0 at T=82.98444
# high_vev = [2.20042495e-06 3.41593587e+01]
# low_vev = [231.96763759  89.86255764]
# Path deformation converged. 46 steps. fRatio = 1.93016e-02
# Path deformation converged. 20 steps. fRatio = 1.90928e-02
# Path deformation converged. 8 steps. fRatio = 1.89459e-02
# Path deformation converged. 5 steps. fRatio = 1.97171e-02
# Path deformation converged. 3 steps. fRatio = 1.99247e-02
# Path deformation converged. 4 steps. fRatio = 1.92037e-02
# Path deformation converged. 3 steps. fRatio = 1.96384e-02
# Path deformation converged. 3 steps. fRatio = 1.97196e-02
# Path deformation converged. 3 steps. fRatio = 1.99247e-02
# Path deformation converged. 3 steps. fRatio = 1.98002e-02
# Path deformation converged. 3 steps. fRatio = 1.97714e-02
# Path deformation converged. 3 steps. fRatio = 1.96740e-02
# Path deformation converged. 3 steps. fRatio = 1.95641e-02
# Path deformation converged. 3 steps. fRatio = 1.92457e-02
# Path deformation converged. 3 steps. fRatio = 1.93558e-02
# Path deformation converged. 2 steps. fRatio = 1.99461e-02
# Path deformation converged. 3 steps. fRatio = 1.97300e-02
# Path deformation converged. 3 steps. fRatio = 1.96055e-02
# Path deformation converged. 3 steps. fRatio = 1.92889e-02
# Path deformation converged. 3 steps. fRatio = 1.91908e-02
# Tunneling from phase 1 to phase 0 at T=82.98445
# high_vev = [1.92537173e-06 3.41593585e+01]
# low_vev = [231.96763463  89.86255765]
# Path deformation converged. 46 steps. fRatio = 1.93017e-02
# Path deformation converged. 20 steps. fRatio = 1.90927e-02
# Path deformation converged. 8 steps. fRatio = 1.88626e-02
# Path deformation converged. 5 steps. fRatio = 1.98923e-02
# Path deformation converged. 3 steps. fRatio = 1.99222e-02
# Path deformation converged. 4 steps. fRatio = 1.92061e-02
# Path deformation converged. 3 steps. fRatio = 1.94214e-02
# Path deformation converged. 3 steps. fRatio = 1.98660e-02
# Path deformation converged. 3 steps. fRatio = 1.98111e-02
# Path deformation converged. 3 steps. fRatio = 1.97956e-02
# Path deformation converged. 3 steps. fRatio = 1.96758e-02
# Path deformation converged. 3 steps. fRatio = 1.96057e-02
# Path deformation converged. 3 steps. fRatio = 1.93522e-02
# Path deformation converged. 3 steps. fRatio = 1.96480e-02
# Path deformation converged. 3 steps. fRatio = 1.91810e-02
# Path deformation converged. 3 steps. fRatio = 1.92287e-02
# Path deformation converged. 3 steps. fRatio = 1.91870e-02
# Path deformation converged. 2 steps. fRatio = 1.97754e-02
# Path deformation converged. 3 steps. fRatio = 1.94454e-02
# Path deformation converged. 3 steps. fRatio = 1.95620e-02
# Tunneling from phase 1 to phase 0 at T=82.98445
# high_vev = [2.12101959e-06 3.41593578e+01]
# low_vev = [231.96763657  89.86255703]
# Path deformation converged. 46 steps. fRatio = 1.93016e-02
# Path deformation converged. 20 steps. fRatio = 1.90350e-02
# Path deformation converged. 8 steps. fRatio = 1.88308e-02
# Path deformation converged. 6 steps. fRatio = 1.84182e-02
# Path deformation converged. 2 steps. fRatio = 1.96583e-02
# Path deformation converged. 3 steps. fRatio = 1.97328e-02
# Path deformation converged. 3 steps. fRatio = 1.96840e-02
# Path deformation converged. 3 steps. fRatio = 1.97433e-02
# Path deformation converged. 3 steps. fRatio = 1.98390e-02
# Path deformation converged. 3 steps. fRatio = 1.99853e-02
# Path deformation converged. 3 steps. fRatio = 1.96631e-02
# Path deformation converged. 3 steps. fRatio = 1.95788e-02
# Path deformation converged. 3 steps. fRatio = 1.95052e-02
# Path deformation converged. 3 steps. fRatio = 1.92177e-02
# Path deformation converged. 3 steps. fRatio = 1.93650e-02
# Path deformation converged. 3 steps. fRatio = 1.92936e-02
# Path deformation converged. 2 steps. fRatio = 1.98630e-02
# Path deformation converged. 3 steps. fRatio = 1.98309e-02
# Path deformation converged. 3 steps. fRatio = 1.94003e-02
# Path deformation converged. 3 steps. fRatio = 1.91209e-02
# Tunneling from phase 1 to phase 0 at T=82.98383
# high_vev = [2.01711142e-06 3.41593177e+01]
# low_vev = [231.96804198  89.86255959]
# Path deformation converged. 46 steps. fRatio = 1.92994e-02
# Path deformation converged. 20 steps. fRatio = 1.91004e-02
# Path deformation converged. 8 steps. fRatio = 1.87518e-02
# Path deformation converged. 5 steps. fRatio = 1.98225e-02
# Path deformation converged. 4 steps. fRatio = 1.93018e-02
# Path deformation converged. 3 steps. fRatio = 1.97823e-02
# Path deformation converged. 3 steps. fRatio = 1.97905e-02
# Path deformation converged. 4 steps. fRatio = 1.90221e-02
# Path deformation converged. 3 steps. fRatio = 1.92752e-02
# Path deformation converged. 2 steps. fRatio = 1.99704e-02
# Path deformation converged. 3 steps. fRatio = 1.98719e-02
# Path deformation converged. 3 steps. fRatio = 1.98334e-02
# Path deformation converged. 3 steps. fRatio = 1.95543e-02
# Path deformation converged. 3 steps. fRatio = 1.95186e-02
# Path deformation converged. 3 steps. fRatio = 1.94490e-02
# Path deformation converged. 2 steps. fRatio = 1.98508e-02
# Path deformation converged. 3 steps. fRatio = 1.99190e-02
# Path deformation converged. 3 steps. fRatio = 1.94409e-02
# Path deformation converged. 3 steps. fRatio = 1.92730e-02
# Path deformation converged. 3 steps. fRatio = 1.92821e-02
# Tunneling from phase 1 to phase 0 at T=96.70535
# high_vev = [3.81021348e-06 3.54256611e+01]
# low_vev = [220.68153175  89.79758246]
# Path deformation converged. 51 steps. fRatio = 1.84452e-02
# Path deformation converged. 11 steps. fRatio = 1.98706e-02
# Path deformation converged. 6 steps. fRatio = 1.75998e-02
# Path deformation converged. 2 steps. fRatio = 1.61852e-02
# Path deformation converged. 2 steps. fRatio = 1.62980e-02
# Path deformation converged. 2 steps. fRatio = 1.63727e-02
# Path deformation converged. 2 steps. fRatio = 1.63660e-02
# Path deformation converged. 2 steps. fRatio = 1.62991e-02
# Path deformation converged. 2 steps. fRatio = 1.61862e-02
# Path deformation converged. 2 steps. fRatio = 1.60599e-02
# Path deformation converged. 2 steps. fRatio = 1.59040e-02
# ...
# Path deformation converged. 4 steps. fRatio = 1.90750e-02
# Path deformation converged. 2 steps. fRatio = 1.76802e-02
# Path deformation converged. 2 steps. fRatio = 1.72833e-02
# Path deformation converged. 2 steps. fRatio = 1.69016e-02
# Path deformation converged. 2 steps. fRatio = 1.65079e-02
# Path deformation converged. 2 steps. fRatio = 1.61106e-02
# Path deformation converged. 2 steps. fRatio = 1.57262e-02
# Path deformation converged. 2 steps. fRatio = 1.53512e-02
# Path deformation converged. 2 steps. fRatio = 1.49879e-02
# Path deformation converged. 2 steps. fRatio = 1.46642e-02
# Path deformation converged. 2 steps. fRatio = 1.43389e-02
# Path deformation converged. 2 steps. fRatio = 1.40564e-02
# Path deformation converged. 2 steps. fRatio = 1.37815e-02
# Path deformation converged. 2 steps. fRatio = 1.35258e-02
# Path deformation converged. 2 steps. fRatio = 1.32888e-02
# Path deformation converged. 2 steps. fRatio = 1.30688e-02
# Path deformation converged. 2 steps. fRatio = 1.28679e-02
# Path deformation converged. 2 steps. fRatio = 1.26825e-02
# Tunneling from phase 1 to phase 0 at T=102.9057
# high_vev = [4.25375797e-06 3.62278665e+01]
# low_vev = [213.60389713  89.74334361]
# Path deformation converged. 51 steps. fRatio = 1.93911e-02
# Path deformation converged. 17 steps. fRatio = 1.56518e-02
# Path deformation converged. 2 steps. fRatio = 1.72773e-02
# Path deformation converged. 2 steps. fRatio = 1.67511e-02
# Path deformation converged. 2 steps. fRatio = 1.64488e-02
# Path deformation converged. 2 steps. fRatio = 1.61054e-02
# Path deformation converged. 2 steps. fRatio = 1.57347e-02
# Path deformation converged. 2 steps. fRatio = 1.53620e-02
# Path deformation converged. 2 steps. fRatio = 1.49877e-02
# Path deformation converged. 2 steps. fRatio = 1.46456e-02
# Path deformation converged. 2 steps. fRatio = 1.43103e-02
# Path deformation converged. 2 steps. fRatio = 1.39999e-02
# Path deformation converged. 2 steps. fRatio = 1.37157e-02
# Path deformation converged. 2 steps. fRatio = 1.34438e-02
# Path deformation converged. 2 steps. fRatio = 1.31922e-02
# Path deformation converged. 2 steps. fRatio = 1.29616e-02
# Path deformation converged. 2 steps. fRatio = 1.27478e-02
# Path deformation converged. 2 steps. fRatio = 1.25449e-02
# Path deformation converged. 2 steps. fRatio = 1.23576e-02
# Path deformation converged. 2 steps. fRatio = 1.21896e-02
# Tunneling from phase 1 to phase 0 at T=104.0487
# high_vev = [4.23215775e-06 3.63907542e+01]
# low_vev = [212.11981344  89.73046005]
# Path deformation converged. 51 steps. fRatio = 1.92914e-02
# Path deformation converged. 17 steps. fRatio = 1.49699e-02
# Path deformation converged. 2 steps. fRatio = 1.50775e-02
# Path deformation converged. 2 steps. fRatio = 1.47947e-02
# Path deformation converged. 2 steps. fRatio = 1.46022e-02
# Path deformation converged. 2 steps. fRatio = 1.43309e-02
# Path deformation converged. 2 steps. fRatio = 1.40425e-02
# Path deformation converged. 2 steps. fRatio = 1.37539e-02
# Path deformation converged. 2 steps. fRatio = 1.34708e-02
# Path deformation converged. 2 steps. fRatio = 1.31970e-02
# Path deformation converged. 2 steps. fRatio = 1.29407e-02
# Path deformation converged. 2 steps. fRatio = 1.27002e-02
# Path deformation converged. 2 steps. fRatio = 1.24757e-02
# Path deformation converged. 2 steps. fRatio = 1.22673e-02
# Path deformation converged. 2 steps. fRatio = 1.20790e-02
# Path deformation converged. 2 steps. fRatio = 1.18928e-02
# Path deformation converged. 2 steps. fRatio = 1.17351e-02
# Path deformation converged. 2 steps. fRatio = 1.15893e-02
# Path deformation converged. 2 steps. fRatio = 1.14394e-02
# Path deformation converged. 2 steps. fRatio = 1.13049e-02
# Tunneling from phase 1 to phase 0 at T=105.1916
# high_vev = [4.20485254e-06 3.65582159e+01]
# low_vev = [210.5712253   89.71641788]
# Path deformation converged. 51 steps. fRatio = 1.64378e-02
# Path deformation converged. 16 steps. fRatio = 1.85781e-02
# Path deformation converged. 2 steps. fRatio = 1.95607e-02
# Path deformation converged. 2 steps. fRatio = 1.84827e-02
# Path deformation converged. 2 steps. fRatio = 1.78222e-02
# Path deformation converged. 2 steps. fRatio = 1.71912e-02
# Path deformation converged. 2 steps. fRatio = 1.65897e-02
# Path deformation converged. 2 steps. fRatio = 1.60025e-02
# Path deformation converged. 2 steps. fRatio = 1.54860e-02
# Path deformation converged. 2 steps. fRatio = 1.49854e-02
# Path deformation converged. 2 steps. fRatio = 1.45337e-02
# Path deformation converged. 2 steps. fRatio = 1.41177e-02
# Path deformation converged. 2 steps. fRatio = 1.37490e-02
# Path deformation converged. 2 steps. fRatio = 1.33917e-02
# Path deformation converged. 2 steps. fRatio = 1.30671e-02
# Path deformation converged. 2 steps. fRatio = 1.27950e-02
# Path deformation converged. 2 steps. fRatio = 1.25309e-02
# Path deformation converged. 2 steps. fRatio = 1.22764e-02
# Path deformation converged. 2 steps. fRatio = 1.20663e-02
# Path deformation converged. 2 steps. fRatio = 1.18711e-02
# Tunneling from phase 1 to phase 0 at T=106.3346
# high_vev = [2.82526641e-06 3.67302026e+01]
# low_vev = [208.95372689  89.70107603]
# Path deformation converged. 51 steps. fRatio = 1.62355e-02
# Path deformation converged. 16 steps. fRatio = 1.76464e-02
# Path deformation converged. 2 steps. fRatio = 1.89445e-02
# Path deformation converged. 1 steps. fRatio = 9.94546e-02
# Tunneling from phase 1 to phase 0 at T=107.4776
# high_vev = [4.82087702e-06 3.69066609e+01]
# low_vev = [207.26235269  89.68426997]
# Path deformation converged. 50 steps. fRatio = 1.94868e-02
# Path deformation converged. 16 steps. fRatio = 1.65159e-02
# Path deformation converged. 2 steps. fRatio = 1.73880e-02
# Path deformation converged. 1 steps. fRatio = 9.55706e-02
# Tunneling from phase 1 to phase 0 at T=108.6205
# high_vev = [5.35543541e-06 3.70875444e+01]
# low_vev = [205.49144964  89.66580904]
# Path deformation converged. 53 steps. fRatio = 1.89712e-02
# Path deformation converged. 14 steps. fRatio = 1.83353e-02
# Path deformation converged. 1 steps. fRatio = 9.28078e-02
# Tunneling from phase 1 to phase 0 at T=109.7635
# high_vev = [6.03199443e-06 3.72727928e+01]
# low_vev = [203.6345557   89.64546078]
# Path deformation converged. 55 steps. fRatio = 1.83451e-02
# Path deformation converged. 11 steps. fRatio = 1.97818e-02
# Path deformation converged. 1 steps. fRatio = 9.30972e-02
# Tunneling from phase 1 to phase 0 at T=110.9065
# high_vev = [5.79833403e-06 3.74623605e+01]
# low_vev = [201.68419877  89.62295574]
# Path deformation converged. 54 steps. fRatio = 1.95283e-02
# Path deformation converged. 11 steps. fRatio = 1.86631e-02
# Path deformation converged. 1 steps. fRatio = 9.02491e-02
# Tunneling from phase 1 to phase 0 at T=112.0494
# high_vev = [6.44689337e-06 3.76561721e+01]
# low_vev = [199.6316813   89.59796121]
# Path deformation converged. 50 steps. fRatio = 1.88950e-02
# Path deformation converged. 11 steps. fRatio = 1.70000e-02
# Path deformation converged. 1 steps. fRatio = 8.84288e-02
# Tunneling from phase 1 to phase 0 at T=113.1924
# high_vev = [7.24066451e-06 3.78541715e+01]
# low_vev = [197.46676513  89.57007621]
# Path deformation converged. 51 steps. fRatio = 1.83345e-02
# Path deformation converged. 17 steps. fRatio = 1.49173e-02
# Path deformation converged. 1 steps. fRatio = 9.14030e-02
# Tunneling from phase 1 to phase 0 at T=114.3354
# high_vev = [6.73325022e-06 3.80562925e+01]
# low_vev = [195.17725514  89.53880835]
# Path deformation converged. 58 steps. fRatio = 1.82886e-02
# Path deformation converged. 12 steps. fRatio = 1.70331e-02
# Path deformation converged. 1 steps. fRatio = 8.62358e-02
# Tunneling from phase 1 to phase 0 at T=115.4783
# high_vev = [6.77133182e-06 3.82624720e+01]
# low_vev = [192.74842814  89.50353451]
# Path deformation converged. 55 steps. fRatio = 1.71595e-02
# Path deformation converged. 15 steps. fRatio = 1.68167e-02
# Path deformation converged. 1 steps. fRatio = 7.98110e-02
# Tunneling from phase 1 to phase 0 at T=116.6213
# high_vev = [8.55627869e-06 3.84726283e+01]
# low_vev = [190.16222259  89.46346848]
# Path deformation converged. 51 steps. fRatio = 1.59328e-02
# Path deformation converged. 16 steps. fRatio = 1.84898e-02
# Path deformation converged. 1 steps. fRatio = 7.81253e-02
# Tunneling from phase 1 to phase 0 at T=117.7643
# high_vev = [7.68074708e-06 3.86866916e+01]
# low_vev = [187.39606834  89.41758503]
# Path deformation converged. 50 steps. fRatio = 1.96962e-02
# Path deformation converged. 15 steps. fRatio = 1.80749e-02
# Path deformation converged. 1 steps. fRatio = 7.40034e-02
# Optimization terminated successfully.
#          Current function value: 0.000005
#          Iterations: 18
#          Function evaluations: 37
# The physical volunme diminishes at Tp: True
# Tunneling from phase 1 to phase 0 at T=99.32834
# high_vev = [4.08948480e-06 3.57480525e+01]
# low_vev = [217.87288438  89.77742714]
# Path deformation converged. 51 steps. fRatio = 1.89908e-02
# Path deformation converged. 16 steps. fRatio = 1.73296e-02
# Path deformation converged. 4 steps. fRatio = 1.94705e-02
# Path deformation converged. 2 steps. fRatio = 1.85614e-02
# Path deformation converged. 2 steps. fRatio = 1.82573e-02
# Path deformation converged. 2 steps. fRatio = 1.79374e-02
# Path deformation converged. 2 steps. fRatio = 1.75738e-02
# Path deformation converged. 2 steps. fRatio = 1.72149e-02
# Path deformation converged. 2 steps. fRatio = 1.68448e-02
# Path deformation converged. 2 steps. fRatio = 1.64895e-02
# Path deformation converged. 2 steps. fRatio = 1.61757e-02
# Path deformation converged. 2 steps. fRatio = 1.58432e-02
# Path deformation converged. 2 steps. fRatio = 1.55463e-02
# Path deformation converged. 2 steps. fRatio = 1.52607e-02
# Path deformation converged. 2 steps. fRatio = 1.50020e-02
# Path deformation converged. 2 steps. fRatio = 1.47439e-02
# Path deformation converged. 2 steps. fRatio = 1.45070e-02
# Path deformation converged. 2 steps. fRatio = 1.43018e-02
# Path deformation converged. 2 steps. fRatio = 1.40942e-02
# Path deformation converged. 2 steps. fRatio = 1.39017e-02
# Tunneling from phase 1 to phase 0 at T=62.85969
# high_vev = [1.58906592e-08 3.36356320e+01]
# low_vev = [241.34742171  89.89986505]
# Path deformation converged. 47 steps. fRatio = 1.99990e-02
# Path deformation converged. 18 steps. fRatio = 1.82275e-02
# Path deformation converged. 11 steps. fRatio = 1.96518e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Tunneling from phase 1 to phase 0 at T=62.86019
# high_vev = [1.70734978e-08 3.36356234e+01]
# low_vev = [241.34726738  89.89986528]
# Path deformation converged. 47 steps. fRatio = 1.99995e-02
# Path deformation converged. 18 steps. fRatio = 1.82375e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Path deformation converged. 19 steps. fRatio = 1.95624e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Path deformation converged. 16 steps. fRatio = 1.99512e-02
# Path deformation converged. 20 steps. fRatio = 1.99028e-02
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# Deformation doesn't appear to be converging.Stopping at the point of best convergence.
# error ocurred

# %%
dict_out
# Out:
# {'ms': 468.9372894907104,
#  'theta': 0.0007790391283424017,
#  'u': 89.91373817155652,
#  'muhs': -655.8700955736117,
#  'mu3': 677.6488485142712,
#  'yt': 0.9915178727762072,
#  'lamh': 0.12907511859003615,
#  'lams': 3.695840079026444,
#  'lammix': 7.287248819407041,
#  'muh2': -21691.10621218125,
#  'mus2': -31268.84755760216,
#  'Pih': 0.6984513316910521,
#  'Pis': 2.1385014896577843,
#  'lamh_tilde': -3.463071336644164,
#  'Lam_CP': 685.9336453027445,
#  'th_bool': True,
#  'isEWSB': False,
#  'edm_Bool': True,
#  'num_FOPT': 1,
#  'Tc_0': 118.90724750971269,
#  'Tmin_0': 60.78193334607271,
#  'Tnuc_0': 101.47428778069512,
#  'action_Tn_0': 15295.783029076842,
#  'h_low_Tnuc_0': 215.37755457749216,
#  's_low_Tnuc_0': 89.75802763948576,
#  'h_high_Tnuc_0': 3.866315235588111e-06,
#  's_high_Tnuc_0': 36.030372044827956,
#  'Delta_rho_Tnuc_0': 61320089.31756672,
#  'Delta_p_Tnuc_0': 22849209.294125974,
#  'alpha_Tnuc_0': 0.017254812551676435,
#  'beta_Tnuc_0': 883.3796723119116,
#  'vwall_0': 0.6104276517419058,
#  'xi_Jouguet_0': 0.6743466613222274,
#  'f_peak_Tnuc_0': 0.008015894192303568,
#  'Omega_peak_Tnuc_0': 3.077137263348876e-17,
#  'SNR_Tnuc_0': 0.0006153923875571022,
#  'Tp_0': 99.32834096982626,
#  'volume_shrinks_0': True,
#  'action_Tp_0': 13356.467840764397}

# %%
df.iloc[modi].Type,df.iloc[modi].vw
# Out:
# ('Hybrid', 0.6722948691854073)

# %%
###Obtained from 
#df=pd.read_csv("SCANS/BAU/Z2_breaking_sols_BAU_All.csv",index_col=[0]).sort_values("alpha_max").drop_duplicates()
#df=df[df.num_FOPT>1]


Temp, alpha, beta, vel=dict_out["Tp_0"],dict_out["alpha_Tp_0"],dict_out["beta_Tp_0"],df.iloc[modi].vw
my_signal=GW_signal(Temp, alpha, beta, vel)
SNR=SNR_GW(my_signal)
Temp, alpha, beta, vel1=dict_out["Tp_0"],dict_out["alpha_Tp_0"],dict_out["beta_Tp_0"],1
my_signal_1=GW_signal(Temp, alpha, beta, vel1)
SNR_1=SNR_GW(my_signal_1)

thick_size=16
label_size=20

plt.plot(my_signal[0],my_signal[1],
         label= "SNR="+str(np.round(SNR,2))+", $v_w=$" +str(np.round(vel,2)))
plt.plot(my_signal_1[0],my_signal_1[1],linestyle="--",
         label="SNR="+str(np.round(SNR_1,2))+ ", $v_w=$"+str(np.round(vel1,2)))
plt.plot(LISA_curve.f,LISA_curve.Omega_lim,alpha=0.05,color="g")
plt.fill_between(LISA_curve.f, LISA_curve.Omega_lim, 1e-2, alpha=0.05,color="g")
plt.figtext(.5, .72, "LISA", fontsize=label_size)

plt.xlabel("$f$ (Hz)",size=label_size)
plt.ylabel("$\\Omega_{SW}$",size=label_size)
plt.xscale("log")
plt.yscale("log")           
plt.xticks(fontsize=thick_size)
plt.yticks(fontsize=thick_size)
plt.grid(True)
plt.legend(loc="lower left",prop={'size': label_size})
#plt.title("Benchmark P2",size=label_size)



#plt.legend(prop={'size': label_size})
plt.tight_layout()
#plt.savefig('SCANS/bubble_PLOTS/GW_spectum_P2.pdf', dpi=300)
plt.show()
